# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

from core.koopman_core import KoopDNN,KoopmanNet,KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from dynamics.duffing import dynamics_duff
from dynamics.Vanpol import dynamics_vanpol

from core.adapt_net import AdaptNet

# %%
# Base Parameters
dt = 0.01 #time step
num_snaps = 2000 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 200 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 2 # no. of states
num_inputs = 1 # no. of inputs

# %%
# Oscillator parameters
dyn_pars = {}

dyn_pars['a'] = 1
dyn_pars['b'] = 4
dyn_pars['c'] = 0.5
dyn_pars['d'] = 0.5

dyn_pars['del_a'] = 3
dyn_pars['del_b'] = 0
dyn_pars['del_c'] = 0
dyn_pars['del_d'] = 0
dyn_pars['delay'] = False
dyn_pars['delay_time'] = 5
dyn_pars['cont_unc_type'] = 'constant'

# %%
X_changed, X_unchanged, U = dynamics_duff(dt, num_traj, num_snaps, num_states, num_inputs, dyn_pars)

print(X_changed.shape, U.shape)
# Out:
# (250, 2001, 2) (250, 2000, 1)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X_changed)))))
print(sum(sum(sum(np.isnan(X_unchanged)))))
# Out:
# 0
# 0

# %%
l2_diff = np.linalg.norm(X_changed-X_unchanged)/((X_changed.size)**(1/2))
print('l2_diff = ', l2_diff)
# Out:
# l2_diff =  0.2543563670082054

# %%
change_in_dym = np.linalg.norm((X_changed-X_unchanged)/X_changed)/X_changed.size
print('fraction of change in dynamics = ', change_in_dym)
# Out:
# fraction of change in dynamics =  0.4601160075207168

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Phase plot for unchanged dynamics")
axs[1].set_title("Phase plot for changed dynamics")

axs[0].set(xlabel = 'x1', ylabel = 'x2')
axs[1].set(xlabel = 'x1', ylabel = 'x2')

for i in range(num_traj):
    axs[0].plot(X_unchanged[i,:,0], X_unchanged[i,:,1])
    axs[1].plot(X_changed[i,:,0], X_changed[i,:,1])
plt.savefig('phase_plot_duffing.jpg')

# %%
plt.figure()

plt.title('Comparison of Phase plot')
plt.plot(X_unchanged[4,:,0], X_unchanged[4,:,1], label = 'unchanged')
plt.plot(X_changed[4,:,0], X_changed[4,:,1], label = 'changed')

plt.legend()
plt.savefig('phase_plot_duffing_single_traj.jpg')
plt.show()

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in position")
axs[1].set_title("Error in velocity")

axs[0].set(xlabel = 't', ylabel = 'x1')
axs[1].set(xlabel = 't', ylabel = 'x2')


axs[0].plot(T, X_unchanged[4,:,0], label = 'unchanged')
axs[0].plot(T, X_changed[4,:,0], label = 'changed')
axs[0].legend()

axs[1].plot(T, X_unchanged[4,:,1], label = 'unchanged')
axs[1].plot(T, X_changed[4,:,1], label = 'changed')
axs[1].legend()

plt.savefig('vel_pos_err_duffing_single_traj.jpg')

# %%
# split training and vaidation datasets
xs_train, us_train = X_unchanged[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X_unchanged[num_train:,:,:],U[num_train:,:,:]

# %% [markdown]
# ***Koopman bilinear Models***

# %%
# auto encoder parameters

net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 2e-4 # 5e-4
net_params['epochs'] = 300
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
train = False

if train == True:
    file = 'duff_pos_adap.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'duff_pos_adap.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 0.2838591635, validation loss: 0.0996795199
# Epoch   2: train loss: 0.0695747510, validation loss: 0.0437129503
# Epoch   3: train loss: 0.0196324587, validation loss: 0.0101755209
# Epoch   4: train loss: 0.0070319711, validation loss: 0.0065064963
# Epoch   5: train loss: 0.0050766454, validation loss: 0.0049584066
# Epoch   6: train loss: 0.0039790161, validation loss: 0.0039167322
# Epoch   7: train loss: 0.0031925926, validation loss: 0.0032226258
# Epoch   8: train loss: 0.0026477929, validation loss: 0.0026563650
# Epoch   9: train loss: 0.0022584130, validation loss: 0.0022943634
# Epoch  10: train loss: 0.0019618692, validation loss: 0.0020241443
# Epoch  11: train loss: 0.0017393018, validation loss: 0.0017939229
# Epoch  12: train loss: 0.0015571800, validation loss: 0.0015973375
# Epoch  13: train loss: 0.0014085150, validation loss: 0.0014699295
# Epoch  14: train loss: 0.0012861897, validation loss: 0.0013387148
# Epoch  15: train loss: 0.0011816698, validation loss: 0.0012201200
# Epoch  16: train loss: 0.0010876681, validation loss: 0.0011194590
# Epoch  17: train loss: 0.0010086773, validation loss: 0.0010445033
# Epoch  18: train loss: 0.0009326331, validation loss: 0.0009681629
# Epoch  19: train loss: 0.0008632935, validation loss: 0.0008964710
# Epoch  20: train loss: 0.0007979864, validation loss: 0.0008453508
# Epoch  21: train loss: 0.0007372085, validation loss: 0.0007645763
# Epoch  22: train loss: 0.0006750881, validation loss: 0.0006896418
# Epoch  23: train loss: 0.0006183883, validation loss: 0.0006240849
# Epoch  24: train loss: 0.0005638266, validation loss: 0.0005756718
# Epoch  25: train loss: 0.0005095173, validation loss: 0.0005360037
# Epoch  26: train loss: 0.0004600821, validation loss: 0.0004868382
# Epoch  27: train loss: 0.0004154284, validation loss: 0.0004157962
# Epoch  28: train loss: 0.0003739458, validation loss: 0.0003738322
# Epoch  29: train loss: 0.0003372503, validation loss: 0.0003445875
# Epoch  30: train loss: 0.0003067687, validation loss: 0.0003163078
# Epoch  31: train loss: 0.0002795379, validation loss: 0.0002850224
# Epoch  32: train loss: 0.0002551833, validation loss: 0.0002790484
# Epoch  33: train loss: 0.0002354820, validation loss: 0.0002475459
# Epoch  34: train loss: 0.0002188671, validation loss: 0.0002343375
# Epoch  35: train loss: 0.0002037342, validation loss: 0.0002141675
# Epoch  36: train loss: 0.0001901868, validation loss: 0.0002104584
# Epoch  37: train loss: 0.0001779295, validation loss: 0.0002057276
# Epoch  38: train loss: 0.0001679637, validation loss: 0.0001825402
# Epoch  39: train loss: 0.0001571904, validation loss: 0.0001736864
# Epoch  40: train loss: 0.0001493882, validation loss: 0.0001587652
# Epoch  41: train loss: 0.0001404237, validation loss: 0.0001616433
# Epoch  42: train loss: 0.0001338064, validation loss: 0.0001555090
# Epoch  43: train loss: 0.0001276008, validation loss: 0.0001497366
# Epoch  44: train loss: 0.0001202252, validation loss: 0.0001242925
# Epoch  45: train loss: 0.0001151849, validation loss: 0.0001273983
# Epoch  46: train loss: 0.0001091835, validation loss: 0.0001531935
# Epoch  47: train loss: 0.0001048599, validation loss: 0.0001192499
# Epoch  48: train loss: 0.0001007000, validation loss: 0.0001066962
# Epoch  49: train loss: 0.0000961329, validation loss: 0.0001023242
# Epoch  50: train loss: 0.0000921667, validation loss: 0.0000980556
# Epoch  51: train loss: 0.0000887816, validation loss: 0.0001048263
# Epoch  52: train loss: 0.0000852609, validation loss: 0.0000985816
# Epoch  53: train loss: 0.0000816324, validation loss: 0.0000835295
# Epoch  54: train loss: 0.0000794198, validation loss: 0.0000798929
# Epoch  55: train loss: 0.0000762790, validation loss: 0.0000777432
# Epoch  56: train loss: 0.0000735236, validation loss: 0.0000753478
# Epoch  57: train loss: 0.0000712932, validation loss: 0.0001247157
# Epoch  58: train loss: 0.0000691449, validation loss: 0.0000716865
# Epoch  59: train loss: 0.0000665866, validation loss: 0.0000762449
# Epoch  60: train loss: 0.0000648392, validation loss: 0.0000690583
# Epoch  61: train loss: 0.0000627178, validation loss: 0.0000877716
# Epoch  62: train loss: 0.0000608752, validation loss: 0.0000820910
# Epoch  63: train loss: 0.0000593668, validation loss: 0.0001089480
# Epoch  64: train loss: 0.0000577730, validation loss: 0.0000600701
# Epoch  65: train loss: 0.0000562494, validation loss: 0.0000551242
# Epoch  66: train loss: 0.0000548064, validation loss: 0.0000539398
# Epoch  67: train loss: 0.0000530548, validation loss: 0.0000578595
# Epoch  68: train loss: 0.0000521718, validation loss: 0.0000546073
# Epoch  69: train loss: 0.0000507497, validation loss: 0.0000659789
# Epoch  70: train loss: 0.0000495005, validation loss: 0.0000484715
# Epoch  71: train loss: 0.0000482672, validation loss: 0.0000614380
# Epoch  72: train loss: 0.0000470225, validation loss: 0.0000491825
# Epoch  73: train loss: 0.0000464630, validation loss: 0.0000435517
# Epoch  74: train loss: 0.0000450431, validation loss: 0.0000429659
# Epoch  75: train loss: 0.0000444080, validation loss: 0.0000446713
# Epoch  76: train loss: 0.0000435655, validation loss: 0.0000445211
# Epoch  77: train loss: 0.0000426366, validation loss: 0.0000589318
# Epoch  78: train loss: 0.0000418885, validation loss: 0.0000423034
# Epoch  79: train loss: 0.0000408898, validation loss: 0.0000408066
# Epoch  80: train loss: 0.0000401405, validation loss: 0.0000415907
# Epoch  81: train loss: 0.0000392091, validation loss: 0.0000614740
# Epoch  82: train loss: 0.0000388108, validation loss: 0.0000507905
# Epoch  83: train loss: 0.0000378200, validation loss: 0.0000371921
# Epoch  84: train loss: 0.0000373065, validation loss: 0.0000382870
# Epoch  85: train loss: 0.0000367022, validation loss: 0.0000381044
# Epoch  86: train loss: 0.0000361726, validation loss: 0.0000407345
# Epoch  87: train loss: 0.0000354117, validation loss: 0.0000326233
# Epoch  88: train loss: 0.0000353743, validation loss: 0.0000331130
# Epoch  89: train loss: 0.0000342321, validation loss: 0.0000514933
# Epoch  90: train loss: 0.0000341126, validation loss: 0.0000343281
# Epoch  91: train loss: 0.0000330537, validation loss: 0.0000305523
# Epoch  92: train loss: 0.0000328374, validation loss: 0.0000305652
# Epoch  93: train loss: 0.0000323771, validation loss: 0.0000398845
# Epoch  94: train loss: 0.0000319874, validation loss: 0.0000364130
# Epoch  95: train loss: 0.0000316638, validation loss: 0.0000314969
# Epoch  96: train loss: 0.0000309499, validation loss: 0.0000411864
# Epoch  97: train loss: 0.0000307311, validation loss: 0.0000308044
# Epoch  98: train loss: 0.0000302206, validation loss: 0.0000381864
# Epoch  99: train loss: 0.0000299071, validation loss: 0.0000286008
# Epoch 100: train loss: 0.0000295769, validation loss: 0.0000455777
# Epoch 101: train loss: 0.0000293900, validation loss: 0.0000253538
# Epoch 102: train loss: 0.0000290307, validation loss: 0.0000339910
# Epoch 103: train loss: 0.0000283033, validation loss: 0.0000365492
# Epoch 104: train loss: 0.0000281001, validation loss: 0.0000684548
# Epoch 105: train loss: 0.0000280739, validation loss: 0.0000248488
# Epoch 106: train loss: 0.0000276131, validation loss: 0.0000247508
# Epoch 107: train loss: 0.0000274617, validation loss: 0.0000419488
# Epoch 108: train loss: 0.0000267414, validation loss: 0.0000615700
# Epoch 109: train loss: 0.0000267310, validation loss: 0.0000304913
# Epoch 110: train loss: 0.0000262745, validation loss: 0.0000532191
# Epoch 111: train loss: 0.0000263294, validation loss: 0.0000269792
# Epoch 112: train loss: 0.0000257189, validation loss: 0.0000745876
# Epoch 113: train loss: 0.0000254621, validation loss: 0.0000312596
# Epoch 114: train loss: 0.0000253840, validation loss: 0.0000219329
# Epoch 115: train loss: 0.0000253197, validation loss: 0.0001015888
# Epoch 116: train loss: 0.0000249592, validation loss: 0.0000211315
# Epoch 117: train loss: 0.0000246719, validation loss: 0.0000241242
# Epoch 118: train loss: 0.0000244793, validation loss: 0.0000251537
# Epoch 119: train loss: 0.0000243690, validation loss: 0.0000210651
# Epoch 120: train loss: 0.0000240988, validation loss: 0.0000221068
# Epoch 121: train loss: 0.0000238121, validation loss: 0.0000403275
# Epoch 122: train loss: 0.0000236186, validation loss: 0.0000252774
# Epoch 123: train loss: 0.0000235494, validation loss: 0.0000201600
# Epoch 124: train loss: 0.0000240925, validation loss: 0.0000198605
# Epoch 125: train loss: 0.0000223869, validation loss: 0.0000211103
# Epoch 126: train loss: 0.0000232395, validation loss: 0.0000187199
# Epoch 127: train loss: 0.0000224139, validation loss: 0.0000198743
# Epoch 128: train loss: 0.0000228820, validation loss: 0.0000376077
# Epoch 129: train loss: 0.0000219584, validation loss: 0.0000283412
# Epoch 130: train loss: 0.0000222028, validation loss: 0.0000197587
# Epoch 131: train loss: 0.0000219669, validation loss: 0.0000169014
# Epoch 132: train loss: 0.0000220042, validation loss: 0.0000268865
# Epoch 133: train loss: 0.0000217251, validation loss: 0.0000168196
# Epoch 134: train loss: 0.0000217498, validation loss: 0.0000215024
# Epoch 135: train loss: 0.0000214993, validation loss: 0.0000268331
# Epoch 136: train loss: 0.0000213129, validation loss: 0.0000241991
# Epoch 137: train loss: 0.0000211530, validation loss: 0.0000214620
# Epoch 138: train loss: 0.0000214248, validation loss: 0.0000168080
# Epoch 139: train loss: 0.0000207470, validation loss: 0.0000180445
# Epoch 140: train loss: 0.0000206702, validation loss: 0.0000201533
# Epoch 141: train loss: 0.0000208531, validation loss: 0.0000182883
# Epoch 142: train loss: 0.0000206177, validation loss: 0.0000209801
# Epoch 143: train loss: 0.0000203997, validation loss: 0.0000147414
# Epoch 144: train loss: 0.0000202369, validation loss: 0.0000161709
# Epoch 145: train loss: 0.0000203221, validation loss: 0.0000551712
# Epoch 146: train loss: 0.0000200679, validation loss: 0.0000155583
# Epoch 147: train loss: 0.0000201870, validation loss: 0.0000186401
# Epoch 148: train loss: 0.0000198244, validation loss: 0.0000248243
# Epoch 149: train loss: 0.0000195882, validation loss: 0.0000145512
# Epoch 150: train loss: 0.0000195743, validation loss: 0.0000146669
# Epoch 151: train loss: 0.0000197498, validation loss: 0.0000138633
# Epoch 152: train loss: 0.0000194033, validation loss: 0.0000147718
# Epoch 153: train loss: 0.0000190691, validation loss: 0.0000316009
# Epoch 154: train loss: 0.0000191681, validation loss: 0.0000196398
# Epoch 155: train loss: 0.0000193601, validation loss: 0.0000262255
# Epoch 156: train loss: 0.0000188174, validation loss: 0.0000135247
# Epoch 157: train loss: 0.0000190552, validation loss: 0.0000152673
# Epoch 158: train loss: 0.0000186898, validation loss: 0.0000225060
# Epoch 159: train loss: 0.0000191357, validation loss: 0.0000212779
# Epoch 160: train loss: 0.0000185019, validation loss: 0.0000126985
# Epoch 161: train loss: 0.0000185300, validation loss: 0.0000133999
# Epoch 162: train loss: 0.0000191658, validation loss: 0.0000134913
# Epoch 163: train loss: 0.0000180478, validation loss: 0.0000133407
# Epoch 164: train loss: 0.0000184847, validation loss: 0.0000122894
# Epoch 165: train loss: 0.0000185137, validation loss: 0.0000162113
# Epoch 166: train loss: 0.0000181476, validation loss: 0.0000125976
# Epoch 167: train loss: 0.0000178595, validation loss: 0.0000149543
# Epoch 168: train loss: 0.0000180240, validation loss: 0.0000131686
# Epoch 169: train loss: 0.0000182003, validation loss: 0.0000125521
# Epoch 170: train loss: 0.0000179384, validation loss: 0.0000118969
# Epoch 171: train loss: 0.0000177997, validation loss: 0.0000699899
# Epoch 172: train loss: 0.0000177736, validation loss: 0.0000555185
# Epoch 173: train loss: 0.0000176144, validation loss: 0.0000203895
# Epoch 174: train loss: 0.0000177564, validation loss: 0.0000135105
# Epoch 175: train loss: 0.0000178979, validation loss: 0.0000116426
# Epoch 176: train loss: 0.0000172356, validation loss: 0.0000159898
# Epoch 177: train loss: 0.0000175585, validation loss: 0.0000188723
# Epoch 178: train loss: 0.0000172764, validation loss: 0.0000293269
# Epoch 179: train loss: 0.0000172015, validation loss: 0.0000191101
# Epoch 180: train loss: 0.0000173440, validation loss: 0.0000143412
# Epoch 181: train loss: 0.0000173630, validation loss: 0.0000190065
# Epoch 182: train loss: 0.0000170371, validation loss: 0.0000141993
# Epoch 183: train loss: 0.0000172086, validation loss: 0.0000111379
# Epoch 184: train loss: 0.0000170149, validation loss: 0.0000108445
# Epoch 185: train loss: 0.0000169338, validation loss: 0.0000152166
# Epoch 186: train loss: 0.0000168887, validation loss: 0.0000126217
# Epoch 187: train loss: 0.0000168423, validation loss: 0.0000268560
# Epoch 188: train loss: 0.0000168167, validation loss: 0.0000124212
# Epoch 189: train loss: 0.0000166243, validation loss: 0.0000291498
# Epoch 190: train loss: 0.0000167442, validation loss: 0.0000144319
# Epoch 191: train loss: 0.0000167718, validation loss: 0.0000151781
# Epoch 192: train loss: 0.0000163418, validation loss: 0.0000139251
# Epoch 193: train loss: 0.0000165217, validation loss: 0.0000143726
# Epoch 194: train loss: 0.0000164831, validation loss: 0.0000114133
# Epoch 195: train loss: 0.0000163282, validation loss: 0.0000128115
# Epoch 196: train loss: 0.0000162838, validation loss: 0.0000671427
# Epoch 197: train loss: 0.0000167093, validation loss: 0.0001170388
# Epoch 198: train loss: 0.0000159647, validation loss: 0.0000135462
# Epoch 199: train loss: 0.0000162365, validation loss: 0.0000178696
# Epoch 200: train loss: 0.0000162603, validation loss: 0.0000156091
# Epoch 201: train loss: 0.0000160333, validation loss: 0.0000119257
# Epoch 202: train loss: 0.0000161166, validation loss: 0.0000111739
# Epoch 203: train loss: 0.0000158649, validation loss: 0.0000136243
# Epoch 204: train loss: 0.0000162295, validation loss: 0.0000099946
# Epoch 205: train loss: 0.0000156106, validation loss: 0.0000112164
# Epoch 206: train loss: 0.0000161850, validation loss: 0.0000115146
# Epoch 207: train loss: 0.0000155670, validation loss: 0.0000118857
# Epoch 208: train loss: 0.0000159085, validation loss: 0.0000493478
# Epoch 209: train loss: 0.0000158217, validation loss: 0.0000122537
# Epoch 210: train loss: 0.0000155944, validation loss: 0.0000133773
# Epoch 211: train loss: 0.0000157465, validation loss: 0.0000094068
# Epoch 212: train loss: 0.0000156833, validation loss: 0.0000093209
# Epoch 213: train loss: 0.0000155893, validation loss: 0.0000103549
# Epoch 214: train loss: 0.0000158215, validation loss: 0.0000090466
# Epoch 215: train loss: 0.0000155878, validation loss: 0.0000144543
# Epoch 216: train loss: 0.0000151692, validation loss: 0.0000161259
# Epoch 217: train loss: 0.0000154233, validation loss: 0.0000092743
# Epoch 218: train loss: 0.0000153423, validation loss: 0.0000134784
# Epoch 219: train loss: 0.0000155275, validation loss: 0.0000153445
# Epoch 220: train loss: 0.0000153695, validation loss: 0.0000146839
# Epoch 221: train loss: 0.0000152406, validation loss: 0.0000098503
# Epoch 222: train loss: 0.0000150988, validation loss: 0.0000205234
# Epoch 223: train loss: 0.0000150583, validation loss: 0.0000110817
# Epoch 224: train loss: 0.0000153375, validation loss: 0.0000095273
# Epoch 225: train loss: 0.0000151313, validation loss: 0.0000124521
# Epoch 226: train loss: 0.0000150262, validation loss: 0.0000129829
# Epoch 227: train loss: 0.0000150795, validation loss: 0.0000116110
# Epoch 228: train loss: 0.0000155085, validation loss: 0.0000112289
# Epoch 229: train loss: 0.0000143489, validation loss: 0.0000082222
# Epoch 230: train loss: 0.0000150134, validation loss: 0.0000114993
# Epoch 231: train loss: 0.0000149872, validation loss: 0.0000127715
# Epoch 232: train loss: 0.0000148951, validation loss: 0.0000108462
# Epoch 233: train loss: 0.0000146878, validation loss: 0.0000096565
# Epoch 234: train loss: 0.0000147627, validation loss: 0.0000113395
# Epoch 235: train loss: 0.0000149041, validation loss: 0.0000099574
# Epoch 236: train loss: 0.0000146846, validation loss: 0.0000138504
# Epoch 237: train loss: 0.0000148039, validation loss: 0.0000079939
# Epoch 238: train loss: 0.0000145844, validation loss: 0.0000110977
# Epoch 239: train loss: 0.0000147313, validation loss: 0.0000183986
# Epoch 240: train loss: 0.0000146082, validation loss: 0.0000262261
# Epoch 241: train loss: 0.0000144309, validation loss: 0.0000173595
# Epoch 242: train loss: 0.0000145249, validation loss: 0.0000104947
# Epoch 243: train loss: 0.0000143794, validation loss: 0.0000141745
# Epoch 244: train loss: 0.0000144745, validation loss: 0.0000103659
# Epoch 245: train loss: 0.0000146073, validation loss: 0.0000098943
# Epoch 246: train loss: 0.0000141704, validation loss: 0.0000078891
# Epoch 247: train loss: 0.0000144152, validation loss: 0.0000104292
# Epoch 248: train loss: 0.0000146622, validation loss: 0.0000100761
# Epoch 249: train loss: 0.0000142328, validation loss: 0.0000115173
# Epoch 250: train loss: 0.0000144074, validation loss: 0.0000142935
# Epoch 251: train loss: 0.0000139599, validation loss: 0.0000085100
# Epoch 252: train loss: 0.0000140929, validation loss: 0.0000160238
# Epoch 253: train loss: 0.0000143667, validation loss: 0.0000103032
# Epoch 254: train loss: 0.0000141393, validation loss: 0.0000077311
# Epoch 255: train loss: 0.0000141069, validation loss: 0.0000083036
# Epoch 256: train loss: 0.0000140372, validation loss: 0.0000123274
# Epoch 257: train loss: 0.0000141187, validation loss: 0.0000087167
# Epoch 258: train loss: 0.0000141025, validation loss: 0.0000085773
# Epoch 259: train loss: 0.0000138356, validation loss: 0.0000077164
# Epoch 260: train loss: 0.0000142493, validation loss: 0.0000070174
# Epoch 261: train loss: 0.0000136149, validation loss: 0.0000173624
# Epoch 262: train loss: 0.0000141346, validation loss: 0.0000078316
# Epoch 263: train loss: 0.0000138031, validation loss: 0.0000203831
# Epoch 264: train loss: 0.0000142708, validation loss: 0.0000310210
# Epoch 265: train loss: 0.0000135135, validation loss: 0.0000301559
# Epoch 266: train loss: 0.0000139062, validation loss: 0.0000077040
# Epoch 267: train loss: 0.0000137886, validation loss: 0.0000117670
# Epoch 268: train loss: 0.0000136418, validation loss: 0.0000345339
# Epoch 269: train loss: 0.0000136407, validation loss: 0.0000082913
# Epoch 270: train loss: 0.0000141166, validation loss: 0.0002163483
# Epoch 271: train loss: 0.0000133074, validation loss: 0.0000135473
# Epoch 272: train loss: 0.0000140281, validation loss: 0.0000125479
# Epoch 273: train loss: 0.0000139608, validation loss: 0.0000177557
# Epoch 274: train loss: 0.0000132445, validation loss: 0.0000080874
# Epoch 275: train loss: 0.0000133534, validation loss: 0.0000070235
# Epoch 276: train loss: 0.0000138525, validation loss: 0.0000077426
# Epoch 277: train loss: 0.0000132596, validation loss: 0.0000075420
# Epoch 278: train loss: 0.0000135357, validation loss: 0.0000075323
# Epoch 279: train loss: 0.0000137109, validation loss: 0.0000116656
# Epoch 280: train loss: 0.0000134359, validation loss: 0.0000243469
# Epoch 281: train loss: 0.0000134385, validation loss: 0.0000483075
# Epoch 282: train loss: 0.0000133433, validation loss: 0.0000175437
# Epoch 283: train loss: 0.0000133109, validation loss: 0.0000085457
# Epoch 284: train loss: 0.0000133153, validation loss: 0.0000094733
# Epoch 285: train loss: 0.0000134442, validation loss: 0.0000080026
# Epoch 286: train loss: 0.0000133296, validation loss: 0.0000086941
# Epoch 287: train loss: 0.0000132736, validation loss: 0.0000067508
# Epoch 288: train loss: 0.0000134379, validation loss: 0.0000136264
# Epoch 289: train loss: 0.0000132815, validation loss: 0.0000088056
# Epoch 290: train loss: 0.0000130994, validation loss: 0.0000168063
# Epoch 291: train loss: 0.0000133303, validation loss: 0.0000067479
# Epoch 292: train loss: 0.0000130922, validation loss: 0.0000067205
# Epoch 293: train loss: 0.0000129758, validation loss: 0.0000165965
# Epoch 294: train loss: 0.0000132998, validation loss: 0.0000112065
# Epoch 295: train loss: 0.0000132104, validation loss: 0.0000281209
# Epoch 296: train loss: 0.0000131365, validation loss: 0.0000089050
# Epoch 297: train loss: 0.0000129036, validation loss: 0.0000130572
# Epoch 298: train loss: 0.0000131557, validation loss: 0.0000078262
# Epoch 299: train loss: 0.0000132308, validation loss: 0.0000089542
# Epoch 300: train loss: 0.0000129122, validation loss: 0.0000107785
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Learned Model Parameters

# %% [markdown]
# ## Bilinear Model Parameters

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (23, 23) (23, 23) (2, 23)

# %% [markdown]
# ## Lifting function

# %% [markdown]
# # Testing

# %% [markdown]
# ## Parameters

# %%
# test data parameters
num_snaps_test = 2000 # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)
num_traj_test = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ## Testing Data

# %%
x_changed_test, x_unchanged_test, u_test = dynamics_duff(dt, num_traj_test, num_snaps_test,num_states, num_inputs, dyn_pars)
print(model_koop_dnn.test_loss(x_unchanged_test,u_test = u_test))
# Out:
# tensor(5.9639e-06)

# %%
x_unchanged_test.shape
# Out:
# (1, 2001, 2)

# %%
# Use the preprocessing if available
X_unchanged,_ = model_koop_dnn.net.process(x_unchanged_test,data_u = u_test)
X_changed,_ = model_koop_dnn.net.process(x_changed_test,data_u = u_test)

# %%
X_changed.shape
# Out:
# (2000, 5)

# %%
# flatten vector
x_unchanged = X_unchanged[:, :num_states]
u = X_unchanged[:, num_states:num_states+num_inputs]
x_unchanged_prime = X_unchanged[:,num_states+num_inputs:]

x_changed = X_changed[:, :num_states]
x_changed_prime = X_changed[:,num_states+num_inputs:]

x_changed_dot = (x_changed_prime-x_changed)/dt
print(x_changed.shape, u.shape, x_changed_prime.shape)
# Out:
# (2000, 2) (2000, 1) (2000, 2)

# %% [markdown]
# # Lifting of states

# %%
# initialize states
# initialize the matricies
z_unchanged = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_unchanged_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values

# %%
# actual lift
z_unchanged[0,:] = lift(x_unchanged[0,:],model_koop_dnn, net_params)
x_unchanged_est[0,:] = x_unchanged[0,:]

# %% [markdown]
# # Time Evolution

# %%
for i in range(num_snaps_test):
  #bilinear
    z_unchanged[i+1,:] = np.matmul(z_unchanged[i,:],A.T)+np.matmul(np.kron(u[i,:],z_unchanged[i,:]),B.T)
    x_unchanged_est[i+1,:] = np.matmul(z_unchanged[i+1,:],C.T)

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lifting performance

# %%
plt.figure()
plt.plot(T_test[:-1], x_unchanged[:,0],label ='Test unchanged data')
plt.plot(T_test, x_unchanged_est[:,0],label = 'estimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ### Error Evolution

# %%
error_model = np.linalg.norm((x_unchanged_est[:-1,:]-x_unchanged[:,:]),axis=1)
error_dynamics_no_adapt = np.linalg.norm((x_changed[:,:]-x_unchanged[:,:]),axis=1)

# %%
plt.figure()
plt.plot(T_test[:-1],error_model)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Model error evolution')
plt.show()

# %% [markdown]
# ## Deviation from Actual Dynamics

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data (changed dynamics)')
plt.plot(T_test[:-1],x_unchanged[:,0],label ='Test data (unchanged dynamics)')
plt.plot(T_test,x_unchanged_est[:,0],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data (changed model)')
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data (unchanged model)')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data (changed dyn)')
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data (unchanged dyn)')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],error_dynamics_no_adapt)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Dynamics error evolution')
plt.show()

# %% [markdown]
# # Adaptation

# %% [markdown]
# ## Data Preprocessing

# %%
# initialize state matricies
z_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
z_changed = np.empty((n_obs,num_snaps_test)).T #actual lifted state
del_z_prime = np.empty((n_obs,num_snaps_test)).T
zu_unchanged = np.empty((n_obs*num_inputs,num_snaps_test)).T
x_adap_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values
del_A_norm = np.zeros((num_snaps_test,1))
del_B_norm = np.zeros((num_snaps_test,1))
# initialize
z_adap[0,:] = z_unchanged[0,:]
zu_unchanged[0,:] = np.kron(u[0,:],z_unchanged[0,:])
x_adap_est[0,:] = x_unchanged[0,:]

#
adap_window = 2 #hyperparameter

# %% [markdown]
# # Adaptive Time evolution

# %%
adapt_net_params = {}
adapt_net_params['state_dim'] = num_states
adapt_net_params['ctrl_dim'] = num_inputs
adapt_net_params['lift_dim'] = 20
adapt_net_params['optimizer'] = 'adam'
adapt_net_params['lr'] = 2e-4 # 5e-4
adapt_net_params['epochs'] = 5
adapt_net_params['batch_size'] = adap_window
adapt_net_params['l2_reg'] = 0.0
adapt_net_params['l1_reg'] = 2e-3
adapt_net_params['first_obs_const'] = net_params["first_obs_const"]
adapt_net_params['override_C'] = net_params["override_C"] # this makes the state a part of lifted state
adapt_net_params['warm_start'] = False



del_A = np.zeros_like(A)
del_B = np.zeros_like(B)

adapt_net_params['del_A_prev'] = del_A
adapt_net_params['del_B_prev'] = del_B
for i in range(num_snaps_test):
  # incorrect dynamics
    zu_unchanged[i,:] = np.kron(u[i,:],z_adap[i,:])
    # z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T + del_A.T)+np.matmul(zu_unchanged[i,:],B.T + del_B.T)
    z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T)+np.matmul(zu_unchanged[i,:],B.T)
    
    z_changed[i,:] = lift(x_changed[i,:],model_koop_dnn, net_params)
    
    del_z_prime[i,:] = z_changed[i,:] - z_unchanged[i,:]
    if i < adap_window + 1 :
        del_A = np.zeros_like(A)
        del_B = np.zeros_like(B)
    else:
        del_Z_prime = del_z_prime[i-adap_window:i,:].T
        Z_unchanged = z_unchanged[i-(adap_window+1):i-1].T
        ZU_unchanged = zu_unchanged[i-(adap_window+1):i-1].T

        #invoke neural net for adapation
        adapt_network = AdaptNet(adapt_net_params)
        adapt_network.model_pipeline(Z_unchanged, ZU_unchanged, del_Z_prime, print_epoch = True)

        del_A, del_B = adapt_network.get_del_matrices()

    del_A_norm[i] = np.linalg.norm(del_A)
    del_B_norm[i] = np.linalg.norm(del_B)
    
    # if del_B_norm[i] < np.linalg.norm(B):
    #     B_factor = adap_factor
    # else:
    #     B_factor = adap_factor*np.linalg.norm(B)/del_B_norm[i]
    #
    # if del_A_norm[i] < np.linalg.norm(A):
    #     A_factor = adap_factor
    # else:
    #     A_factor = adap_factor*np.linalg.norm(A)/del_A_norm[i]
    #
    # del_A = A_factor*del_A
    # del_B = B_factor*del_B
    adapt_net_params['del_A_prev'] = del_A
    adapt_net_params['del_B_prev'] = del_B
    # adapted model
    z_adap[i+1,:] = np.matmul(z_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_adap[i,:]), B + del_B.T )
    x_adap_est[i+1,:] = np.matmul(z_adap[i+1,:],C.T)

# %%
A.T.shape, del_A.shape
# Out:
# ((23, 23), (23, 23))

# %% [markdown]
# # Performance Plotting

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,0],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,0],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.jpg')

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,1],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.jpg')

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(x_adap_est[:,0],x_adap_est[:,1],label = 'estimated (adapt)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.jpg')

# %% [markdown]
# # Error Comparisons

# %%
error_dynamics_adap = np.linalg.norm((x_adap_est[:-1,:]-x_changed[:,:]), axis=1)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in Adaptive Model")
axs[1].set_title("Error in Non-Adaptive Model")

axs[0].set(xlabel = 't', ylabel = 'error')
axs[1].set(xlabel = 't', ylabel = 'error')


axs[0].plot(T_test[:-1],error_dynamics_adap)

axs[1].plot(T_test[:-1],error_dynamics_no_adapt)

plt.savefig('adap_error_comp.jpg')

# %% [markdown]
# ## Norm evolutions

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
np.linalg.norm(A)
# Out:
# 4.798268

# %%
np.linalg.norm(A)
# Out:
# 4.798268

# %%
np.linalg.norm(B)
# Out:
# 0.011357097

# %%
np.linalg.norm(B)
# Out:
# 0.011357097

# %% [markdown]
# ## Post Adaptive Learning

# %%
z_post_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_post_adap_est = np.zeros((num_states,num_snaps_test+1)).T 
x_post_adap_est[0,:] = x_unchanged[0,:]
z_post_adap[0,:] = z_unchanged[0,:]

# %%
for i in range(num_snaps_test):
    z_post_adap[i+1,:] = np.matmul(z_post_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_post_adap[i,:]), B + del_B.T )
    x_post_adap_est[i+1,:] = np.matmul(z_post_adap[i+1,:],C.T)

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,0],label ='estimated (no adapt)')
plt.plot(T_test,x_post_adap_est[:,0],label = 'esimated (post_adapt)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.jpg')

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(T_test,x_post_adap_est[:,1],label = 'esimated (post_adapt)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.jpg')

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(x_adap_est[:,0],x_post_adap_est[:,1],label = 'estimated (post_adapt)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.jpg')
