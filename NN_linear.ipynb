# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

from core.koopman_core_linear import KoopDNN,KoopmanNet,KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from dynamics.duffing import dynamics_duff
from dynamics.Vanpol import dynamics_vanpol

from core.adapt_net import AdaptNet

# %%
# Base Parameters
dt = 0.01 #time step
num_snaps = 500 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 200 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 2 # no. of states
num_inputs = 1 # no. of inputs

# %%
# Oscillator parameters
dyn_pars = {}

dyn_pars['a'] = 1
dyn_pars['b'] = 4
dyn_pars['c'] = 0.5
dyn_pars['d'] = 0.5

dyn_pars['del_a'] = 3
dyn_pars['del_b'] = 8
dyn_pars['del_c'] = 5
dyn_pars['del_d'] = 3
dyn_pars['delay'] = False
dyn_pars['delay_time'] = 5
dyn_pars['cont_unc_type'] = 'sinusoidal'

# %%
X_changed, X_unchanged, U = dynamics_duff(dt, num_traj, num_snaps, num_states, num_inputs, dyn_pars)

print(X_changed.shape, U.shape)
# Out:
# (250, 501, 2) (250, 500, 1)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X_changed)))))
print(sum(sum(sum(np.isnan(X_unchanged)))))
# Out:
# 0
# 0

# %%
l2_diff = np.linalg.norm(X_changed-X_unchanged)/((X_changed.size)**(1/2))
print('l2_diff = ', l2_diff)
# Out:
# l2_diff =  0.28347792359136054

# %%
change_in_dym = np.linalg.norm((X_changed-X_unchanged)/X_changed)/X_changed.size
print('fraction of change in dynamics = ', change_in_dym)
# Out:
# fraction of change in dynamics =  48.116121882906086

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Phase plot for unchanged dynamics")
axs[1].set_title("Phase plot for changed dynamics")

axs[0].set(xlabel = 'x1', ylabel = 'x2')
axs[1].set(xlabel = 'x1', ylabel = 'x2')

for i in range(num_traj):
    axs[0].plot(X_unchanged[i,:,0], X_unchanged[i,:,1])
    axs[1].plot(X_changed[i,:,0], X_changed[i,:,1])
plt.savefig('phase_plot_duffing.jpg')

# %%
plt.figure()

plt.title('Comparison of Phase plot')
plt.plot(X_unchanged[4,:,0], X_unchanged[4,:,1], label = 'unchanged')
plt.plot(X_changed[4,:,0], X_changed[4,:,1], label = 'changed')

plt.legend()
plt.savefig('phase_plot_duffing_single_traj.jpg')
plt.show()

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in position")
axs[1].set_title("Error in velocity")

axs[0].set(xlabel = 't', ylabel = 'x1')
axs[1].set(xlabel = 't', ylabel = 'x2')


axs[0].plot(T, X_unchanged[4,:,0], label = 'unchanged')
axs[0].plot(T, X_changed[4,:,0], label = 'changed')
axs[0].legend()

axs[1].plot(T, X_unchanged[4,:,1], label = 'unchanged')
axs[1].plot(T, X_changed[4,:,1], label = 'changed')
axs[1].legend()

plt.savefig('vel_pos_err_duffing_single_traj.jpg')

# %%
# split training and vaidation datasets
xs_train, us_train = X_unchanged[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X_unchanged[num_train:,:,:],U[num_train:,:,:]

# %% [markdown]
# ***Koopman bilinear Models***

# %%
# auto encoder parameters

net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 2e-4 # 5e-4
net_params['epochs'] = 300
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'duff_linear_0_01.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'duff_0_01.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 0.4665958881, validation loss: 0.1342228898
# Epoch   2: train loss: 0.1268614978, validation loss: 0.1145221375
# Epoch   3: train loss: 0.1122266948, validation loss: 0.1033029479
# Epoch   4: train loss: 0.1021619812, validation loss: 0.0945857779
# Epoch   5: train loss: 0.0936371312, validation loss: 0.0865890628
# Epoch   6: train loss: 0.0845930502, validation loss: 0.0767443781
# Epoch   7: train loss: 0.0731161460, validation loss: 0.0636078991
# Epoch   8: train loss: 0.0578137562, validation loss: 0.0467106095
# Epoch   9: train loss: 0.0389015079, validation loss: 0.0271865743
# Epoch  10: train loss: 0.0200568493, validation loss: 0.0123588552
# Epoch  11: train loss: 0.0098234080, validation loss: 0.0072122463
# Epoch  12: train loss: 0.0064235348, validation loss: 0.0051928251
# Epoch  13: train loss: 0.0047477442, validation loss: 0.0039509603
# Epoch  14: train loss: 0.0036657988, validation loss: 0.0031431839
# Epoch  15: train loss: 0.0029967183, validation loss: 0.0026245658
# Epoch  16: train loss: 0.0025921620, validation loss: 0.0023558062
# Epoch  17: train loss: 0.0023194165, validation loss: 0.0021038355
# Epoch  18: train loss: 0.0021137849, validation loss: 0.0019503494
# Epoch  19: train loss: 0.0019481706, validation loss: 0.0018266726
# Epoch  20: train loss: 0.0017995149, validation loss: 0.0016543559
# Epoch  21: train loss: 0.0016687961, validation loss: 0.0015630419
# Epoch  22: train loss: 0.0015490561, validation loss: 0.0014352204
# Epoch  23: train loss: 0.0014416693, validation loss: 0.0013414970
# Epoch  24: train loss: 0.0013466653, validation loss: 0.0012397550
# Epoch  25: train loss: 0.0012629071, validation loss: 0.0011650970
# Epoch  26: train loss: 0.0011857939, validation loss: 0.0011163836
# Epoch  27: train loss: 0.0011179313, validation loss: 0.0010478733
# Epoch  28: train loss: 0.0010549164, validation loss: 0.0009772417
# Epoch  29: train loss: 0.0009959062, validation loss: 0.0009292662
# Epoch  30: train loss: 0.0009450089, validation loss: 0.0008743417
# Epoch  31: train loss: 0.0008964904, validation loss: 0.0008391491
# Epoch  32: train loss: 0.0008513992, validation loss: 0.0007935502
# Epoch  33: train loss: 0.0008094103, validation loss: 0.0007520022
# Epoch  34: train loss: 0.0007698895, validation loss: 0.0007249393
# Epoch  35: train loss: 0.0007336179, validation loss: 0.0006873171
# Epoch  36: train loss: 0.0006993762, validation loss: 0.0006559401
# Epoch  37: train loss: 0.0006664039, validation loss: 0.0006233257
# Epoch  38: train loss: 0.0006363795, validation loss: 0.0005941042
# Epoch  39: train loss: 0.0006077187, validation loss: 0.0005631647
# Epoch  40: train loss: 0.0005793144, validation loss: 0.0005386345
# Epoch  41: train loss: 0.0005538401, validation loss: 0.0005293807
# Epoch  42: train loss: 0.0005331934, validation loss: 0.0004901189
# Epoch  43: train loss: 0.0005052940, validation loss: 0.0004679113
# Epoch  44: train loss: 0.0004824406, validation loss: 0.0004499492
# Epoch  45: train loss: 0.0004628101, validation loss: 0.0004416693
# Epoch  46: train loss: 0.0004404345, validation loss: 0.0004098066
# Epoch  47: train loss: 0.0004227572, validation loss: 0.0004011796
# Epoch  48: train loss: 0.0004008881, validation loss: 0.0003701064
# Epoch  49: train loss: 0.0003836175, validation loss: 0.0003519260
# Epoch  50: train loss: 0.0003644004, validation loss: 0.0003429237
# Epoch  51: train loss: 0.0003456770, validation loss: 0.0003177574
# Epoch  52: train loss: 0.0003293770, validation loss: 0.0003034867
# Epoch  53: train loss: 0.0003115511, validation loss: 0.0002922438
# Epoch  54: train loss: 0.0002962353, validation loss: 0.0002722255
# Epoch  55: train loss: 0.0002803621, validation loss: 0.0002574362
# Epoch  56: train loss: 0.0002652268, validation loss: 0.0002439269
# Epoch  57: train loss: 0.0002508077, validation loss: 0.0002335702
# Epoch  58: train loss: 0.0002381415, validation loss: 0.0002243620
# Epoch  59: train loss: 0.0002237976, validation loss: 0.0002017101
# Epoch  60: train loss: 0.0002122634, validation loss: 0.0001972850
# Epoch  61: train loss: 0.0002000612, validation loss: 0.0001812928
# Epoch  62: train loss: 0.0001902902, validation loss: 0.0001724897
# Epoch  63: train loss: 0.0001796657, validation loss: 0.0001782596
# Epoch  64: train loss: 0.0001732465, validation loss: 0.0001547010
# Epoch  65: train loss: 0.0001625927, validation loss: 0.0001607453
# Epoch  66: train loss: 0.0001559239, validation loss: 0.0001405765
# Epoch  67: train loss: 0.0001489416, validation loss: 0.0001337683
# Epoch  68: train loss: 0.0001415139, validation loss: 0.0001396429
# Epoch  69: train loss: 0.0001363030, validation loss: 0.0001263704
# Epoch  70: train loss: 0.0001318373, validation loss: 0.0001253322
# Epoch  71: train loss: 0.0001252712, validation loss: 0.0001143364
# Epoch  72: train loss: 0.0001215317, validation loss: 0.0001147289
# Epoch  73: train loss: 0.0001163970, validation loss: 0.0001071084
# Epoch  74: train loss: 0.0001133947, validation loss: 0.0001019624
# Epoch  75: train loss: 0.0001101499, validation loss: 0.0001031879
# Epoch  76: train loss: 0.0001053450, validation loss: 0.0000956989
# Epoch  77: train loss: 0.0001022912, validation loss: 0.0000930933
# Epoch  78: train loss: 0.0000986332, validation loss: 0.0000907177
# Epoch  79: train loss: 0.0000960395, validation loss: 0.0000892232
# Epoch  80: train loss: 0.0000939503, validation loss: 0.0000838188
# Epoch  81: train loss: 0.0000906232, validation loss: 0.0000900106
# Epoch  82: train loss: 0.0000880287, validation loss: 0.0000793663
# Epoch  83: train loss: 0.0000858167, validation loss: 0.0000789261
# Epoch  84: train loss: 0.0000837917, validation loss: 0.0000791855
# Epoch  85: train loss: 0.0000809575, validation loss: 0.0000733748
# Epoch  86: train loss: 0.0000788064, validation loss: 0.0000719614
# Epoch  87: train loss: 0.0000776357, validation loss: 0.0000695818
# Epoch  88: train loss: 0.0000754022, validation loss: 0.0000689763
# Epoch  89: train loss: 0.0000733948, validation loss: 0.0000675444
# Epoch  90: train loss: 0.0000713693, validation loss: 0.0000644005
# Epoch  91: train loss: 0.0000702702, validation loss: 0.0000618511
# Epoch  92: train loss: 0.0000684767, validation loss: 0.0000653668
# Epoch  93: train loss: 0.0000665739, validation loss: 0.0000596644
# Epoch  94: train loss: 0.0000660319, validation loss: 0.0000609891
# Epoch  95: train loss: 0.0000641977, validation loss: 0.0000570482
# Epoch  96: train loss: 0.0000619682, validation loss: 0.0000622774
# Epoch  97: train loss: 0.0000609258, validation loss: 0.0000572889
# Epoch  98: train loss: 0.0000598735, validation loss: 0.0000743994
# Epoch  99: train loss: 0.0000588824, validation loss: 0.0000558492
# Epoch 100: train loss: 0.0000576639, validation loss: 0.0000539934
# Epoch 101: train loss: 0.0000564418, validation loss: 0.0000642077
# Epoch 102: train loss: 0.0000551327, validation loss: 0.0000488258
# Epoch 103: train loss: 0.0000542299, validation loss: 0.0000469353
# Epoch 104: train loss: 0.0000535475, validation loss: 0.0000473006
# Epoch 105: train loss: 0.0000527271, validation loss: 0.0000458973
# Epoch 106: train loss: 0.0000505873, validation loss: 0.0000442144
# Epoch 107: train loss: 0.0000507685, validation loss: 0.0000439009
# Epoch 108: train loss: 0.0000492418, validation loss: 0.0000455808
# Epoch 109: train loss: 0.0000485890, validation loss: 0.0000421014
# Epoch 110: train loss: 0.0000479525, validation loss: 0.0000502717
# Epoch 111: train loss: 0.0000467728, validation loss: 0.0000454902
# Epoch 112: train loss: 0.0000462955, validation loss: 0.0000426911
# Epoch 113: train loss: 0.0000455327, validation loss: 0.0000400508
# Epoch 114: train loss: 0.0000448433, validation loss: 0.0000391905
# Epoch 115: train loss: 0.0000433545, validation loss: 0.0000376672
# Epoch 116: train loss: 0.0000426797, validation loss: 0.0000377524
# Epoch 117: train loss: 0.0000429807, validation loss: 0.0000359977
# Epoch 118: train loss: 0.0000414441, validation loss: 0.0000530033
# Epoch 119: train loss: 0.0000409505, validation loss: 0.0000422841
# Epoch 120: train loss: 0.0000402977, validation loss: 0.0000341849
# Epoch 121: train loss: 0.0000398634, validation loss: 0.0000388030
# Epoch 122: train loss: 0.0000391220, validation loss: 0.0000329004
# Epoch 123: train loss: 0.0000385630, validation loss: 0.0000324289
# Epoch 124: train loss: 0.0000386202, validation loss: 0.0000342616
# Epoch 125: train loss: 0.0000364541, validation loss: 0.0000313452
# Epoch 126: train loss: 0.0000370660, validation loss: 0.0000318569
# Epoch 127: train loss: 0.0000360789, validation loss: 0.0000310708
# Epoch 128: train loss: 0.0000357424, validation loss: 0.0000508454
# Epoch 129: train loss: 0.0000354143, validation loss: 0.0000308589
# Epoch 130: train loss: 0.0000350439, validation loss: 0.0000368187
# Epoch 131: train loss: 0.0000346169, validation loss: 0.0000283206
# Epoch 132: train loss: 0.0000332785, validation loss: 0.0000280652
# Epoch 133: train loss: 0.0000334896, validation loss: 0.0000301741
# Epoch 134: train loss: 0.0000334897, validation loss: 0.0000274131
# Epoch 135: train loss: 0.0000325677, validation loss: 0.0000288902
# Epoch 136: train loss: 0.0000314161, validation loss: 0.0000293244
# Epoch 137: train loss: 0.0000314931, validation loss: 0.0000265171
# Epoch 138: train loss: 0.0000313317, validation loss: 0.0000258048
# Epoch 139: train loss: 0.0000307762, validation loss: 0.0000254040
# Epoch 140: train loss: 0.0000301619, validation loss: 0.0000352855
# Epoch 141: train loss: 0.0000302370, validation loss: 0.0000354873
# Epoch 142: train loss: 0.0000298545, validation loss: 0.0000239282
# Epoch 143: train loss: 0.0000287081, validation loss: 0.0000274272
# Epoch 144: train loss: 0.0000291987, validation loss: 0.0000233871
# Epoch 145: train loss: 0.0000280137, validation loss: 0.0000236137
# Epoch 146: train loss: 0.0000280785, validation loss: 0.0000231423
# Epoch 147: train loss: 0.0000281569, validation loss: 0.0000258327
# Epoch 148: train loss: 0.0000273415, validation loss: 0.0000259565
# Epoch 149: train loss: 0.0000266272, validation loss: 0.0000225021
# Epoch 150: train loss: 0.0000270947, validation loss: 0.0000227070
# Epoch 151: train loss: 0.0000264323, validation loss: 0.0000398230
# Epoch 152: train loss: 0.0000260634, validation loss: 0.0000218212
# Epoch 153: train loss: 0.0000262271, validation loss: 0.0000211212
# Epoch 154: train loss: 0.0000254843, validation loss: 0.0000212402
# Epoch 155: train loss: 0.0000254351, validation loss: 0.0000200317
# Epoch 156: train loss: 0.0000248103, validation loss: 0.0000458490
# Epoch 157: train loss: 0.0000250839, validation loss: 0.0000285026
# Epoch 158: train loss: 0.0000245267, validation loss: 0.0000206206
# Epoch 159: train loss: 0.0000243645, validation loss: 0.0000345411
# Epoch 160: train loss: 0.0000239442, validation loss: 0.0000192182
# Epoch 161: train loss: 0.0000238085, validation loss: 0.0000201871
# Epoch 162: train loss: 0.0000229123, validation loss: 0.0000382326
# Epoch 163: train loss: 0.0000233365, validation loss: 0.0000211623
# Epoch 164: train loss: 0.0000227857, validation loss: 0.0000189364
# Epoch 165: train loss: 0.0000226783, validation loss: 0.0000192934
# Epoch 166: train loss: 0.0000225649, validation loss: 0.0000170065
# Epoch 167: train loss: 0.0000220715, validation loss: 0.0000206333
# Epoch 168: train loss: 0.0000217903, validation loss: 0.0000288169
# Epoch 169: train loss: 0.0000222092, validation loss: 0.0000187964
# Epoch 170: train loss: 0.0000213525, validation loss: 0.0000200972
# Epoch 171: train loss: 0.0000208960, validation loss: 0.0000163799
# Epoch 172: train loss: 0.0000218484, validation loss: 0.0000164372
# Epoch 173: train loss: 0.0000205331, validation loss: 0.0000178081
# Epoch 174: train loss: 0.0000208800, validation loss: 0.0000173628
# Epoch 175: train loss: 0.0000203257, validation loss: 0.0000157843
# Epoch 176: train loss: 0.0000209081, validation loss: 0.0000166324
# Epoch 177: train loss: 0.0000194914, validation loss: 0.0000323929
# Epoch 178: train loss: 0.0000197581, validation loss: 0.0000155144
# Epoch 179: train loss: 0.0000195725, validation loss: 0.0000153227
# Epoch 180: train loss: 0.0000202581, validation loss: 0.0000292690
# Epoch 181: train loss: 0.0000190331, validation loss: 0.0000147305
# Epoch 182: train loss: 0.0000197094, validation loss: 0.0000139574
# Epoch 183: train loss: 0.0000187405, validation loss: 0.0000141945
# Epoch 184: train loss: 0.0000189027, validation loss: 0.0000164959
# Epoch 185: train loss: 0.0000192324, validation loss: 0.0000208809
# Epoch 186: train loss: 0.0000179608, validation loss: 0.0000135480
# Epoch 187: train loss: 0.0000185238, validation loss: 0.0000193853
# Epoch 188: train loss: 0.0000178179, validation loss: 0.0000146553
# Epoch 189: train loss: 0.0000185802, validation loss: 0.0000196149
# Epoch 190: train loss: 0.0000175735, validation loss: 0.0000271897
# Epoch 191: train loss: 0.0000178538, validation loss: 0.0000131860
# Epoch 192: train loss: 0.0000175099, validation loss: 0.0000251232
# Epoch 193: train loss: 0.0000186112, validation loss: 0.0000172683
# Epoch 194: train loss: 0.0000164049, validation loss: 0.0000122211
# Epoch 195: train loss: 0.0000165900, validation loss: 0.0000124238
# Epoch 196: train loss: 0.0000177591, validation loss: 0.0000228085
# Epoch 197: train loss: 0.0000160493, validation loss: 0.0000173217
# Epoch 198: train loss: 0.0000169028, validation loss: 0.0000125330
# Epoch 199: train loss: 0.0000167277, validation loss: 0.0000138452
# Epoch 200: train loss: 0.0000165407, validation loss: 0.0000113618
# Epoch 201: train loss: 0.0000163617, validation loss: 0.0000148261
# Epoch 202: train loss: 0.0000163502, validation loss: 0.0000139100
# Epoch 203: train loss: 0.0000165508, validation loss: 0.0000145840
# Epoch 204: train loss: 0.0000155169, validation loss: 0.0000127897
# Epoch 205: train loss: 0.0000158845, validation loss: 0.0000113666
# Epoch 206: train loss: 0.0000163609, validation loss: 0.0000130292
# Epoch 207: train loss: 0.0000146175, validation loss: 0.0000109588
# Epoch 208: train loss: 0.0000160566, validation loss: 0.0000139864
# Epoch 209: train loss: 0.0000153580, validation loss: 0.0000171290
# Epoch 210: train loss: 0.0000147962, validation loss: 0.0000123086
# Epoch 211: train loss: 0.0000157041, validation loss: 0.0000114661
# Epoch 212: train loss: 0.0000147827, validation loss: 0.0000114933
# Epoch 213: train loss: 0.0000148521, validation loss: 0.0000126393
# Epoch 214: train loss: 0.0000149903, validation loss: 0.0000115214
# Epoch 215: train loss: 0.0000145215, validation loss: 0.0000107516
# Epoch 216: train loss: 0.0000148682, validation loss: 0.0000100212
# Epoch 217: train loss: 0.0000142885, validation loss: 0.0000184721
# Epoch 218: train loss: 0.0000150250, validation loss: 0.0000102935
# Epoch 219: train loss: 0.0000140553, validation loss: 0.0000107985
# Epoch 220: train loss: 0.0000148798, validation loss: 0.0000100397
# Epoch 221: train loss: 0.0000137912, validation loss: 0.0000109324
# Epoch 222: train loss: 0.0000139820, validation loss: 0.0000121301
# Epoch 223: train loss: 0.0000143578, validation loss: 0.0000134964
# Epoch 224: train loss: 0.0000133628, validation loss: 0.0000641514
# Epoch 225: train loss: 0.0000140194, validation loss: 0.0000093737
# Epoch 226: train loss: 0.0000137992, validation loss: 0.0000326862
# Epoch 227: train loss: 0.0000135834, validation loss: 0.0000091552
# Epoch 228: train loss: 0.0000140580, validation loss: 0.0000263549
# Epoch 229: train loss: 0.0000136337, validation loss: 0.0000122554
# Epoch 230: train loss: 0.0000134197, validation loss: 0.0000131243
# Epoch 231: train loss: 0.0000127941, validation loss: 0.0000086589
# Epoch 232: train loss: 0.0000131909, validation loss: 0.0000110102
# Epoch 233: train loss: 0.0000127295, validation loss: 0.0000307127
# Epoch 234: train loss: 0.0000132167, validation loss: 0.0000093591
# Epoch 235: train loss: 0.0000127951, validation loss: 0.0000095798
# Epoch 236: train loss: 0.0000131548, validation loss: 0.0000093924
# Epoch 237: train loss: 0.0000130798, validation loss: 0.0000296923
# Epoch 238: train loss: 0.0000122746, validation loss: 0.0000125944
# Epoch 239: train loss: 0.0000129249, validation loss: 0.0000149049
# Epoch 240: train loss: 0.0000123355, validation loss: 0.0000110343
# Epoch 241: train loss: 0.0000131446, validation loss: 0.0000114612
# Epoch 242: train loss: 0.0000121840, validation loss: 0.0000223780
# Epoch 243: train loss: 0.0000125233, validation loss: 0.0000105973
# Epoch 244: train loss: 0.0000120997, validation loss: 0.0000080773
# Epoch 245: train loss: 0.0000126287, validation loss: 0.0000101815
# Epoch 246: train loss: 0.0000124256, validation loss: 0.0000081347
# Epoch 247: train loss: 0.0000123054, validation loss: 0.0000076565
# Epoch 248: train loss: 0.0000116363, validation loss: 0.0000100320
# Epoch 249: train loss: 0.0000123521, validation loss: 0.0000325635
# Epoch 250: train loss: 0.0000114212, validation loss: 0.0000080712
# Epoch 251: train loss: 0.0000129336, validation loss: 0.0000131812
# Epoch 252: train loss: 0.0000119752, validation loss: 0.0000112506
# Epoch 253: train loss: 0.0000113702, validation loss: 0.0000159995
# Epoch 254: train loss: 0.0000118604, validation loss: 0.0000082093
# Epoch 255: train loss: 0.0000116874, validation loss: 0.0000077125
# Epoch 256: train loss: 0.0000113004, validation loss: 0.0000150937
# Epoch 257: train loss: 0.0000117140, validation loss: 0.0000127688
# Epoch 258: train loss: 0.0000114721, validation loss: 0.0000168127
# Epoch 259: train loss: 0.0000113873, validation loss: 0.0000073125
# Epoch 260: train loss: 0.0000114130, validation loss: 0.0000093245
# Epoch 261: train loss: 0.0000113492, validation loss: 0.0000074120
# Epoch 262: train loss: 0.0000114652, validation loss: 0.0000167598
# Epoch 263: train loss: 0.0000112066, validation loss: 0.0000066382
# Epoch 264: train loss: 0.0000116436, validation loss: 0.0000078176
# Epoch 265: train loss: 0.0000114649, validation loss: 0.0000071631
# Epoch 266: train loss: 0.0000114294, validation loss: 0.0000071201
# Epoch 267: train loss: 0.0000104487, validation loss: 0.0000067799
# Epoch 268: train loss: 0.0000112774, validation loss: 0.0000324118
# Epoch 269: train loss: 0.0000108797, validation loss: 0.0000063842
# Epoch 270: train loss: 0.0000111598, validation loss: 0.0000316773
# Epoch 271: train loss: 0.0000112128, validation loss: 0.0000080885
# Epoch 272: train loss: 0.0000102748, validation loss: 0.0000070040
# Epoch 273: train loss: 0.0000106958, validation loss: 0.0000063164
# Epoch 274: train loss: 0.0000113024, validation loss: 0.0000062258
# Epoch 275: train loss: 0.0000105911, validation loss: 0.0000085777
# Epoch 276: train loss: 0.0000108998, validation loss: 0.0000062906
# Epoch 277: train loss: 0.0000106547, validation loss: 0.0000066770
# Epoch 278: train loss: 0.0000100369, validation loss: 0.0000062758
# Epoch 279: train loss: 0.0000110652, validation loss: 0.0000073550
# Epoch 280: train loss: 0.0000103366, validation loss: 0.0000066650
# Epoch 281: train loss: 0.0000101281, validation loss: 0.0000090522
# Epoch 282: train loss: 0.0000110365, validation loss: 0.0000076553
# Epoch 283: train loss: 0.0000101322, validation loss: 0.0000130268
# Epoch 284: train loss: 0.0000104698, validation loss: 0.0000058580
# Epoch 285: train loss: 0.0000100313, validation loss: 0.0000060713
# Epoch 286: train loss: 0.0000100540, validation loss: 0.0000124659
# Epoch 287: train loss: 0.0000104401, validation loss: 0.0000073154
# Epoch 288: train loss: 0.0000099860, validation loss: 0.0000056575
# Epoch 289: train loss: 0.0000103125, validation loss: 0.0000056309
# Epoch 290: train loss: 0.0000113683, validation loss: 0.0000064148
# Epoch 291: train loss: 0.0000088739, validation loss: 0.0000150571
# Epoch 292: train loss: 0.0000103006, validation loss: 0.0000071399
# Epoch 293: train loss: 0.0000099419, validation loss: 0.0000076834
# Epoch 294: train loss: 0.0000096835, validation loss: 0.0000060857
# Epoch 295: train loss: 0.0000100676, validation loss: 0.0000195477
# Epoch 296: train loss: 0.0000101556, validation loss: 0.0000058865
# Epoch 297: train loss: 0.0000097756, validation loss: 0.0000087069
# Epoch 298: train loss: 0.0000100300, validation loss: 0.0000066376
# Epoch 299: train loss: 0.0000097515, validation loss: 0.0000061042
# Epoch 300: train loss: 0.0000095213, validation loss: 0.0000060067
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Learned Model Parameters

# %% [markdown]
# ## Bilinear Model Parameters

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (23, 23) (23, 1) (2, 23)

# %%
#check controllability

# %% [markdown]
# ## Lifting function

# %% [markdown]
# # Testing

# %% [markdown]
# ## Parameters

# %%
# test data parameters
num_snaps_test = 2000 # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)
num_traj_test = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ## Testing Data

# %%
x_changed_test, x_unchanged_test, u_test = dynamics_duff(dt, num_traj_test, num_snaps_test,num_states, num_inputs, dyn_pars)
print(model_koop_dnn.test_loss(x_unchanged_test,u_test = u_test))
# Out:
# tensor(0.0431)

# %%
x_unchanged_test.shape
# Out:
# (1, 2001, 2)

# %%
# Use the preprocessing if available
X_unchanged,_ = model_koop_dnn.net.process(x_unchanged_test,data_u = u_test)
X_changed,_ = model_koop_dnn.net.process(x_changed_test,data_u = u_test)

# %%
X_changed.shape
# Out:
# (2000, 5)

# %%
# flatten vector
x_unchanged = X_unchanged[:, :num_states]
u = X_unchanged[:, num_states:num_states+num_inputs]
x_unchanged_prime = X_unchanged[:,num_states+num_inputs:]

x_changed = X_changed[:, :num_states]
x_changed_prime = X_changed[:,num_states+num_inputs:]

x_changed_dot = (x_changed_prime-x_changed)/dt
print(x_changed.shape, u.shape, x_changed_prime.shape)
# Out:
# (2000, 2) (2000, 1) (2000, 2)

# %% [markdown]
# # Lifting of states

# %%
# initialize states
# initialize the matricies
z_unchanged = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_unchanged_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values

# %%
# actual lift
z_unchanged[0,:] = lift(x_unchanged[0,:],model_koop_dnn, net_params)
x_unchanged_est[0,:] = x_unchanged[0,:]

# %% [markdown]
# # Time Evolution

# %%
for i in range(num_snaps_test):
  #bilinear
    z_unchanged[i+1,:] = np.matmul(z_unchanged[i,:],A.T)+np.matmul(u[i,:],B.T)
    x_unchanged_est[i+1,:] = np.matmul(z_unchanged[i+1,:],C.T)

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lifting performance

# %%
plt.figure()
plt.plot(T_test[:-1], x_unchanged[:,0],label ='Test unchanged data')
plt.plot(T_test, x_unchanged_est[:,0],label = 'estimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ### Error Evolution

# %%
error_model = np.linalg.norm((x_unchanged_est[:-1,:]-x_unchanged[:,:]),axis=1)
error_dynamics_no_adapt = np.linalg.norm((x_changed[:,:]-x_unchanged[:,:]),axis=1)

# %%
plt.figure()
plt.plot(T_test[:-1],error_model)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Model error evolution')
plt.show()

# %% [markdown]
# ## Deviation from Actual Dynamics

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data (changed dynamics)')
plt.plot(T_test[:-1],x_unchanged[:,0],label ='Test data (unchanged dynamics)')
plt.plot(T_test,x_unchanged_est[:,0],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data (changed model)')
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data (unchanged model)')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data (changed dyn)')
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data (unchanged dyn)')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],error_dynamics_no_adapt)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Dynamics error evolution')
plt.show()

# %% [markdown]
# # Adaptation

# %% [markdown]
# ## Data Preprocessing

# %%
# initialize state matricies
z_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
z_changed = np.empty((n_obs,num_snaps_test)).T #actual lifted state
del_z_prime = np.empty((n_obs,num_snaps_test)).T
zu_unchanged = np.empty((n_obs*num_inputs,num_snaps_test)).T
x_adap_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values
del_A_norm = np.zeros((num_snaps_test,1))
del_B_norm = np.zeros((num_snaps_test,1))
# initialize
z_adap[0,:] = z_unchanged[0,:]
zu_unchanged[0,:] = np.kron(u[0,:],z_unchanged[0,:])
x_adap_est[0,:] = x_unchanged[0,:]

#
adap_window = 1 #hyperparameter

# %% [markdown]
# # Adaptive Time evolution

# %%
adapt_net_params = {}
adapt_net_params['state_dim'] = num_states
adapt_net_params['ctrl_dim'] = num_inputs
adapt_net_params['lift_dim'] = 20
adapt_net_params['optimizer'] = 'adam'
adapt_net_params['lr'] = 5e-4 # 5e-4
adapt_net_params['epochs'] = 8
adapt_net_params['batch_size'] = adap_window
adapt_net_params['l2_reg'] = 0.0
adapt_net_params['l1_reg'] = 1e-3
adapt_net_params['first_obs_const'] = net_params["first_obs_const"]
adapt_net_params['override_C'] = net_params["override_C"] # this makes the state a part of lifted state

del_A = np.zeros_like(A)
del_B = np.zeros_like(B)
for i in range(num_snaps_test):
  # incorrect dynamics
    zu_unchanged[i,:] = np.kron(u[i,:],z_adap[i,:])
    z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T + del_A.T)+np.matmul(zu_unchanged[i,:],B.T + del_B.T)
    # z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T)+np.matmul(zu_unchanged[i,:],B.T)
    
    z_changed[i,:] = lift(x_changed[i,:],model_koop_dnn, net_params)
    
    del_z_prime[i,:] = z_changed[i,:] - z_unchanged[i,:]
    if i < adap_window + 1 :
        del_A = np.zeros_like(A)
        del_B = np.zeros_like(B)
    else:
        del_Z_prime = del_z_prime[i-adap_window:i,:].T
        Z_unchanged = z_unchanged[i-(adap_window+1):i-1].T
        ZU_unchanged = zu_unchanged[i-(adap_window+1):i-1].T

        #invoke neural net for adapation
        adapt_network = AdaptNet(adapt_net_params)
        adapt_network.model_pipeline(Z_unchanged, ZU_unchanged, del_Z_prime, print_epoch = True)

        del_A, del_B = adapt_network.get_del_matrices()

    del_A_norm[i] = np.linalg.norm(del_A)
    del_B_norm[i] = np.linalg.norm(del_B)
    
    # adapted model
    z_adap[i+1,:] = np.matmul(z_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_adap[i,:]), B + del_B.T )
    x_adap_est[i+1,:] = np.matmul(z_adap[i+1,:],C.T)

# %%
A.T.shape, del_A.shape

# %% [markdown]
# # Performance Plotting

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,0],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,0],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.pdf')

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,1],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.pdf')

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(x_adap_est[:,0],x_adap_est[:,1],label = 'estimated (adapt)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.pdf')

# %% [markdown]
# # Error Comparisons

# %%
error_dynamics_adap = np.linalg.norm((x_adap_est[:-1,:]-x_changed[:,:]), axis=1)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in Adaptive Model")
axs[1].set_title("Error in Non-Adaptive Model")

axs[0].set(xlabel = 't', ylabel = 'error')
axs[1].set(xlabel = 't', ylabel = 'error')


axs[0].plot(T_test[:-1],error_dynamics_adap)

axs[1].plot(T_test[:-1],error_dynamics_no_adapt)

plt.savefig('adap_error_comp.pdf')

# %% [markdown]
# ## Norm evolutions

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
np.linalg.norm(A)
