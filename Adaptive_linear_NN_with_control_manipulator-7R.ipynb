# %%
# import libraries
import math
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch
import random
import time

# import Koopman Libraries
from core.koopman_core_linear import KoopDNN_linear, KoopmanNet_linear, KoopmanNetCtrl_linear
from sklearn import preprocessing
from core.util import fit_standardizer
from models.koop_model import model_matricies,lift

# Import Adaptive Koopman
from core.adapt_net_linear_test import AdaptNet_linear
import scipy.io

# Import Robot Dynamics
from dynamics.robot_selector import robot_selector
from dynamics.data_gen_robot import data_gen_robot_multi

# %% [markdown]
# ## Robot Generation

# %%
# robot_selcetion
robot_type = "3R"
modality = "3D"
robot_name = robot_type + "_" + modality

# %%
# robot pars
robot_pars = {}
robot_pars['m'] = 0.8
robot_pars['l'] = 1
robot_pars['I'] = (robot_pars['m']/(robot_pars['l']**2))*np.eye(3)/12
robot_pars['G'] = 1
robot_pars['B'] = 0
robot_pars['T'] = 0

# robot parameters changed
robot_pars_changed = {}
robot_pars_changed ['m'] = 0.1#0.1
robot_pars_changed ['l'] = 1 # 2
robot_pars_changed ['I'] = (robot_pars_changed['m']/(robot_pars_changed['l']**2))*np.eye(3)/12
robot_pars_changed ['G'] = 0
robot_pars_changed ['B'] = 0.5
robot_pars_changed ['T'] = 0.5
robot_pars_changed ['ext_torque'] = False
SNR_DB = 10
robot_pars_changed ['ext_torque_type'] = 'sinosoidal'
robot_pars_changed ['SN'] = (10**(SNR_DB/10))

# %%
# get robots
robot = robot_selector(robot_name,robot_pars)
robot_changed = robot_selector(robot_name,robot_pars_changed)

# %%
print(robot)
print(robot_changed)
# Out:
# DHRobot: 3R_3D, 3 joints (RRR), dynamics, standard DH parameters
# ┌────┬────┬────┬───────┐
# │θⱼ  │ dⱼ │ aⱼ │  ⍺ⱼ   │
# ├────┼────┼────┼───────┤
# │ q1 │  0 │  1 │  0.0° │
# │ q2 │  0 │  1 │ 90.0° │
# │ q3 │  0 │  1 │  0.0° │
# └────┴────┴────┴───────┘
#
# ┌─┬──┐
# └─┴──┘
#
# DHRobot: 3R_3D, 3 joints (RRR), dynamics, standard DH parameters
# ┌────┬────┬────┬───────┐
# │θⱼ  │ dⱼ │ aⱼ │  ⍺ⱼ   │
# ├────┼────┼────┼───────┤
# │ q1 │  0 │  1 │  0.0° │
# │ q2 │  0 │  1 │ 90.0° │
# │ q3 │  0 │  1 │  0.0° │
# └────┴────┴────┴───────┘
#
# ┌─┬──┐
# └─┴──┘

# %% [markdown]
# ## Data Generation

# %%
dt = 0.02 #time step
num_train = 100 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_snaps = 100 # no. of snapshots
controller = 'controller' # controller used or not for data generation
num_joints = robot.random_q().shape[0]
num_states = 2*robot.random_q().shape[0]
num_inputs = num_joints

if robot.name.__contains__("2D"):
    num_states_cart = 2
else:
    num_states_cart = 3
T = np.linspace(0,num_snaps*dt,num_snaps)

# %%
X_end_unchanged,X_unchanged, X_end_changed, X_changed, U = data_gen_robot_multi(dt,num_traj,num_snaps, robot, robot_changed, robot_pars_changed, controller)
print(X_changed.shape, U.shape)
# Out:
# (125, 100, 6) (125, 99, 3)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X_changed)))))
print(sum(sum(sum(np.isnan(X_unchanged)))))
# Out:
# 861
# 0

# %%
# change in dynamics
# l2 change
l2_diff = np.linalg.norm(X_changed-X_unchanged)/((X_changed.size)**(1/2))
print('l2_diff = ', l2_diff)

# fractional change
change_in_dym = np.linalg.norm((X_changed-X_unchanged)/X_changed)/X_changed.size
print('fraction of change in dynamics = ', change_in_dym)
# Out:
# l2_diff =  nan
# fraction of change in dynamics =  nan

# %%
# Overall data
plt.figure(figsize = (20,10))

for j in range(num_traj):
    for i in range(int(num_joints)):
        plt.subplot(num_joints,2,2*i+1)
        plt.xlabel("t")
        plt.ylabel("th"+str(i+1))
        plt.plot(T,X_unchanged[j,:,i])
        plt.subplot(num_joints,2,2*i+2)
        plt.xlabel("t")
        plt.ylabel("th_dot"+str(i+1))
        plt.plot(T,X_unchanged[j,:,num_joints+i])
plt.suptitle("Original Dynamics", fontsize=30)
# Out:
# Text(0.5, 0.98, 'Original Dynamics')

# %%
# Overall data
plt.figure(figsize = (20,10))

for j in range(num_traj):
    for i in range(int(num_joints)):
        plt.subplot(num_joints,2,2*i+1)
        plt.xlabel("t")
        plt.ylabel("th"+str(i+1))
        plt.plot(T,X_changed[j,:,i])
        plt.subplot(num_joints,2,2*i+2)
        plt.xlabel("t")
        plt.ylabel("th_dot"+str(i+1))
        plt.plot(T,X_changed[j,:,num_joints+i])
plt.suptitle("Changed Dynamics", fontsize=30)
# Out:
# Text(0.5, 0.98, 'Changed Dynamics')

# %%
plt.figure(figsize = (20,10))
for j in range(num_traj):
    for i in range(int(num_joints)):
        plt.subplot(num_joints,1,i+1)
        plt.xlabel("t")
        plt.ylabel("tau"+str(i+1))
        plt.plot(T[:-1],U[j,:,i])
plt.suptitle("Control Inputs", fontsize=30)
# Out:
# Text(0.5, 0.98, 'Control Inputs')

# %%
## difference in dynamics
plt.figure(figsize= (20,10))
j = random.randrange(0,num_traj)
for i in range(int(num_joints)):
    plt.subplot(num_joints,2,2*i+1)
    plt.xlabel("t")
    plt.ylabel("th"+str(i+1))
    plt.plot(T,X_unchanged[j,:,i], label = 'Original')
    plt.plot(T,X_changed[j,:,i], label = 'Changed')
    plt.legend()
    plt.subplot(num_joints,2,2*i+2)
    plt.xlabel("t")
    plt.ylabel("th_dot"+str(i+1))
    plt.plot(T,X_unchanged[j,:,num_joints+i], label = "Original")
    plt.plot(T,X_changed[j,:,num_joints+i], label = "Changed")   
    plt.legend()
plt.suptitle("Difference in Dynamics", fontsize=30)
# Out:
# Text(0.5, 0.98, 'Difference in Dynamics')

# %% [markdown]
# ## Learning Koopman Models

# %%
# split training and vaidation datasets
xs_train, us_train = X_unchanged[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X_unchanged[num_train:,:,:],U[num_train:,:,:]

# %%
# auto encoder parameters
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 10
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 300
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
# Koopman Model
train = True
file = 'saved_models/manipulators/linear/'+ robot_type + '/' + modality + '/Koop_arch.pth'
if train == True:
    net = KoopmanNetCtrl_linear(net_params)
    model_koop_dnn = KoopDNN_linear(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 25.4632358551, validation loss: 20.1839902878
# Epoch   2: train loss: 22.7539176941, validation loss: 18.3597519875
# Epoch   3: train loss: 20.1471633911, validation loss: 16.4099055290
# Epoch   4: train loss: 17.6275596619, validation loss: 14.0746325970
# Epoch   5: train loss: 15.2646512985, validation loss: 11.8904304981
# Epoch   6: train loss: 13.0659675598, validation loss: 10.0884829521
# Epoch   7: train loss: 10.8356790543, validation loss: 7.9873895645
# Epoch   8: train loss: 8.4140205383, validation loss: 5.7290712595
# Epoch   9: train loss: 6.0897803307, validation loss: 4.1586963415
# Epoch  10: train loss: 4.3073358536, validation loss: 3.1321887016
# Epoch  11: train loss: 3.2515842915, validation loss: 2.5492748380
# Epoch  12: train loss: 2.6827564240, validation loss: 2.1865469813
# Epoch  13: train loss: 2.3518581390, validation loss: 1.9408608437
# Epoch  14: train loss: 2.1171085835, validation loss: 1.7684687614
# Epoch  15: train loss: 1.9415694475, validation loss: 1.6476326346
# Epoch  16: train loss: 1.8073483706, validation loss: 1.5422041178
# Epoch  17: train loss: 1.6942183971, validation loss: 1.4631116629
# Epoch  18: train loss: 1.6102596521, validation loss: 1.4033250451
# Epoch  19: train loss: 1.5376442671, validation loss: 1.3540396333
# Epoch  20: train loss: 1.4800783396, validation loss: 1.3154511750
# Epoch  21: train loss: 1.4285461903, validation loss: 1.2808815181
# Epoch  22: train loss: 1.3861726522, validation loss: 1.2461079001
# Epoch  23: train loss: 1.3512139320, validation loss: 1.2237833619
# Epoch  24: train loss: 1.3215565681, validation loss: 1.1990410805
# Epoch  25: train loss: 1.2937442064, validation loss: 1.1811693966
# Epoch  26: train loss: 1.2702271938, validation loss: 1.1648196578
# Epoch  27: train loss: 1.2512118816, validation loss: 1.1496732831
# Epoch  28: train loss: 1.2315437794, validation loss: 1.1382618845
# Epoch  29: train loss: 1.2171071768, validation loss: 1.1271674216
# Epoch  30: train loss: 1.2035369873, validation loss: 1.1187851965
# Epoch  31: train loss: 1.1901206970, validation loss: 1.1057711422
# Epoch  32: train loss: 1.1749013662, validation loss: 1.0987440705
# Epoch  33: train loss: 1.1644666195, validation loss: 1.0889452517
# Epoch  34: train loss: 1.1555352211, validation loss: 1.0791703224
# Epoch  35: train loss: 1.1463381052, validation loss: 1.0718703866
# Epoch  36: train loss: 1.1380212307, validation loss: 1.0636966407
# Epoch  37: train loss: 1.1252971888, validation loss: 1.0579870522
# Epoch  38: train loss: 1.1209588051, validation loss: 1.0583449244
# Epoch  39: train loss: 1.1110051870, validation loss: 1.0407063961
# Epoch  40: train loss: 1.1012754440, validation loss: 1.0323517680
# Epoch  41: train loss: 1.0911580324, validation loss: 1.0260623157
# Epoch  42: train loss: 1.0839906931, validation loss: 1.0190425217
# Epoch  43: train loss: 1.0771105289, validation loss: 1.0113217592
# Epoch  44: train loss: 1.0680180788, validation loss: 1.0023619831
# Epoch  45: train loss: 1.0593435764, validation loss: 0.9968129933
# Epoch  46: train loss: 1.0500091314, validation loss: 0.9881378353
# Epoch  47: train loss: 1.0424777269, validation loss: 0.9817444861
# Epoch  48: train loss: 1.0351793766, validation loss: 0.9822305143
# Epoch  49: train loss: 1.0271060467, validation loss: 0.9669184029
# Epoch  50: train loss: 1.0195525885, validation loss: 0.9581390381
# Epoch  51: train loss: 1.0119608641, validation loss: 0.9531192839
# Epoch  52: train loss: 1.0020664930, validation loss: 0.9443544805
# Epoch  53: train loss: 0.9939423800, validation loss: 0.9367782176
# Epoch  54: train loss: 0.9857206941, validation loss: 0.9293222547
# Epoch  55: train loss: 0.9776585102, validation loss: 0.9214125156
# Epoch  56: train loss: 0.9702571034, validation loss: 0.9130936146
# Epoch  57: train loss: 0.9613313079, validation loss: 0.9089382648
# Epoch  58: train loss: 0.9536824226, validation loss: 0.8981712937
# Epoch  59: train loss: 0.9447117448, validation loss: 0.8939297318
# Epoch  60: train loss: 0.9362141490, validation loss: 0.8849406719
# Epoch  61: train loss: 0.9280328751, validation loss: 0.8766726851
# Epoch  62: train loss: 0.9190384150, validation loss: 0.8696054161
# Epoch  63: train loss: 0.9118052721, validation loss: 0.8617949545
# Epoch  64: train loss: 0.9032577276, validation loss: 0.8553172946
# Epoch  65: train loss: 0.8952546716, validation loss: 0.8475496113
# Epoch  66: train loss: 0.8864173889, validation loss: 0.8420322835
# Epoch  67: train loss: 0.8783265948, validation loss: 0.8331047952
# Epoch  68: train loss: 0.8715175986, validation loss: 0.8268947363
# Epoch  69: train loss: 0.8622927666, validation loss: 0.8162060201
# Epoch  70: train loss: 0.8547929525, validation loss: 0.8108717322
# Epoch  71: train loss: 0.8446841836, validation loss: 0.8021450579
# Epoch  72: train loss: 0.8368877769, validation loss: 0.7939716518
# Epoch  73: train loss: 0.8289209008, validation loss: 0.7864733458
# Epoch  74: train loss: 0.8198590875, validation loss: 0.7812630177
# Epoch  75: train loss: 0.8129151464, validation loss: 0.7704169214
# Epoch  76: train loss: 0.8028525114, validation loss: 0.7642216682
# Epoch  77: train loss: 0.7957228422, validation loss: 0.7580857217
# Epoch  78: train loss: 0.7867872715, validation loss: 0.7509656817
# Epoch  79: train loss: 0.7786187530, validation loss: 0.7419750780
# Epoch  80: train loss: 0.7693372965, validation loss: 0.7346538514
# Epoch  81: train loss: 0.7617732882, validation loss: 0.7263846427
# Epoch  82: train loss: 0.7528070807, validation loss: 0.7203523487
# Epoch  83: train loss: 0.7455162406, validation loss: 0.7152232409
# Epoch  84: train loss: 0.7371007800, validation loss: 0.7025683284
# Epoch  85: train loss: 0.7283917665, validation loss: 0.6986642063
# Epoch  86: train loss: 0.7201485038, validation loss: 0.6887944102
# Epoch  87: train loss: 0.7121286392, validation loss: 0.6836368799
# Epoch  88: train loss: 0.7032589316, validation loss: 0.6755822867
# Epoch  89: train loss: 0.6958655715, validation loss: 0.6680322409
# Epoch  90: train loss: 0.6891633272, validation loss: 0.6606038600
# Epoch  91: train loss: 0.6799849272, validation loss: 0.6535098612
# Epoch  92: train loss: 0.6722569466, validation loss: 0.6470329642
# Epoch  93: train loss: 0.6645002365, validation loss: 0.6405433506
# Epoch  94: train loss: 0.6570596695, validation loss: 0.6334607065
# Epoch  95: train loss: 0.6491433382, validation loss: 0.6248024642
# Epoch  96: train loss: 0.6413518786, validation loss: 0.6179673135
# Epoch  97: train loss: 0.6338117719, validation loss: 0.6122692466
# Epoch  98: train loss: 0.6266433597, validation loss: 0.6043321013
# Epoch  99: train loss: 0.6187577248, validation loss: 0.5981323272
# Epoch 100: train loss: 0.6110022068, validation loss: 0.5918571413
# Epoch 101: train loss: 0.6037254930, validation loss: 0.5853460133
# Epoch 102: train loss: 0.5965247750, validation loss: 0.5789476991
# Epoch 103: train loss: 0.5901362896, validation loss: 0.5723500192
# Epoch 104: train loss: 0.5834283233, validation loss: 0.5644968390
# Epoch 105: train loss: 0.5760157108, validation loss: 0.5600152940
# Epoch 106: train loss: 0.5696728826, validation loss: 0.5529818863
# Epoch 107: train loss: 0.5628756285, validation loss: 0.5474404484
# Epoch 108: train loss: 0.5561822653, validation loss: 0.5407461435
# Epoch 109: train loss: 0.5500118136, validation loss: 0.5352780521
# Epoch 110: train loss: 0.5443459749, validation loss: 0.5295194417
# Epoch 111: train loss: 0.5381717086, validation loss: 0.5249886185
# Epoch 112: train loss: 0.5321404338, validation loss: 0.5181338966
# Epoch 113: train loss: 0.5264087319, validation loss: 0.5110825419
# Epoch 114: train loss: 0.5200126767, validation loss: 0.5069622874
# Epoch 115: train loss: 0.5147425532, validation loss: 0.5025397956
# Epoch 116: train loss: 0.5093106031, validation loss: 0.4952213168
# Epoch 117: train loss: 0.5036867261, validation loss: 0.4908342957
# Epoch 118: train loss: 0.4977542758, validation loss: 0.4854848713
# Epoch 119: train loss: 0.4930441976, validation loss: 0.4804966867
# Epoch 120: train loss: 0.4883128405, validation loss: 0.4766109049
# Epoch 121: train loss: 0.4830015600, validation loss: 0.4701230377
# Epoch 122: train loss: 0.4773797691, validation loss: 0.4665929049
# Epoch 123: train loss: 0.4735541642, validation loss: 0.4617387742
# Epoch 124: train loss: 0.4686478972, validation loss: 0.4563454837
# Epoch 125: train loss: 0.4635951817, validation loss: 0.4533827960
# Epoch 126: train loss: 0.4588950276, validation loss: 0.4480641991
# Epoch 127: train loss: 0.4542605579, validation loss: 0.4434210539
# Epoch 128: train loss: 0.4498203099, validation loss: 0.4391185224
# Epoch 129: train loss: 0.4458809495, validation loss: 0.4343546420
# Epoch 130: train loss: 0.4408852458, validation loss: 0.4324612498
# Epoch 131: train loss: 0.4367549717, validation loss: 0.4264866501
# Epoch 132: train loss: 0.4329285622, validation loss: 0.4226903439
# Epoch 133: train loss: 0.4294756353, validation loss: 0.4188860416
# Epoch 134: train loss: 0.4243339002, validation loss: 0.4146453321
# Epoch 135: train loss: 0.4204065800, validation loss: 0.4106326878
# Epoch 136: train loss: 0.4157110453, validation loss: 0.4070142925
# Epoch 137: train loss: 0.4118549526, validation loss: 0.4052238435
# Epoch 138: train loss: 0.4085507989, validation loss: 0.4003000408
# Epoch 139: train loss: 0.4037880599, validation loss: 0.3949408740
# Epoch 140: train loss: 0.3996755183, validation loss: 0.3925274491
# Epoch 141: train loss: 0.3960108757, validation loss: 0.3891817421
# Epoch 142: train loss: 0.3925563991, validation loss: 0.3842658013
# Epoch 143: train loss: 0.3882871270, validation loss: 0.3814959764
# Epoch 144: train loss: 0.3848272860, validation loss: 0.3777518004
# Epoch 145: train loss: 0.3808629811, validation loss: 0.3739840835
# Epoch 146: train loss: 0.3772867024, validation loss: 0.3709873736
# Epoch 147: train loss: 0.3734296858, validation loss: 0.3673416197
# Epoch 148: train loss: 0.3693420291, validation loss: 0.3632564425
# Epoch 149: train loss: 0.3656821251, validation loss: 0.3601309299
# Epoch 150: train loss: 0.3615317643, validation loss: 0.3568769157
# Epoch 151: train loss: 0.3581527174, validation loss: 0.3530712068
# Epoch 152: train loss: 0.3542599678, validation loss: 0.3498904601
# Epoch 153: train loss: 0.3504267335, validation loss: 0.3460630029
# Epoch 154: train loss: 0.3465992510, validation loss: 0.3432537794
# Epoch 155: train loss: 0.3433274627, validation loss: 0.3404879376
# Epoch 156: train loss: 0.3394423425, validation loss: 0.3362539977
# Epoch 157: train loss: 0.3357991576, validation loss: 0.3330446050
# Epoch 158: train loss: 0.3323520124, validation loss: 0.3296816945
# Epoch 159: train loss: 0.3288130462, validation loss: 0.3279593453
# Epoch 160: train loss: 0.3251575530, validation loss: 0.3230084181
# Epoch 161: train loss: 0.3212958574, validation loss: 0.3210923597
# Epoch 162: train loss: 0.3177540302, validation loss: 0.3177225634
# Epoch 163: train loss: 0.3140750527, validation loss: 0.3140055135
# Epoch 164: train loss: 0.3106504679, validation loss: 0.3109496266
# Epoch 165: train loss: 0.3075030446, validation loss: 0.3075693369
# Epoch 166: train loss: 0.3038560748, validation loss: 0.3048399463
# Epoch 167: train loss: 0.3003075421, validation loss: 0.3019592017
# Epoch 168: train loss: 0.2966916561, validation loss: 0.2998615503
# Epoch 169: train loss: 0.2939057350, validation loss: 0.2961431816
# Epoch 170: train loss: 0.2914992571, validation loss: 0.2933749974
# Epoch 171: train loss: 0.2877325416, validation loss: 0.2911713108
# Epoch 172: train loss: 0.2847335339, validation loss: 0.2899775177
# Epoch 173: train loss: 0.2816949785, validation loss: 0.2856505141
# Epoch 174: train loss: 0.2780301869, validation loss: 0.2836112678
# Epoch 175: train loss: 0.2745094895, validation loss: 0.2793429330
# Epoch 176: train loss: 0.2718260288, validation loss: 0.2767686680
# Epoch 177: train loss: 0.2693122327, validation loss: 0.2744193867
# Epoch 178: train loss: 0.2664434910, validation loss: 0.2723957002
# Epoch 179: train loss: 0.2630285323, validation loss: 0.2700164318
# Epoch 180: train loss: 0.2607193291, validation loss: 0.2680876851
# Epoch 181: train loss: 0.2579475939, validation loss: 0.2654453591
# Epoch 182: train loss: 0.2552267611, validation loss: 0.2632445112
# Epoch 183: train loss: 0.2526141405, validation loss: 0.2601781622
# Epoch 184: train loss: 0.2498793900, validation loss: 0.2574384794
# Epoch 185: train loss: 0.2474562377, validation loss: 0.2552179337
# Epoch 186: train loss: 0.2447213829, validation loss: 0.2530627280
# Epoch 187: train loss: 0.2423817068, validation loss: 0.2538445741
# Epoch 188: train loss: 0.2404909432, validation loss: 0.2516774908
# Epoch 189: train loss: 0.2374816984, validation loss: 0.2494841695
# Epoch 190: train loss: 0.2352423519, validation loss: 0.2464877144
# Epoch 191: train loss: 0.2334932387, validation loss: 0.2442670390
# Epoch 192: train loss: 0.2313706875, validation loss: 0.2428369179
# Epoch 193: train loss: 0.2289299816, validation loss: 0.2397483364
# Epoch 194: train loss: 0.2273453623, validation loss: 0.2388343543
# Epoch 195: train loss: 0.2249232978, validation loss: 0.2363279760
# Epoch 196: train loss: 0.2230801731, validation loss: 0.2336409092
# Epoch 197: train loss: 0.2216430753, validation loss: 0.2327654719
# Epoch 198: train loss: 0.2193937004, validation loss: 0.2317409903
# Epoch 199: train loss: 0.2174891680, validation loss: 0.2307950914
# Epoch 200: train loss: 0.2154125124, validation loss: 0.2292199492
# Epoch 201: train loss: 0.2143079489, validation loss: 0.2278061897
# Epoch 202: train loss: 0.2121520340, validation loss: 0.2257586181
# Epoch 203: train loss: 0.2109057903, validation loss: 0.2251551449
# Epoch 204: train loss: 0.2088774890, validation loss: 0.2238423944
# Epoch 205: train loss: 0.2076594085, validation loss: 0.2210355341
# Epoch 206: train loss: 0.2065106630, validation loss: 0.2193337366
# Epoch 207: train loss: 0.2048415095, validation loss: 0.2198703021
# Epoch 208: train loss: 0.2036860734, validation loss: 0.2197943062
# Epoch 209: train loss: 0.2023603171, validation loss: 0.2160711005
# Epoch 210: train loss: 0.2009451985, validation loss: 0.2158073723
# Epoch 211: train loss: 0.1998612732, validation loss: 0.2147833496
# Epoch 212: train loss: 0.1986820251, validation loss: 0.2131078675
# Epoch 213: train loss: 0.1970486343, validation loss: 0.2115458593
# Epoch 214: train loss: 0.1958034486, validation loss: 0.2114886448
# Epoch 215: train loss: 0.1951834559, validation loss: 0.2093611121
# Epoch 216: train loss: 0.1941663474, validation loss: 0.2086514637
# Epoch 217: train loss: 0.1924253851, validation loss: 0.2077756301
# Epoch 218: train loss: 0.1922874749, validation loss: 0.2093346611
# Epoch 219: train loss: 0.1911849529, validation loss: 0.2065270200
# Epoch 220: train loss: 0.1904983371, validation loss: 0.2054546490
# Epoch 221: train loss: 0.1892624199, validation loss: 0.2048306897
# Epoch 222: train loss: 0.1882033795, validation loss: 0.2033231378
# Epoch 223: train loss: 0.1874573976, validation loss: 0.2038911551
# Epoch 224: train loss: 0.1865342408, validation loss: 0.2027222067
# Epoch 225: train loss: 0.1858990192, validation loss: 0.2019445390
# Epoch 226: train loss: 0.1846462786, validation loss: 0.1993367255
# Epoch 227: train loss: 0.1841230392, validation loss: 0.2009136990
# Epoch 228: train loss: 0.1833209693, validation loss: 0.1981904820
# Epoch 229: train loss: 0.1826311797, validation loss: 0.1991680995
# Epoch 230: train loss: 0.1818058193, validation loss: 0.1966970220
# Epoch 231: train loss: 0.1810839921, validation loss: 0.1965938777
# Epoch 232: train loss: 0.1809844673, validation loss: 0.1967053175
# Epoch 233: train loss: 0.1798659712, validation loss: 0.1966029555
# Epoch 234: train loss: 0.1792163402, validation loss: 0.1943926439
# Epoch 235: train loss: 0.1787030399, validation loss: 0.1941647366
# Epoch 236: train loss: 0.1779197752, validation loss: 0.1938860953
# Epoch 237: train loss: 0.1775099784, validation loss: 0.1933530018
# Epoch 238: train loss: 0.1768246144, validation loss: 0.1925194651
# Epoch 239: train loss: 0.1762485355, validation loss: 0.1917998642
# Epoch 240: train loss: 0.1758064926, validation loss: 0.1955895409
# Epoch 241: train loss: 0.1751176566, validation loss: 0.1907169998
# Epoch 242: train loss: 0.1747416556, validation loss: 0.1907554224
# Epoch 243: train loss: 0.1746756285, validation loss: 0.1909973562
# Epoch 244: train loss: 0.1739374399, validation loss: 0.1916396797
# Epoch 245: train loss: 0.1731600463, validation loss: 0.1893272653
# Epoch 246: train loss: 0.1727282554, validation loss: 0.1884088114
# Epoch 247: train loss: 0.1722087264, validation loss: 0.1896358430
# Epoch 248: train loss: 0.1719890982, validation loss: 0.1878939047
# Epoch 249: train loss: 0.1715823710, validation loss: 0.1904991731
# Epoch 250: train loss: 0.1712624878, validation loss: 0.1864342362
# Epoch 251: train loss: 0.1703104675, validation loss: 0.1876327336
# Epoch 252: train loss: 0.1701616049, validation loss: 0.1858601287
# Epoch 253: train loss: 0.1695887446, validation loss: 0.1853064403
# Epoch 254: train loss: 0.1697545499, validation loss: 0.1865041316
# Epoch 255: train loss: 0.1688294113, validation loss: 0.1874504924
# Epoch 256: train loss: 0.1682989597, validation loss: 0.1844924167
# Epoch 257: train loss: 0.1680029333, validation loss: 0.1834338307
# Epoch 258: train loss: 0.1681326032, validation loss: 0.1859630063
# Epoch 259: train loss: 0.1677115411, validation loss: 0.1853314176
# Epoch 260: train loss: 0.1671041697, validation loss: 0.1823566079
# Epoch 261: train loss: 0.1664769650, validation loss: 0.1839874342
# Epoch 262: train loss: 0.1663147807, validation loss: 0.1829453275
# Epoch 263: train loss: 0.1663573235, validation loss: 0.1821673259
# Epoch 264: train loss: 0.1657391936, validation loss: 0.1806668848
# Epoch 265: train loss: 0.1653758585, validation loss: 0.1802131474
# Epoch 266: train loss: 0.1644671410, validation loss: 0.1820043638
# Epoch 267: train loss: 0.1646779329, validation loss: 0.1799333632
# Epoch 268: train loss: 0.1642010659, validation loss: 0.1801009297
# Epoch 269: train loss: 0.1636672318, validation loss: 0.1792648897
# Epoch 270: train loss: 0.1634264737, validation loss: 0.1796929151
# Epoch 271: train loss: 0.1631676704, validation loss: 0.1790773243
# Epoch 272: train loss: 0.1632437855, validation loss: 0.1787874058
# Epoch 273: train loss: 0.1632651091, validation loss: 0.1787385836
# Epoch 274: train loss: 0.1623826176, validation loss: 0.1790520549
# Epoch 275: train loss: 0.1621537507, validation loss: 0.1778300509
# Epoch 276: train loss: 0.1617989689, validation loss: 0.1784955367
# Epoch 277: train loss: 0.1623823196, validation loss: 0.1774158463
# Epoch 278: train loss: 0.1613252759, validation loss: 0.1789262235
# Epoch 279: train loss: 0.1610539854, validation loss: 0.1766146153
# Epoch 280: train loss: 0.1605885029, validation loss: 0.1761919677
# Epoch 281: train loss: 0.1602425426, validation loss: 0.1787399039
# Epoch 282: train loss: 0.1596271545, validation loss: 0.1757442042
# Epoch 283: train loss: 0.1595010906, validation loss: 0.1749227598
# Epoch 284: train loss: 0.1594309509, validation loss: 0.1744367719
# Epoch 285: train loss: 0.1589048654, validation loss: 0.1759381965
# Epoch 286: train loss: 0.1588924080, validation loss: 0.1746419668
# Epoch 287: train loss: 0.1587365568, validation loss: 0.1745643348
# Epoch 288: train loss: 0.1580031365, validation loss: 0.1745774373
# Epoch 289: train loss: 0.1578455269, validation loss: 0.1732659042
# Epoch 290: train loss: 0.1580243111, validation loss: 0.1747489735
# Epoch 291: train loss: 0.1578217596, validation loss: 0.1739989489
# Epoch 292: train loss: 0.1575419903, validation loss: 0.1740933523
# Epoch 293: train loss: 0.1571539193, validation loss: 0.1730096206
# Epoch 294: train loss: 0.1566543728, validation loss: 0.1724013776
# Epoch 295: train loss: 0.1564359367, validation loss: 0.1721447378
# Epoch 296: train loss: 0.1563652307, validation loss: 0.1719051369
# Epoch 297: train loss: 0.1564257592, validation loss: 0.1714674473
# Epoch 298: train loss: 0.1558726579, validation loss: 0.1713673353
# Epoch 299: train loss: 0.1557400227, validation loss: 0.1713573143
# Epoch 300: train loss: 0.1551160812, validation loss: 0.1711984321
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Koopman Model Parameters

# %%
A = np.array(model_koop_dnn.A)
B = np.array(model_koop_dnn.B)
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (17, 17) (17, 3) (6, 17)

# %% [markdown]
# ## Testing

# %%
# test data parameters
num_snaps_test = 100 # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test)
num_traj_test = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %%
x_end_unchanged_test,x_unchanged_test,x_end_changed_test, x_changed_test, u_test = data_gen_robot_multi(dt,num_traj_test,num_snaps_test, robot, robot_changed, robot_pars_changed, controller)
print(model_koop_dnn.test_loss(x_unchanged_test,u_test = u_test))
# Out:
# tensor(0.2062)

# %%
x_unchanged_test.shape
# Out:
# (1, 100, 6)

# %%
# Use the preprocessing if available
X_unchanged_t,_ = model_koop_dnn.net.process(x_unchanged_test,data_u = u_test)
X_changed_t,_ = model_koop_dnn.net.process(x_changed_test,data_u = u_test)

# %%
X_changed_t.shape
# Out:
# (99, 15)

# %%
# flatten vector
x_unchanged_t = X_unchanged_t[:, :num_states]
u_t = X_unchanged_t[:, num_states:num_states+num_inputs]
x_unchanged_prime_t = X_unchanged_t[:,num_states+num_inputs:]

x_changed_t = X_changed_t[:, :num_states]
x_changed_prime_t = X_changed_t[:,num_states+num_inputs:]

x_changed_dot_t = (x_changed_prime_t-x_changed_t)/dt
print(x_changed_t.shape, u_t.shape, x_changed_prime_t.shape)
# Out:
# (99, 6) (99, 3) (99, 6)

# %%
# initialize states
# initialize the matricies
z_unchanged_t = np.empty((n_obs,num_snaps_test)).T   #lifted state
x_unchanged_est_t = np.zeros((num_states,num_snaps_test)).T #estimated values

# actual lift
z_unchanged_t[0,:] = lift(x_unchanged_t[0,:],model_koop_dnn, net_params)
x_unchanged_est_t[0,:] = x_unchanged_t[0,:]

# %%
for i in range(num_snaps_test-1):
  #bilinear
    z_unchanged_t[i+1,:] = np.matmul(z_unchanged_t[i,:],A.T)+np.matmul(u_t[i,:],B.T)
    x_unchanged_est_t[i+1,:] = np.matmul(z_unchanged_t[i+1,:],C.T)

# %%
# state estimation evolution
plt.figure(figsize=(20, 10)) 

for i in range(num_joints):
    plt.subplot(num_joints, 2, 2*i +1)
    plt.plot(T_test[:-1],x_unchanged_t[:,i],label ='Original Dynamics')
    plt.plot(T_test[:],x_unchanged_est_t[:,i],label = 'estimated Original (linear)')
    plt.xlabel('t')

    plt.ylabel('th_' + str(i+1))
    plt.legend()
    
    plt.subplot(num_joints, 2, 2*i + 2)
    plt.plot(T_test[:-1],x_unchanged_t[:,num_joints+i],label ='Original Dynamics')
    plt.plot(T_test[:],x_unchanged_est_t[:,num_joints+i],label = 'estimated Original (linear)')
    plt.xlabel('t')
    plt.ylabel('th_dot' + str(i+1))
    plt.legend()
plt.suptitle("Testing Performance", fontsize=30)
# Out:
# Text(0.5, 0.98, 'Testing Performance')

# %%
# error estimation
error_model_t = np.linalg.norm((x_unchanged_est_t[:-1,:]-x_unchanged_t[:,:]),axis=1)
error_dynamics_no_adapt_t = np.linalg.norm((x_changed_t[:,:]-x_unchanged_t[:,:]),axis=1)

plt.figure()
plt.plot(T_test[:-1],error_model_t)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Model error evolution')
plt.show()

# %%
# comparison with Chnaged dynamics
plt.figure(figsize=(20, 10)) 

for i in range(num_joints):
    plt.subplot(num_joints, 2, 2*i +1)
    plt.plot(T_test[:-1],x_unchanged_t[:,i],label ='Original Dynamics')
    plt.plot(T_test[:-1],x_changed_t[:,i],label ='Changed Dynamics')
    plt.plot(T_test[:],x_unchanged_est_t[:,i],label = 'estimated Original (linear)')
    plt.xlabel('t')
    plt.ylabel('th_' + str(i+1))
    plt.legend()
    
    plt.subplot(num_joints, 2, 2*i + 2)
    plt.plot(T_test[:-1],x_unchanged_t[:,num_joints+i],label ='Original Dynamics')
    plt.plot(T_test[:-1],x_changed_t[:,num_joints+i],label  ='Changed Dynamics')
    plt.plot(T_test[:],x_unchanged_est_t[:,num_joints+i],label = 'estimated Original (linear)')
    plt.xlabel('t')
    plt.ylabel('th_dot' + str(i+1))
    plt.legend()
plt.suptitle("Change in Dynamics", fontsize=30)
# Out:
# Text(0.5, 0.98, 'Change in Dynamics')

# %%
plt.figure()
plt.plot(T_test[:-1],error_dynamics_no_adapt_t)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Dynamics error evolution')
plt.show()

# %% [markdown]
# ## Adaptive Koopman with Control

# %%
# adaptive net parameters
adap_window = 20 #20 #hyperparameter

adapt_net_params = {}
adapt_net_params['state_dim'] = num_states
adapt_net_params['ctrl_dim'] = num_inputs
adapt_net_params['lift_dim'] = net_params["encoder_output_dim"]
adapt_net_params['optimizer'] = 'adam'
adapt_net_params['lr'] = 5e-4 # 5e-3
adapt_net_params['epochs'] = 30 #30
adapt_net_params['batch_size'] = adap_window
adapt_net_params['l2_reg'] = 5e-1
adapt_net_params['l1_reg'] = 5e-1
adapt_net_params['first_obs_const'] = net_params["first_obs_const"]
adapt_net_params['override_C'] = net_params["override_C"] # this makes the state a part of lifted state
adapt_net_params['warm_start'] = True

del_A = np.zeros_like(A)
del_B = np.zeros_like(B)

adapt_net_params['del_A_prev'] = del_A
adapt_net_params['del_B_prev'] = del_B

time_delay = 10000

# %%
from control_files.nmpc_osqp_adapt import NonlinearMPCController
from dynamics.learned_models_control.linear_dynamics import linear_Dynamics
import scipy

# %%
# model objects for MPC
linear_model = linear_Dynamics(scipy.sparse.csc_matrix(A),scipy.sparse.csc_matrix(B), C)
linear_model_no_adapt = linear_Dynamics(scipy.sparse.csc_matrix(A),scipy.sparse.csc_matrix(B), C)
linear_model.A
# Out:
# <17x17 sparse matrix of type '<class 'numpy.float32'>'
# 	with 273 stored elements in Compressed Sparse Column format>

# %%
# OSQP solver setting
solver_settings = {}
solver_settings['gen_embedded_ctrl'] = False
solver_settings['warm_start'] = True
solver_settings['polish'] = True
solver_settings['polish_refine_iter'] = 3
solver_settings['scaling'] = True
solver_settings['adaptive_rho'] = False
solver_settings['check_termination'] = 25
solver_settings['max_iter'] = 1000
solver_settings['eps_abs'] = 1e-5
solver_settings['eps_rel'] = 1e-6
solver_settings['eps_prim_inf'] = 1e-4
solver_settings['eps_dual_inf'] = 1e-4
solver_settings['linsys_solver'] = 'qdldl'

# %%
#Closed loop performance evaluation parameters:
traj_length = 1000
max_iter = 200
N =  30 #length of horizon
t_eval = dt * np.arange(traj_length+1)                       # Simulation time points, closed loop
Q_mpc = 1e5*scipy.sparse.diags(np.ones(num_states))                       # State penalty matrix, trajectory generation
QN_mpc = 1e2*scipy.sparse.diags(np.ones(num_states))         # Final state penalty matrix, trajectory generation
R_mpc = 10*scipy.sparse.eye(num_inputs)                                     # Actuation penalty matrix, trajectory generation
R0_mpc = 10*scipy.sparse.csc_matrix(np.zeros(num_inputs))

# %%
## linear path
# x_ref = np.vstack((np.vstack((np.linspace(0,np.pi,num_snaps_ctrl),np.linspace(0,np.pi/2,num_snaps_ctrl))),np.linspace(0,np.pi,num_snaps_ctrl)))
# x_ref_dot = np.vstack((np.vstack(((np.pi/10)*np.ones(num_snaps_ctrl),(np.pi/20)*np.ones(num_snaps_ctrl))),(np.pi/10)*np.ones(num_snaps_ctrl)))
# x_ref_ddot = np.vstack((np.vstack((np.zeros(num_snaps_ctrl),np.zeros(num_snaps_ctrl))),np.zeros(num_snaps_ctrl)))

def gen_desired_path(num_states,num_snaps, t_end,shape):
    
    x_ref = np.empty((int(num_states),num_snaps))
    x_ref_dot = np.empty_like(x_ref)
    x_ref_ddot = np.empty_like(x_ref)

    # lets say t = 20 completes one cycles
    num_cycles = int(t_end/20)
    
    arg = np.linspace(0, num_cycles*2*np.pi,num_snaps)
    
    for i in range(num_snaps):
        if shape == 'linear':
            x_ref[:,i] = arg[i]*np.ones((num_states))
            x_ref_dot[:,i] = (arg[-1]/t_end)*np.ones((num_states))
            x_ref_ddot[:,i] = np.zeros(num_states,)
            
        if shape == 'sinosoidal':
            x_ref[:,i] = np.sin(arg[i])*np.ones((num_states))
            x_ref_dot[:,i] = (arg[-1]/t_end)*np.cos(arg[i])*np.ones((num_states))
            x_ref_ddot[:,i] = -((arg[-1]/t_end)**2)*np.cos(arg[i])*np.ones((num_states))
        else:
            print('Shape is not defined')
            break
            
            
    return x_ref, x_ref_dot, x_ref_ddot

# %%
x_ref_pos, x_ref_dot,_  = gen_desired_path(int(num_states/2),traj_length+1, t_eval[-1],'sinosoidal')
x_ref = np.vstack((x_ref_pos, x_ref_dot))
x_ref.shape
# Out:
# (6, 1001)

# %%
# Design trajectory:
xt = np.empty((traj_length+1, num_states))
xt[0,:] = x_ref[:,0]             # Initial value, closed loop trajectory

# x_r = np.array([0., 0.])              # Desired final value, closed loop trajectory
# x_ref = np.tile(x_r.reshape(-1,1), (1, traj_length))
umax = 30*np.ones((num_joints,))
umin = -umax

xmax =  30*np.ones((num_states))
xmin = -xmax

# Define initial solution for SQP algorithm:
x_init = np.linspace(xt[0,:], xt[0,:], N+1) + 0.1
u_init = 1*np.ones((num_inputs, N)).T

# %%
n_lift = A.shape[0]
z_init = np.empty((N+1, n_lift))
z0 = lift(xt[0,:], model_koop_dnn, net_params)
for i in range(N+1):
    z_init[i,:] = lift(x_init[i,:], model_koop_dnn, net_params)

# %%
# initialize state matricies
u = np.empty((traj_length, num_inputs))
z_new_dyn = np.empty((n_obs, traj_length+1)).T   #lifted state
zt_old_dyn = np.empty((n_obs, traj_length+1)).T #actual lifted state
del_z_prime = np.empty((n_obs, traj_length)).T
zu_old_dyn = np.empty((n_obs*num_inputs, traj_length)).T
x_new_dyn = np.empty((num_states, traj_length+1)).T #estimated values
xt_old = np.empty((num_states, traj_length+1)).T
del_A_norm = np.zeros((traj_length,1))
del_B_norm = np.zeros((traj_length,1))

# initialize
z_new_dyn[0,:] = zt_old_dyn[0,:] = z0
x_new_dyn[0,:] = xt_old[0,:] = xt[0,:]

# %%
controller_nmpc_adapt = NonlinearMPCController(linear_model, N, dt, umin, umax, xmin, xmax, Q_mpc, R_mpc, QN_mpc, solver_settings)
controller_nmpc_adapt.construct_controller(z_init, u_init, x_ref[:,0])

# %%
total_time = 0
algo_start_time = time.time()
for i in range(traj_length):
  # incorrect dynamics
    start_time = time.time()
    z_new_dyn[i,:] = lift(x_new_dyn[i,:], model_koop_dnn, net_params)
    
    del_z_prime[i,:] = z_new_dyn[i,:] - zt_old_dyn[i,:]
    zu_old_dyn[i,:] = np.kron(u[i,:], zt_old_dyn[i,:])

    if i < adap_window + 1 :
        del_A = np.zeros_like(A)
        del_B = np.zeros_like(B)
    else:
        del_Z_prime = del_z_prime[i-adap_window:i,:].T
        Z_old = zt_old_dyn[i-(adap_window+1):i-1].T
        U_old = u[i-(adap_window+1):i-1].T

        #invoke neural net for adapation
        adapt_network = AdaptNet_linear(adapt_net_params)

        adapt_network.model_pipeline(Z_old, U_old, del_Z_prime, print_epoch = True)

        del_A, del_B = adapt_network.get_del_matrices()

    del_A_norm[i] = np.linalg.norm(del_A)
    del_B_norm[i] = np.linalg.norm(del_B)

    linear_model.A = scipy.sparse.csc_matrix(A + del_A)
    linear_model.B = scipy.sparse.csc_matrix(B + del_B)

    # linear_model.A = scipy.sparse.csc_matrix(linear_model.A.toarray() + del_A)
    # linear_model.B = scipy.sparse.csc_matrix(linear_model.B.toarray() + del_B)

    
    controller_nmpc_adapt.solve_to_convergence(x_ref[:,i+1], z_new_dyn[i,:], controller_nmpc_adapt.z_init, controller_nmpc_adapt.u_init, max_iter = max_iter, eps = 1e-3)
    controller_nmpc_adapt.update_initial_guess_()
    u[i,:] = controller_nmpc_adapt.cur_u[0,:]
    end_time = time.time()

    total_time = total_time + end_time-start_time
    
    if sum(np.isnan(u[i,:])) > 0:
        break

    # adapted model
    zt_old_dyn[i+1,:] = controller_nmpc_adapt.z_N0
    #zt_old_dyn[i+1,:] = np.matmul(z_new[i,:],A.T)+np.matmul(u_t[i,:],B.T)
    xt[i+1,:] = np.matmul(zt_old_dyn[i+1,:],C.T)
    
    th_ddot_old = robot.accel(xt_old[i,0:num_joints], xt_old[i,num_joints:], u[i,:])
    xt_old[i+1,num_joints:] = th_ddot_old*dt + xt_old[i,num_joints:] 
    xt_old[i+1,:num_joints] = xt_old[i,num_joints:] *dt + xt_old[i,:num_joints] 

    
    if robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'constant':
        tau_app = u[i,:]/robot_pars_changed['SN']
    elif robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'gaussian':
        tau_app = np.random.normal(loc = u[i,:],scale = 1/robot_pars_changed['SN'])
    elif robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'random':
        tau_app = u[i,:] + (2*np.random.rand(u[i,:].shape[0])-1)/robot_pars_changed['SN']
    elif robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'sinosiodal':
        tau_app = u[i,:] + np.sin(200*np.pi*i*dt)/robot_pars_changed['SN']
        
    else:
        tau_app = u[i,:]

    algo_time = time.time()-algo_start_time

    if algo_start_time < time_delay:
        x_new_dyn[i+1,num_joints:] = xt_old[i+1,num_joints:]
        x_new_dyn[i+1,:num_joints] = xt_old[i+1,:num_joints] 
    else:
        th_ddot_new = robot_changed.accel(x_new_dyn[i,0:num_joints], x_new_dyn[i,num_joints:], tau_app)
        x_new_dyn[i+1,num_joints:] = th_ddot_new*dt + x_new_dyn[i,num_joints:] 
        x_new_dyn[i+1,:num_joints] = x_new_dyn[i,num_joints:]*dt + x_new_dyn[i,:num_joints] 
    
    adapt_net_params['del_A_prev'] = del_A
    adapt_net_params['del_B_prev'] = del_B
    

print('Time Taken', total_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 36
#      30 linear_model.B = scipy.sparse.csc_matrix(B + del_B)
#      32 # linear_model.A = scipy.sparse.csc_matrix(linear_model.A.toarray() + del_A)
#      33 # linear_model.B = scipy.sparse.csc_matrix(linear_model.B.toarray() + del_B)
# ---> 36 controller_nmpc_adapt.solve_to_convergence(x_ref[:,i+1], z_new_dyn[i,:], controller_nmpc_adapt.z_init, controller_nmpc_adapt.u_init, max_iter = max_iter, eps = 1e-3)
#      37 controller_nmpc_adapt.update_initial_guess_()
#      38 u[i,:] = controller_nmpc_adapt.cur_u[0,:]
#
# File ~/Projects/Adaptive-koopman/control_files/nmpc_osqp_adapt.py:181, in NonlinearMPCController.solve_to_convergence(self, xr, z, z_init_0, u_init_0, max_iter, eps)
#     178 self.update_constraint_matrix_data_(A_lst, B_lst)
#     179 t_prep = time.time() - t0
# --> 181 self.solve_mpc_()
#     182 dz = self.dz_flat.reshape(self.N + 1, self.nz)
#     183 du = self.du_flat.reshape(self.N, self.nu)
#
# File ~/Projects/Adaptive-koopman/control_files/nmpc_osqp_adapt.py:414, in NonlinearMPCController.solve_mpc_(self)
#     412 self.du_flat = self.res.x[(self.N + 1) * self.nz:(self.N + 1) * self.nz + self.nu * self.N]
#     413 if self.res.info.status != 'solved':
# --> 414     raise ValueError('OSQP did not solve the problem!')
#
# ValueError: OSQP did not solve the problem!

# %%
i

# %%
algo_time

# %%
#controller that works on old model (unadapted)
N_noadapt = N #length of horizon
Q_mpc_noadapt = 1e5*scipy.sparse.diags(np.ones(num_states))                       # State penalty matrix, trajectory generation
QN_mpc_noadapt = 1e3*scipy.sparse.diags(np.ones(num_states))         # Final state penalty matrix, trajectory generation
R_mpc_noadapt = 10*scipy.sparse.eye(num_inputs)                                     # Actuation penalty matrix, trajectory generation
R0_mpc_noadapt = 10*scipy.sparse.csc_matrix(np.zeros(num_inputs))

# x_r = np.array([0., 0.])              # Desired final value, closed loop trajectory
# x_ref = np.tile(x_r.reshape(-1,1), (1, traj_length))
umax_noadapt = 100*np.ones((num_joints,))
umin_noadapt = -umax

xmax_noadapt =  30*np.ones((num_states,))
xmin_noadapt = -xmax

# %%
controller_nmpc_noadapt = NonlinearMPCController(linear_model_no_adapt, N_noadapt, dt, umin_noadapt, umax_noadapt, xmin_noadapt, xmax_noadapt, Q_mpc_noadapt, R_mpc_noadapt, QN_mpc_noadapt, solver_settings)
controller_nmpc_noadapt.construct_controller(z_init, u_init, x_ref[:,0])
# controller_nmpc_noadapt.trajectory_tracking(xt[0,:], z0, x_ref.T, max_iter)

# %%
xt_no_adapt = np.empty((num_states,traj_length+1)).T
x_new_noadapt = np.empty((num_states,traj_length+1)).T
xt_no_adapt[0,:] = x_new_noadapt[0,:] = xt[0,:]
u_no_adapt = np.empty((num_inputs, traj_length)).T
z_no_adapt = np.empty((n_obs, traj_length+1)).T

algo_start_time = time.time()

for i in range(traj_length):
    # incorrect dynamics
    z_no_adapt[i,:] = lift(x_new_noadapt[i,:], model_koop_dnn, net_params)

    controller_nmpc_noadapt.solve_to_convergence(x_ref[:,i+1], z_no_adapt[i,:], controller_nmpc_noadapt.z_init, controller_nmpc_noadapt.u_init, max_iter = max_iter, eps = 1e-3)
    controller_nmpc_noadapt.update_initial_guess_()
    u_no_adapt[i,:] = controller_nmpc_noadapt.cur_u[0,:]
    
    if sum(np.isnan(u_no_adapt[i,:])) > 0:
        break
    
    
    xt_no_adapt[i+1,:] = np.matmul(controller_nmpc_noadapt.z_N0, C.T)
    
    if robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'constant':
        tau_app = u_no_adapt[i,:]/robot_pars_changed['SN']
    elif robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'gaussian':
        tau_app = np.random.normal(loc = u_no_adapt[i,:],scale = 1/robot_pars_changed['SN'])
    elif robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'random':
        tau_app = u_no_adapt[i,:] + (2*np.random.rand(u_no_adapt[i,:].shape[0])-1)/robot_pars_changed['SN']
    elif robot_pars_changed ['ext_torque'] and robot_pars_changed ['ext_torque_type'] == 'sinosiodal':
        tau_app = u_no_adapt[i,:] + np.sin(200*np.pi*i*dt)/robot_pars_changed['SN']
        
    else:
        tau_app = u_no_adapt[i,:]

    algo_time = time.time()-algo_start_time

    if algo_start_time < time_delay:
        th_ddot_new = robot.accel(x_new_noadapt[i,:num_joints], x_new_noadapt[i,num_joints:], u_no_adapt[i,:])
        x_new_noadapt[i+1,num_joints:] = th_ddot_new*dt + x_new_noadapt[i,num_joints:] 
        x_new_noadapt[i+1,:num_joints] = x_new_noadapt[i,num_joints:]*dt + x_new_noadapt[i,:num_joints]  
    else:
        th_ddot_new = robot_changed.accel(x_new_noadapt[i,:num_joints], x_new_noadapt[i,num_joints:], tau_app)
        x_new_noadapt[i+1,num_joints:] = th_ddot_new*dt + x_new_noadapt[i,num_joints:] 
        x_new_noadapt[i+1,:num_joints] = x_new_noadapt[i,num_joints:]*dt + x_new_noadapt[i,:num_joints]

# %%
i

# %% [markdown]
# ## Performance Plotting

# %%
plt.figure(figsize=(20, 10) )
for i in range(num_joints):
    plt.subplot(num_joints,2,2*i+1)
    plt.plot(t_eval, x_new_noadapt[:,i], label='path traced (without adapt)',linewidth = 2.0)
    plt.plot(t_eval, x_ref[i,:], label="reference",linewidth = 2.0)
    plt.plot(t_eval, x_new_dyn[:,i],label ='path traced (with adapt)',ls = '--', linewidth = 2.0,color = 'g')
    plt.xlabel('t')
    plt.ylabel('th'+ str(i+1))
    plt.legend()
    
    plt.subplot(num_joints,2,2*i+2)
    plt.plot(t_eval, x_new_noadapt[:,num_joints+i], label='path traced (without adapt)',linewidth = 2.0)
    plt.plot(t_eval, x_ref[num_joints+i,:], label="reference",linewidth = 2.0)
    plt.plot(t_eval, x_new_dyn[:,num_joints+i],label ='path traced (with adapt)',linewidth = 2.0, ls = '--', color = 'g')
    plt.xlabel('t')
    plt.ylabel('th_dot'+ str(i+1))
    plt.legend()

# %%
plt.figure(figsize=(20,7) )
for i in range(num_joints):
    plt.subplot(1,num_joints,i+1)
    plt.plot(t_eval, xt_no_adapt[:,i], label='path traced (without adapt)',linewidth = 2.0)
    plt.plot(t_eval, x_ref[i,:], label="reference",linewidth = 2.0)
    plt.plot(t_eval, xt[:,i],label ='path traced (with adapt)',ls = '--', linewidth = 2.0,color = 'g')
    plt.xlabel('t')
    plt.ylabel('th'+ str(i+1))
    plt.legend()
plt.savefig('3R_states.pdf')

# %%
plt.figure(figsize=(20, 10)) 
for i in range(num_joints):
    plt.subplot(num_joints,2,2*i+1)
    plt.plot(t_eval[:-1], u[:,i], label = "Adapt")
    plt.xlabel('T')
    plt.ylabel("u" + str(i+1))
    plt.legend()
    
    plt.subplot(num_joints,2,2*i+2)
    plt.plot(t_eval[:-1], u_no_adapt[:,i],  label = "No Adapt")
    plt.xlabel('T')
    plt.ylabel("u" + str(i+1))
    plt.legend()

# %%
plt.figure(figsize = (20,10))

plt.subplot(1,2,1)
plt.plot(t_eval[:-1],del_A_norm)
plt.xlabel('t')
plt.ylabel('||del_A||')
plt.title(" ||del_A|| Evolution")

plt.subplot(1,2,2)
plt.plot(t_eval[:-1],del_B_norm)
plt.xlabel('t')
plt.ylabel('||del_B||')
plt.title("||del_B|| Evolution")

# %%
plt.figure(figsize = (20,10))

plt.subplot(1,2,1)
plt.plot(t_eval[:-1],del_A_norm/np.linalg.norm(A))
plt.xlabel('t')
plt.ylabel('||del_A||/||A||')
plt.title(" ||del_A||/||A|| Evolution")

plt.subplot(1,2,2)
plt.plot(t_eval[:-1],del_B_norm/np.linalg.norm(A))
plt.xlabel('t')
plt.ylabel('||del_B||/|||B||')
plt.title("||del_B||/||B|| Evolution")

# %%
error_dynamics_adapt = np.linalg.norm((xt.T-x_ref),axis=0)
error_dynamics_no_adapt = np.linalg.norm((xt_no_adapt.T-x_ref),axis=0)

plt.figure(figsize = (20,10))

plt.subplot(1,2,1)
plt.plot(t_eval,error_dynamics_adapt)
plt.xlabel('t')
plt.ylabel('error')
plt.title("Error in Adaptive Model")

plt.subplot(1,2,2)
plt.plot(t_eval,error_dynamics_no_adapt)
plt.xlabel('t')
plt.ylabel('error')
plt.title("Error in Non-Adaptive Model")

# %%
plt.figure(figsize = (20,10))

plt.plot(t_eval,error_dynamics_adapt, label = 'Adapt')
plt.plot(t_eval,error_dynamics_no_adapt, label = 'No Adapt')

plt.xlabel('t')
plt.ylabel('error')
plt.title("Error in Adaptive Model")
plt.legend()

# %%
error_dynamics_adapt_rmse = np.linalg.norm(error_dynamics_adapt)
error_dynamics_no_adapt_rmse = np.linalg.norm(error_dynamics_no_adapt)

print("RMSE Error in Adaptive Model", error_dynamics_adapt_rmse)
print("RMSE Error in Non-Adaptive Model", error_dynamics_no_adapt_rmse)
