# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

from core.koopman_core_linear import KoopDNN,KoopmanNet,KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from dynamics.duffing import dynamics_duff
from dynamics.Vanpol import dynamics_vanpol

from core.adapt_net_lin import AdaptNet_lin
import control as ct
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[99], line 13
#      10 from dynamics.duffing import dynamics_duff
#      11 from dynamics.Vanpol import dynamics_vanpol
# ---> 13 from core.adapt_net_lin import AdaptNet_lin
#      14 import control as ct
#
# ModuleNotFoundError: No module named 'core.adapt_net_lin'

# %%
# Base Parameters
dt = 0.01 #time step
num_snaps = 500 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 200 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 2 # no. of states
num_inputs = 1 # no. of inputs

# %%
# Oscillator parameters
dyn_pars = {}

dyn_pars['a'] = 1
dyn_pars['b'] = 4
dyn_pars['c'] = 0.5
dyn_pars['d'] = 0.5

dyn_pars['del_a'] = 3
dyn_pars['del_b'] = 8
dyn_pars['del_c'] = 5
dyn_pars['del_d'] = 3
dyn_pars['delay'] = False
dyn_pars['delay_time'] = 5
dyn_pars['cont_unc_type'] = 'sinusoidal'

# %%
X_changed, X_unchanged, U = dynamics_duff(dt, num_traj, num_snaps, num_states, num_inputs, dyn_pars)

print(X_changed.shape, U.shape)
# Out:
# (250, 501, 2) (250, 500, 1)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X_changed)))))
print(sum(sum(sum(np.isnan(X_unchanged)))))
# Out:
# 0
# 0

# %%
l2_diff = np.linalg.norm(X_changed-X_unchanged)/((X_changed.size)**(1/2))
print('l2_diff = ', l2_diff)
# Out:
# l2_diff =  0.2688673412258225

# %%
change_in_dym = np.linalg.norm((X_changed-X_unchanged)/X_changed)/X_changed.size
print('fraction of change in dynamics = ', change_in_dym)
# Out:
# fraction of change in dynamics =  7.365823347385349

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Phase plot for unchanged dynamics")
axs[1].set_title("Phase plot for changed dynamics")

axs[0].set(xlabel = 'x1', ylabel = 'x2')
axs[1].set(xlabel = 'x1', ylabel = 'x2')

for i in range(num_traj):
    axs[0].plot(X_unchanged[i,:,0], X_unchanged[i,:,1])
    axs[1].plot(X_changed[i,:,0], X_changed[i,:,1])
plt.savefig('phase_plot_duffing.jpg')

# %%
plt.figure()

plt.title('Comparison of Phase plot')
plt.plot(X_unchanged[4,:,0], X_unchanged[4,:,1], label = 'unchanged')
plt.plot(X_changed[4,:,0], X_changed[4,:,1], label = 'changed')

plt.legend()
plt.savefig('phase_plot_duffing_single_traj.jpg')
plt.show()

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in position")
axs[1].set_title("Error in velocity")

axs[0].set(xlabel = 't', ylabel = 'x1')
axs[1].set(xlabel = 't', ylabel = 'x2')


axs[0].plot(T, X_unchanged[4,:,0], label = 'unchanged')
axs[0].plot(T, X_changed[4,:,0], label = 'changed')
axs[0].legend()

axs[1].plot(T, X_unchanged[4,:,1], label = 'unchanged')
axs[1].plot(T, X_changed[4,:,1], label = 'changed')
axs[1].legend()

plt.savefig('vel_pos_err_duffing_single_traj.jpg')

# %%
# split training and vaidation datasets
xs_train, us_train = X_unchanged[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X_unchanged[num_train:,:,:],U[num_train:,:,:]

# %% [markdown]
# ***Koopman bilinear Models***

# %%
# auto encoder parameters

net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 2e-4 # 5e-4
net_params['epochs'] = 300
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'duff_linear_0_01.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'duff_0_01.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 0.4365835786, validation loss: 0.0807150671
# Epoch   2: train loss: 0.1107948348, validation loss: 0.0719109638
# Epoch   3: train loss: 0.1001003981, validation loss: 0.0646532120
# Epoch   4: train loss: 0.0925858170, validation loss: 0.0601026243
# Epoch   5: train loss: 0.0850094557, validation loss: 0.0549494956
# Epoch   6: train loss: 0.0739175454, validation loss: 0.0463177858
# Epoch   7: train loss: 0.0562007539, validation loss: 0.0301802242
# Epoch   8: train loss: 0.0329709277, validation loss: 0.0142988296
# Epoch   9: train loss: 0.0140632829, validation loss: 0.0054781786
# Epoch  10: train loss: 0.0064038192, validation loss: 0.0032536880
# Epoch  11: train loss: 0.0042672940, validation loss: 0.0024551987
# Epoch  12: train loss: 0.0033514586, validation loss: 0.0020383289
# Epoch  13: train loss: 0.0028516802, validation loss: 0.0018145391
# Epoch  14: train loss: 0.0025375620, validation loss: 0.0016244898
# Epoch  15: train loss: 0.0023017982, validation loss: 0.0014725982
# Epoch  16: train loss: 0.0021018547, validation loss: 0.0013434372
# Epoch  17: train loss: 0.0019383263, validation loss: 0.0012349977
# Epoch  18: train loss: 0.0017965272, validation loss: 0.0011488508
# Epoch  19: train loss: 0.0016659499, validation loss: 0.0010505123
# Epoch  20: train loss: 0.0015523630, validation loss: 0.0009829586
# Epoch  21: train loss: 0.0014446614, validation loss: 0.0009135510
# Epoch  22: train loss: 0.0013477700, validation loss: 0.0008487897
# Epoch  23: train loss: 0.0012608912, validation loss: 0.0007938698
# Epoch  24: train loss: 0.0011789416, validation loss: 0.0007420694
# Epoch  25: train loss: 0.0011027200, validation loss: 0.0007127796
# Epoch  26: train loss: 0.0010333649, validation loss: 0.0006470677
# Epoch  27: train loss: 0.0009690510, validation loss: 0.0006022186
# Epoch  28: train loss: 0.0009086741, validation loss: 0.0005712463
# Epoch  29: train loss: 0.0008547897, validation loss: 0.0005349576
# Epoch  30: train loss: 0.0008024481, validation loss: 0.0004982669
# Epoch  31: train loss: 0.0007524817, validation loss: 0.0004770450
# Epoch  32: train loss: 0.0007067156, validation loss: 0.0004378087
# Epoch  33: train loss: 0.0006630658, validation loss: 0.0004050404
# Epoch  34: train loss: 0.0006173726, validation loss: 0.0003940595
# Epoch  35: train loss: 0.0005779847, validation loss: 0.0003519317
# Epoch  36: train loss: 0.0005383994, validation loss: 0.0003250689
# Epoch  37: train loss: 0.0004990939, validation loss: 0.0002964533
# Epoch  38: train loss: 0.0004656477, validation loss: 0.0002839501
# Epoch  39: train loss: 0.0004314563, validation loss: 0.0002570705
# Epoch  40: train loss: 0.0004006126, validation loss: 0.0002366422
# Epoch  41: train loss: 0.0003721337, validation loss: 0.0002278096
# Epoch  42: train loss: 0.0003468290, validation loss: 0.0002095115
# Epoch  43: train loss: 0.0003211187, validation loss: 0.0001911935
# Epoch  44: train loss: 0.0003018182, validation loss: 0.0001805768
# Epoch  45: train loss: 0.0002817721, validation loss: 0.0002377324
# Epoch  46: train loss: 0.0002652243, validation loss: 0.0001666869
# Epoch  47: train loss: 0.0002470579, validation loss: 0.0001485593
# Epoch  48: train loss: 0.0002340509, validation loss: 0.0001397909
# Epoch  49: train loss: 0.0002198676, validation loss: 0.0001338253
# Epoch  50: train loss: 0.0002085873, validation loss: 0.0001385014
# Epoch  51: train loss: 0.0001956473, validation loss: 0.0001254030
# Epoch  52: train loss: 0.0001847195, validation loss: 0.0001130903
# Epoch  53: train loss: 0.0001767431, validation loss: 0.0001097790
# Epoch  54: train loss: 0.0001682329, validation loss: 0.0001030562
# Epoch  55: train loss: 0.0001590261, validation loss: 0.0000980747
# Epoch  56: train loss: 0.0001515983, validation loss: 0.0001018549
# Epoch  57: train loss: 0.0001447967, validation loss: 0.0000900796
# Epoch  58: train loss: 0.0001384367, validation loss: 0.0000848946
# Epoch  59: train loss: 0.0001320482, validation loss: 0.0000888637
# Epoch  60: train loss: 0.0001266165, validation loss: 0.0000780660
# Epoch  61: train loss: 0.0001217152, validation loss: 0.0000743156
# Epoch  62: train loss: 0.0001164122, validation loss: 0.0000727322
# Epoch  63: train loss: 0.0001125397, validation loss: 0.0000729747
# Epoch  64: train loss: 0.0001068613, validation loss: 0.0000664937
# Epoch  65: train loss: 0.0001033856, validation loss: 0.0000646507
# Epoch  66: train loss: 0.0001014962, validation loss: 0.0000626569
# Epoch  67: train loss: 0.0000967655, validation loss: 0.0000602494
# Epoch  68: train loss: 0.0000929193, validation loss: 0.0000592614
# Epoch  69: train loss: 0.0000900906, validation loss: 0.0000561811
# Epoch  70: train loss: 0.0000874679, validation loss: 0.0000601440
# Epoch  71: train loss: 0.0000845211, validation loss: 0.0000553886
# Epoch  72: train loss: 0.0000821144, validation loss: 0.0000572557
# Epoch  73: train loss: 0.0000791319, validation loss: 0.0000591947
# Epoch  74: train loss: 0.0000772771, validation loss: 0.0000497419
# Epoch  75: train loss: 0.0000759886, validation loss: 0.0000522141
# Epoch  76: train loss: 0.0000721830, validation loss: 0.0000468086
# Epoch  77: train loss: 0.0000702178, validation loss: 0.0000455281
# Epoch  78: train loss: 0.0000692630, validation loss: 0.0000512799
# Epoch  79: train loss: 0.0000670346, validation loss: 0.0000465984
# Epoch  80: train loss: 0.0000656624, validation loss: 0.0000454363
# Epoch  81: train loss: 0.0000625228, validation loss: 0.0000428390
# Epoch  82: train loss: 0.0000616856, validation loss: 0.0000444049
# Epoch  83: train loss: 0.0000597909, validation loss: 0.0000407855
# Epoch  84: train loss: 0.0000590286, validation loss: 0.0000508314
# Epoch  85: train loss: 0.0000572553, validation loss: 0.0000484004
# Epoch  86: train loss: 0.0000558108, validation loss: 0.0000404571
# Epoch  87: train loss: 0.0000549630, validation loss: 0.0000398075
# Epoch  88: train loss: 0.0000533787, validation loss: 0.0000353008
# Epoch  89: train loss: 0.0000507099, validation loss: 0.0000463640
# Epoch  90: train loss: 0.0000507539, validation loss: 0.0000373636
# Epoch  91: train loss: 0.0000497546, validation loss: 0.0000335530
# Epoch  92: train loss: 0.0000483588, validation loss: 0.0000304695
# Epoch  93: train loss: 0.0000473486, validation loss: 0.0000289044
# Epoch  94: train loss: 0.0000463941, validation loss: 0.0000291241
# Epoch  95: train loss: 0.0000452326, validation loss: 0.0000347218
# Epoch  96: train loss: 0.0000446979, validation loss: 0.0000402820
# Epoch  97: train loss: 0.0000434327, validation loss: 0.0000516482
# Epoch  98: train loss: 0.0000428952, validation loss: 0.0000276143
# Epoch  99: train loss: 0.0000416033, validation loss: 0.0000253181
# Epoch 100: train loss: 0.0000413331, validation loss: 0.0000294389
# Epoch 101: train loss: 0.0000403226, validation loss: 0.0000335464
# Epoch 102: train loss: 0.0000397212, validation loss: 0.0000246723
# Epoch 103: train loss: 0.0000389692, validation loss: 0.0000251819
# Epoch 104: train loss: 0.0000378719, validation loss: 0.0000250572
# Epoch 105: train loss: 0.0000372732, validation loss: 0.0000229509
# Epoch 106: train loss: 0.0000365428, validation loss: 0.0000225200
# Epoch 107: train loss: 0.0000355927, validation loss: 0.0000219501
# Epoch 108: train loss: 0.0000356404, validation loss: 0.0000242791
# Epoch 109: train loss: 0.0000350068, validation loss: 0.0000208154
# Epoch 110: train loss: 0.0000346282, validation loss: 0.0000217816
# Epoch 111: train loss: 0.0000330031, validation loss: 0.0000203625
# Epoch 112: train loss: 0.0000340280, validation loss: 0.0000277624
# Epoch 113: train loss: 0.0000319430, validation loss: 0.0000211721
# Epoch 114: train loss: 0.0000322006, validation loss: 0.0000198765
# Epoch 115: train loss: 0.0000314270, validation loss: 0.0000206550
# Epoch 116: train loss: 0.0000310162, validation loss: 0.0000249325
# Epoch 117: train loss: 0.0000302415, validation loss: 0.0000203727
# Epoch 118: train loss: 0.0000300358, validation loss: 0.0000288004
# Epoch 119: train loss: 0.0000301968, validation loss: 0.0000181595
# Epoch 120: train loss: 0.0000296745, validation loss: 0.0000189830
# Epoch 121: train loss: 0.0000289137, validation loss: 0.0000325532
# Epoch 122: train loss: 0.0000281443, validation loss: 0.0000177880
# Epoch 123: train loss: 0.0000277343, validation loss: 0.0000180561
# Epoch 124: train loss: 0.0000284438, validation loss: 0.0000188892
# Epoch 125: train loss: 0.0000263636, validation loss: 0.0000251662
# Epoch 126: train loss: 0.0000279286, validation loss: 0.0000157896
# Epoch 127: train loss: 0.0000259651, validation loss: 0.0000160703
# Epoch 128: train loss: 0.0000262618, validation loss: 0.0000186670
# Epoch 129: train loss: 0.0000256589, validation loss: 0.0000149939
# Epoch 130: train loss: 0.0000257259, validation loss: 0.0000206488
# Epoch 131: train loss: 0.0000251945, validation loss: 0.0000169969
# Epoch 132: train loss: 0.0000248979, validation loss: 0.0000147735
# Epoch 133: train loss: 0.0000248421, validation loss: 0.0000310377
# Epoch 134: train loss: 0.0000244878, validation loss: 0.0000148937
# Epoch 135: train loss: 0.0000238266, validation loss: 0.0000142526
# Epoch 136: train loss: 0.0000238192, validation loss: 0.0000153685
# Epoch 137: train loss: 0.0000238541, validation loss: 0.0000142794
# Epoch 138: train loss: 0.0000225946, validation loss: 0.0000135285
# Epoch 139: train loss: 0.0000227869, validation loss: 0.0000137081
# Epoch 140: train loss: 0.0000224891, validation loss: 0.0000128114
# Epoch 141: train loss: 0.0000229653, validation loss: 0.0000182880
# Epoch 142: train loss: 0.0000217143, validation loss: 0.0000131041
# Epoch 143: train loss: 0.0000218619, validation loss: 0.0000187189
# Epoch 144: train loss: 0.0000218950, validation loss: 0.0000125798
# Epoch 145: train loss: 0.0000215016, validation loss: 0.0000132921
# Epoch 146: train loss: 0.0000209550, validation loss: 0.0000223090
# Epoch 147: train loss: 0.0000211109, validation loss: 0.0000133720
# Epoch 148: train loss: 0.0000206284, validation loss: 0.0000143240
# Epoch 149: train loss: 0.0000207570, validation loss: 0.0000115275
# Epoch 150: train loss: 0.0000207202, validation loss: 0.0000114025
# Epoch 151: train loss: 0.0000193479, validation loss: 0.0000196725
# Epoch 152: train loss: 0.0000203212, validation loss: 0.0000141747
# Epoch 153: train loss: 0.0000197531, validation loss: 0.0000110272
# Epoch 154: train loss: 0.0000192478, validation loss: 0.0000217577
# Epoch 155: train loss: 0.0000187692, validation loss: 0.0000116078
# Epoch 156: train loss: 0.0000202367, validation loss: 0.0000113109
# Epoch 157: train loss: 0.0000179650, validation loss: 0.0000118817
# Epoch 158: train loss: 0.0000188769, validation loss: 0.0000118218
# Epoch 159: train loss: 0.0000186816, validation loss: 0.0000100856
# Epoch 160: train loss: 0.0000183107, validation loss: 0.0000130671
# Epoch 161: train loss: 0.0000182965, validation loss: 0.0000123189
# Epoch 162: train loss: 0.0000183455, validation loss: 0.0000105849
# Epoch 163: train loss: 0.0000183932, validation loss: 0.0000104582
# Epoch 164: train loss: 0.0000176180, validation loss: 0.0000113861
# Epoch 165: train loss: 0.0000173969, validation loss: 0.0000188423
# Epoch 166: train loss: 0.0000172916, validation loss: 0.0000153229
# Epoch 167: train loss: 0.0000174051, validation loss: 0.0000115191
# Epoch 168: train loss: 0.0000169179, validation loss: 0.0000122797
# Epoch 169: train loss: 0.0000169237, validation loss: 0.0000150871
# Epoch 170: train loss: 0.0000169890, validation loss: 0.0000133302
# Epoch 171: train loss: 0.0000167887, validation loss: 0.0000143124
# Epoch 172: train loss: 0.0000165587, validation loss: 0.0000090833
# Epoch 173: train loss: 0.0000165887, validation loss: 0.0000087284
# Epoch 174: train loss: 0.0000163295, validation loss: 0.0000083457
# Epoch 175: train loss: 0.0000164939, validation loss: 0.0000084811
# Epoch 176: train loss: 0.0000160045, validation loss: 0.0000143927
# Epoch 177: train loss: 0.0000160287, validation loss: 0.0000128598
# Epoch 178: train loss: 0.0000158230, validation loss: 0.0000111002
# Epoch 179: train loss: 0.0000153118, validation loss: 0.0000100312
# Epoch 180: train loss: 0.0000156464, validation loss: 0.0000118141
# Epoch 181: train loss: 0.0000157535, validation loss: 0.0000089765
# Epoch 182: train loss: 0.0000153268, validation loss: 0.0000088596
# Epoch 183: train loss: 0.0000151306, validation loss: 0.0000081489
# Epoch 184: train loss: 0.0000160332, validation loss: 0.0000079048
# Epoch 185: train loss: 0.0000144596, validation loss: 0.0000174740
# Epoch 186: train loss: 0.0000148794, validation loss: 0.0000115240
# Epoch 187: train loss: 0.0000153896, validation loss: 0.0000081769
# Epoch 188: train loss: 0.0000142974, validation loss: 0.0000133814
# Epoch 189: train loss: 0.0000146630, validation loss: 0.0000075693
# Epoch 190: train loss: 0.0000143320, validation loss: 0.0000102522
# Epoch 191: train loss: 0.0000147694, validation loss: 0.0000101584
# Epoch 192: train loss: 0.0000140773, validation loss: 0.0000092923
# Epoch 193: train loss: 0.0000141315, validation loss: 0.0000090628
# Epoch 194: train loss: 0.0000140503, validation loss: 0.0000072350
# Epoch 195: train loss: 0.0000143982, validation loss: 0.0000074502
# Epoch 196: train loss: 0.0000139344, validation loss: 0.0000074892
# Epoch 197: train loss: 0.0000144912, validation loss: 0.0000079966
# Epoch 198: train loss: 0.0000129357, validation loss: 0.0000076861
# Epoch 199: train loss: 0.0000138427, validation loss: 0.0000076663
# Epoch 200: train loss: 0.0000138455, validation loss: 0.0000149813
# Epoch 201: train loss: 0.0000137979, validation loss: 0.0000067752
# Epoch 202: train loss: 0.0000130843, validation loss: 0.0000223087
# Epoch 203: train loss: 0.0000135047, validation loss: 0.0000066992
# Epoch 204: train loss: 0.0000133221, validation loss: 0.0000083608
# Epoch 205: train loss: 0.0000131636, validation loss: 0.0000126455
# Epoch 206: train loss: 0.0000131555, validation loss: 0.0000109089
# Epoch 207: train loss: 0.0000127276, validation loss: 0.0000102115
# Epoch 208: train loss: 0.0000138315, validation loss: 0.0000066354
# Epoch 209: train loss: 0.0000123703, validation loss: 0.0000064173
# Epoch 210: train loss: 0.0000125597, validation loss: 0.0000066052
# Epoch 211: train loss: 0.0000130027, validation loss: 0.0000094778
# Epoch 212: train loss: 0.0000129339, validation loss: 0.0000067877
# Epoch 213: train loss: 0.0000125235, validation loss: 0.0000072238
# Epoch 214: train loss: 0.0000121135, validation loss: 0.0000207571
# Epoch 215: train loss: 0.0000128878, validation loss: 0.0000141644
# Epoch 216: train loss: 0.0000128532, validation loss: 0.0000070206
# Epoch 217: train loss: 0.0000119207, validation loss: 0.0000069060
# Epoch 218: train loss: 0.0000121294, validation loss: 0.0000169713
# Epoch 219: train loss: 0.0000123649, validation loss: 0.0000060231
# Epoch 220: train loss: 0.0000122147, validation loss: 0.0000067486
# Epoch 221: train loss: 0.0000121051, validation loss: 0.0000174344
# Epoch 222: train loss: 0.0000126917, validation loss: 0.0000143259
# Epoch 223: train loss: 0.0000118588, validation loss: 0.0000096632
# Epoch 224: train loss: 0.0000116929, validation loss: 0.0000096923
# Epoch 225: train loss: 0.0000119583, validation loss: 0.0000058458
# Epoch 226: train loss: 0.0000117792, validation loss: 0.0000058146
# Epoch 227: train loss: 0.0000118582, validation loss: 0.0000109936
# Epoch 228: train loss: 0.0000115337, validation loss: 0.0000099844
# Epoch 229: train loss: 0.0000115531, validation loss: 0.0000052673
# Epoch 230: train loss: 0.0000122202, validation loss: 0.0000056967
# Epoch 231: train loss: 0.0000112332, validation loss: 0.0000226462
# Epoch 232: train loss: 0.0000116989, validation loss: 0.0000056355
# Epoch 233: train loss: 0.0000107811, validation loss: 0.0000157115
# Epoch 234: train loss: 0.0000119430, validation loss: 0.0000123443
# Epoch 235: train loss: 0.0000111540, validation loss: 0.0000121560
# Epoch 236: train loss: 0.0000109354, validation loss: 0.0000057940
# Epoch 237: train loss: 0.0000118126, validation loss: 0.0000060902
# Epoch 238: train loss: 0.0000109301, validation loss: 0.0000056783
# Epoch 239: train loss: 0.0000112473, validation loss: 0.0000051529
# Epoch 240: train loss: 0.0000112111, validation loss: 0.0000053887
# Epoch 241: train loss: 0.0000116173, validation loss: 0.0000053245
# Epoch 242: train loss: 0.0000105914, validation loss: 0.0000077873
# Epoch 243: train loss: 0.0000111912, validation loss: 0.0000056215
# Epoch 244: train loss: 0.0000105151, validation loss: 0.0000155357
# Epoch 245: train loss: 0.0000111942, validation loss: 0.0000106243
# Epoch 246: train loss: 0.0000111554, validation loss: 0.0000082161
# Epoch 247: train loss: 0.0000106947, validation loss: 0.0000055057
# Epoch 248: train loss: 0.0000108385, validation loss: 0.0000187320
# Epoch 249: train loss: 0.0000105511, validation loss: 0.0000063700
# Epoch 250: train loss: 0.0000107173, validation loss: 0.0000153248
# Epoch 251: train loss: 0.0000102538, validation loss: 0.0000128252
# Epoch 252: train loss: 0.0000105546, validation loss: 0.0000057210
# Epoch 253: train loss: 0.0000108914, validation loss: 0.0000106550
# Epoch 254: train loss: 0.0000104837, validation loss: 0.0000120406
# Epoch 255: train loss: 0.0000104499, validation loss: 0.0000218185
# Epoch 256: train loss: 0.0000104637, validation loss: 0.0000063618
# Epoch 257: train loss: 0.0000103416, validation loss: 0.0000063042
# Epoch 258: train loss: 0.0000103111, validation loss: 0.0000045043
# Epoch 259: train loss: 0.0000103982, validation loss: 0.0000059301
# Epoch 260: train loss: 0.0000101803, validation loss: 0.0000048818
# Epoch 261: train loss: 0.0000105242, validation loss: 0.0000058668
# Epoch 262: train loss: 0.0000099370, validation loss: 0.0000051191
# Epoch 263: train loss: 0.0000103425, validation loss: 0.0000134792
# Epoch 264: train loss: 0.0000101401, validation loss: 0.0000121499
# Epoch 265: train loss: 0.0000097851, validation loss: 0.0000076693
# Epoch 266: train loss: 0.0000100410, validation loss: 0.0000264454
# Epoch 267: train loss: 0.0000098072, validation loss: 0.0000056492
# Epoch 268: train loss: 0.0000107596, validation loss: 0.0000046474
# Epoch 269: train loss: 0.0000095574, validation loss: 0.0000049275
# Epoch 270: train loss: 0.0000099545, validation loss: 0.0000050316
# Epoch 271: train loss: 0.0000096564, validation loss: 0.0000085176
# Epoch 272: train loss: 0.0000099910, validation loss: 0.0000102530
# Epoch 273: train loss: 0.0000099431, validation loss: 0.0000072686
# Epoch 274: train loss: 0.0000098110, validation loss: 0.0000046775
# Epoch 275: train loss: 0.0000093529, validation loss: 0.0000048813
# Epoch 276: train loss: 0.0000102636, validation loss: 0.0000043020
# Epoch 277: train loss: 0.0000093796, validation loss: 0.0000058157
# Epoch 278: train loss: 0.0000095048, validation loss: 0.0000050225
# Epoch 279: train loss: 0.0000098682, validation loss: 0.0000105980
# Epoch 280: train loss: 0.0000092499, validation loss: 0.0000069557
# Epoch 281: train loss: 0.0000096478, validation loss: 0.0000082866
# Epoch 282: train loss: 0.0000096023, validation loss: 0.0000151106
# Epoch 283: train loss: 0.0000095077, validation loss: 0.0000043005
# Epoch 284: train loss: 0.0000095008, validation loss: 0.0000080483
# Epoch 285: train loss: 0.0000097070, validation loss: 0.0000040845
# Epoch 286: train loss: 0.0000098551, validation loss: 0.0000071869
# Epoch 287: train loss: 0.0000090699, validation loss: 0.0000040808
# Epoch 288: train loss: 0.0000090418, validation loss: 0.0000038794
# Epoch 289: train loss: 0.0000095364, validation loss: 0.0000148923
# Epoch 290: train loss: 0.0000092508, validation loss: 0.0000268622
# Epoch 291: train loss: 0.0000092475, validation loss: 0.0000041552
# Epoch 292: train loss: 0.0000091278, validation loss: 0.0000063068
# Epoch 293: train loss: 0.0000095358, validation loss: 0.0000045022
# Epoch 294: train loss: 0.0000089774, validation loss: 0.0000076642
# Epoch 295: train loss: 0.0000091451, validation loss: 0.0000050662
# Epoch 296: train loss: 0.0000090986, validation loss: 0.0000068530
# Epoch 297: train loss: 0.0000090994, validation loss: 0.0000051712
# Epoch 298: train loss: 0.0000093313, validation loss: 0.0000043924
# Epoch 299: train loss: 0.0000087385, validation loss: 0.0000046803
# Epoch 300: train loss: 0.0000091240, validation loss: 0.0000131057
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Learned Model Parameters

# %% [markdown]
# ## Bilinear Model Parameters

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (23, 23) (23, 1) (2, 23)

# %%
#check controllability
Con = ct.ctrb(A, B)
np.linalg.matrix_rank(Con)
# Out:
# 8

# %% [markdown]
# ## Lifting function

# %% [markdown]
# # Testing

# %% [markdown]
# ## Parameters

# %%
# test data parameters
num_snaps_test = 2000 # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)
num_traj_test = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ## Testing Data

# %%
x_changed_test, x_unchanged_test, u_test = dynamics_duff(dt, num_traj_test, num_snaps_test,num_states, num_inputs, dyn_pars)
print(model_koop_dnn.test_loss(x_unchanged_test,u_test = u_test))
# Out:
# tensor(0.0373)

# %%
x_unchanged_test.shape
# Out:
# (1, 2001, 2)

# %%
# Use the preprocessing if available
X_unchanged,_ = model_koop_dnn.net.process(x_unchanged_test,data_u = u_test)
X_changed,_ = model_koop_dnn.net.process(x_changed_test,data_u = u_test)

# %%
X_changed.shape
# Out:
# (2000, 5)

# %%
# flatten vector
x_unchanged = X_unchanged[:, :num_states]
u = X_unchanged[:, num_states:num_states+num_inputs]
x_unchanged_prime = X_unchanged[:,num_states+num_inputs:]

x_changed = X_changed[:, :num_states]
x_changed_prime = X_changed[:,num_states+num_inputs:]

x_changed_dot = (x_changed_prime-x_changed)/dt
print(x_changed.shape, u.shape, x_changed_prime.shape)
# Out:
# (2000, 2) (2000, 1) (2000, 2)

# %% [markdown]
# # Lifting of states

# %%
# initialize states
# initialize the matricies
z_unchanged = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_unchanged_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values

# %%
# actual lift
z_unchanged[0,:] = lift(x_unchanged[0,:],model_koop_dnn, net_params)
x_unchanged_est[0,:] = x_unchanged[0,:]

# %% [markdown]
# # Time Evolution

# %%
for i in range(num_snaps_test):
  #bilinear
    z_unchanged[i+1,:] = np.matmul(z_unchanged[i,:],A.T)+np.matmul(u[i,:],B.T)
    x_unchanged_est[i+1,:] = np.matmul(z_unchanged[i+1,:],C.T)

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lifting performance

# %%
plt.figure()
plt.plot(T_test[:-1], x_unchanged[:,0],label ='Test unchanged data')
plt.plot(T_test, x_unchanged_est[:,0],label = 'estimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ### Error Evolution

# %%
error_model = np.linalg.norm((x_unchanged_est[:-1,:]-x_unchanged[:,:]),axis=1)
error_dynamics_no_adapt = np.linalg.norm((x_changed[:,:]-x_unchanged[:,:]),axis=1)

# %%
plt.figure()
plt.plot(T_test[:-1],error_model)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Model error evolution')
plt.show()

# %% [markdown]
# ## Deviation from Actual Dynamics

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data (changed dynamics)')
plt.plot(T_test[:-1],x_unchanged[:,0],label ='Test data (unchanged dynamics)')
plt.plot(T_test,x_unchanged_est[:,0],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data (changed model)')
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data (unchanged model)')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data (changed dyn)')
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data (unchanged dyn)')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],error_dynamics_no_adapt)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Dynamics error evolution')
plt.show()

# %% [markdown]
# # Adaptation

# %% [markdown]
# ## Data Preprocessing

# %%
# initialize state matricies
z_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
z_changed = np.empty((n_obs,num_snaps_test)).T #actual lifted state
del_z_prime = np.empty((n_obs,num_snaps_test)).T
zu_unchanged = np.empty((n_obs*num_inputs,num_snaps_test)).T
x_adap_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values
del_A_norm = np.zeros((num_snaps_test,1))
del_B_norm = np.zeros((num_snaps_test,1))
# initialize
z_adap[0,:] = z_unchanged[0,:]
zu_unchanged[0,:] = np.kron(u[0,:],z_unchanged[0,:])
x_adap_est[0,:] = x_unchanged[0,:]

#
adap_window = 1 #hyperparameter

# %% [markdown]
# # Adaptive Time evolution

# %%
adapt_net_params = {}
adapt_net_params['state_dim'] = num_states
adapt_net_params['ctrl_dim'] = num_inputs
adapt_net_params['lift_dim'] = 20
adapt_net_params['optimizer'] = 'adam'
adapt_net_params['lr'] = 5e-4 # 5e-4
adapt_net_params['epochs'] = 8
adapt_net_params['batch_size'] = adap_window
adapt_net_params['l2_reg'] = 0.0
adapt_net_params['l1_reg'] = 1e-3
adapt_net_params['first_obs_const'] = net_params["first_obs_const"]
adapt_net_params['override_C'] = net_params["override_C"] # this makes the state a part of lifted state
adapt_net_params['warm_start'] = False # this makes the state a part of lifted state


del_A = np.zeros_like(A)
del_B = np.zeros_like(B)
for i in range(num_snaps_test):
  # incorrect dynamics
    zu_unchanged[i,:] = np.kron(u[i,:],z_adap[i,:])
    z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T + del_A.T)+np.matmul(zu_unchanged[i,:],B.T + del_B.T)
    # z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T)+np.matmul(zu_unchanged[i,:],B.T)
    
    z_changed[i,:] = lift(x_changed[i,:],model_koop_dnn, net_params)
    
    del_z_prime[i,:] = z_changed[i,:] - z_unchanged[i,:]
    if i < adap_window + 1 :
        del_A = np.zeros_like(A)
        del_B = np.zeros_like(B)
    else:
        del_Z_prime = del_z_prime[i-adap_window:i,:].T
        Z_unchanged = z_unchanged[i-(adap_window+1):i-1].T
        ZU_unchanged = zu_unchanged[i-(adap_window+1):i-1].T

        #invoke neural net for adapation
        adapt_network = AdaptNet(adapt_net_params)
        adapt_network.model_pipeline(Z_unchanged, ZU_unchanged, del_Z_prime, print_epoch = True)

        del_A, del_B = adapt_network.get_del_matrices()

    del_A_norm[i] = np.linalg.norm(del_A)
    del_B_norm[i] = np.linalg.norm(del_B)
    
    # adapted model
    z_adap[i+1,:] = np.matmul(z_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_adap[i,:]), B + del_B.T )
    x_adap_est[i+1,:] = np.matmul(z_adap[i+1,:],C.T)

# %%
A.T.shape, del_A.shape

# %% [markdown]
# # Performance Plotting

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,0],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,0],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.pdf')

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,1],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.pdf')

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(x_adap_est[:,0],x_adap_est[:,1],label = 'estimated (adapt)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.pdf')

# %% [markdown]
# # Error Comparisons

# %%
error_dynamics_adap = np.linalg.norm((x_adap_est[:-1,:]-x_changed[:,:]), axis=1)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in Adaptive Model")
axs[1].set_title("Error in Non-Adaptive Model")

axs[0].set(xlabel = 't', ylabel = 'error')
axs[1].set(xlabel = 't', ylabel = 'error')


axs[0].plot(T_test[:-1],error_dynamics_adap)

axs[1].plot(T_test[:-1],error_dynamics_no_adapt)

plt.savefig('adap_error_comp.pdf')

# %% [markdown]
# ## Norm evolutions

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
np.linalg.norm(A)
