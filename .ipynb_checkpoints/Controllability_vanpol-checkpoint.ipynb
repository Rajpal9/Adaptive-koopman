# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

# linear Koopman
from core.koopman_core_linear import KoopDNN as KoopDNN_lin
from core.koopman_core_linear import KoopmanNet as KoopmanNet_lin
from core.koopman_core_linear import KoopmanNetCtrl as KoopmanNetCtrl_lin


# models
from models.koop_model import model_matricies,lift
from dynamics.Vanpol import dynamics_vanpol_data_gen, dynamics_vanpol

## utilities
from core.utility import Output_Con
import control as ct

## OSQP terms
import osqp
import numpy as np
import scipy as sp
from scipy import sparse

## linear Model
from control_files.nmpc_osqp import NonlinearMPCController
from dynamics.learned_models_control.linear_dynamics import linear_Dynamics

# %%
# Base Parameters
dt = 0.01 #time step
num_snaps = 2000 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 200 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 2 # no. of states
num_inputs = 1 # no. of inputs

# %%
# Oscillator parameters
dyn_pars = {}

dyn_pars['a'] = 1
dyn_pars['b'] = 4
dyn_pars['c'] = 0.5
dyn_pars['d'] = 0.5

dyn_pars['del_a'] = 0.0
dyn_pars['del_b'] = 0.0
dyn_pars['del_c'] = 0.0
dyn_pars['del_d'] = 0.0
dyn_pars['delay'] = False
dyn_pars['delay_time'] = 5
dyn_pars['cont_unc_type'] = 'sinusoidal'

# %%
_, X, U = dynamics_vanpol_data_gen(dt, num_traj, num_snaps, num_states, num_inputs, dyn_pars)

print(X.shape, U.shape)
# Out:
# (250, 2001, 2) (250, 2000, 1)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X)))))
# Out:
# 0

# %%
# plot dataset
plt.figure()
plt.title("Phase plot for Vanpol dynamics")
plt.xlabel('x1') 
plt.ylabel('x2')

for i in range(num_traj):
    plt.plot(X[i,:,0], X[i,:,1])

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("position")
axs[1].set_title("velocity")

axs[0].set(xlabel = 't', ylabel = 'x1')
axs[1].set(xlabel = 't', ylabel = 'x2')


axs[0].plot(T, X[4,:,0])

axs[1].plot(T, X[4,:,1])

# %%
# split training and vaidation datasets
xs_train, us_train = X[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X[num_train:,:,:],U[num_train:,:,:]

# %%
# auto encoder parameters for linear

net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 2e-4 # 5e-4
net_params['epochs'] = 300
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = False # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
## linear model Training
train = True

if train == True:
    file = 'saved_models/learned_models/linear_model/vanpol_lin_control_no_state.pth'
    net_lin = KoopmanNetCtrl_lin(net_params)
    model_koop_dnn_lin = KoopDNN_lin(net_lin)
    model_koop_dnn_lin.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn_lin.model_pipeline(net_params)
    model_koop_dnn_lin.construct_koopman_model()
    torch.save(model_koop_dnn_lin,file)
else:
    file = 'saved_models/learned_models/linear_model/vanpol_lin_control_state_no_state.pth'
    model_koop_dnn_lin = torch.load(file)
# Out:
# Epoch   1: train loss: 0.4215426147, validation loss: 0.1104853384
# Epoch   2: train loss: 0.0621109046, validation loss: 0.0356849288
# Epoch   3: train loss: 0.0247332081, validation loss: 0.0164138908
# Epoch   4: train loss: 0.0124206189, validation loss: 0.0090839745
# Epoch   5: train loss: 0.0069792760, validation loss: 0.0051887737
# Epoch   6: train loss: 0.0042449324, validation loss: 0.0033433414
# Epoch   7: train loss: 0.0027523329, validation loss: 0.0022863899
# Epoch   8: train loss: 0.0019074180, validation loss: 0.0016249973
# Epoch   9: train loss: 0.0014475194, validation loss: 0.0011940456
# Epoch  10: train loss: 0.0011908630, validation loss: 0.0009912022
# Epoch  11: train loss: 0.0010355531, validation loss: 0.0008945492
# Epoch  12: train loss: 0.0009431315, validation loss: 0.0008105920
# Epoch  13: train loss: 0.0008770603, validation loss: 0.0007171104
# Epoch  14: train loss: 0.0008373819, validation loss: 0.0008053146
# Epoch  15: train loss: 0.0007864009, validation loss: 0.0007495963
# Epoch  16: train loss: 0.0007647570, validation loss: 0.0006083242
# Epoch  17: train loss: 0.0007345818, validation loss: 0.0006748643
# Epoch  18: train loss: 0.0007168560, validation loss: 0.0005895815
# Epoch  19: train loss: 0.0006929761, validation loss: 0.0005252523
# Epoch  20: train loss: 0.0006754084, validation loss: 0.0009205357
# Epoch  21: train loss: 0.0006657910, validation loss: 0.0005679471
# Epoch  22: train loss: 0.0006485654, validation loss: 0.0005145498
# Epoch  23: train loss: 0.0006396088, validation loss: 0.0005483752
# Epoch  24: train loss: 0.0006179815, validation loss: 0.0005252374
# Epoch  25: train loss: 0.0006163763, validation loss: 0.0006239156
# Epoch  26: train loss: 0.0006059869, validation loss: 0.0006248383
# Epoch  27: train loss: 0.0005975342, validation loss: 0.0004304122
# Epoch  28: train loss: 0.0005900545, validation loss: 0.0004067116
# Epoch  29: train loss: 0.0005854057, validation loss: 0.0006023280
# Epoch  30: train loss: 0.0005737726, validation loss: 0.0006170034
# Epoch  31: train loss: 0.0005736833, validation loss: 0.0015344108
# Epoch  32: train loss: 0.0005604377, validation loss: 0.0003771033
# Epoch  33: train loss: 0.0005606813, validation loss: 0.0006817886
# Epoch  34: train loss: 0.0005578746, validation loss: 0.0004158761
# Epoch  35: train loss: 0.0005436038, validation loss: 0.0004432812
# Epoch  36: train loss: 0.0005458739, validation loss: 0.0003747250
# Epoch  37: train loss: 0.0005380184, validation loss: 0.0003634716
# Epoch  38: train loss: 0.0005374548, validation loss: 0.0004589076
# Epoch  39: train loss: 0.0005275752, validation loss: 0.0003458856
# Epoch  40: train loss: 0.0005240546, validation loss: 0.0003431853
# Epoch  41: train loss: 0.0005223163, validation loss: 0.0005711318
# Epoch  42: train loss: 0.0005173546, validation loss: 0.0003479145
# Epoch  43: train loss: 0.0005157618, validation loss: 0.0003918779
# Epoch  44: train loss: 0.0005102316, validation loss: 0.0003366382
# Epoch  45: train loss: 0.0005088410, validation loss: 0.0006522950
# Epoch  46: train loss: 0.0005044723, validation loss: 0.0004144159
# Epoch  47: train loss: 0.0005010094, validation loss: 0.0003550380
# Epoch  48: train loss: 0.0005009971, validation loss: 0.0003730762
# Epoch  49: train loss: 0.0004872045, validation loss: 0.0007931627
# Epoch  50: train loss: 0.0004960868, validation loss: 0.0006697313
# Epoch  51: train loss: 0.0004849780, validation loss: 0.0003586652
# Epoch  52: train loss: 0.0004864853, validation loss: 0.0003498460
# Epoch  53: train loss: 0.0004847367, validation loss: 0.0003356352
# Epoch  54: train loss: 0.0004782745, validation loss: 0.0003034264
# Epoch  55: train loss: 0.0004843143, validation loss: 0.0005083490
# Epoch  56: train loss: 0.0004802230, validation loss: 0.0003101046
# Epoch  57: train loss: 0.0004665844, validation loss: 0.0011854223
# Epoch  58: train loss: 0.0004736617, validation loss: 0.0004048204
# Epoch  59: train loss: 0.0004662021, validation loss: 0.0002872526
# Epoch  60: train loss: 0.0004622686, validation loss: 0.0002896558
# Epoch  61: train loss: 0.0004682894, validation loss: 0.0006308489
# Epoch  62: train loss: 0.0004628661, validation loss: 0.0003715659
# Epoch  63: train loss: 0.0004558071, validation loss: 0.0002958500
# Epoch  64: train loss: 0.0004576723, validation loss: 0.0003212345
# Epoch  65: train loss: 0.0004602665, validation loss: 0.0005590673
# Epoch  66: train loss: 0.0004542754, validation loss: 0.0002739177
# Epoch  67: train loss: 0.0004449775, validation loss: 0.0002816894
# Epoch  68: train loss: 0.0004501489, validation loss: 0.0003318215
# Epoch  69: train loss: 0.0004498859, validation loss: 0.0004745244
# Epoch  70: train loss: 0.0004435976, validation loss: 0.0002874203
# Epoch  71: train loss: 0.0004416323, validation loss: 0.0003757707
# Epoch  72: train loss: 0.0004376351, validation loss: 0.0003120673
# Epoch  73: train loss: 0.0004398345, validation loss: 0.0003173965
# Epoch  74: train loss: 0.0004338837, validation loss: 0.0003625701
# Epoch  75: train loss: 0.0004368646, validation loss: 0.0002591862
# Epoch  76: train loss: 0.0004314746, validation loss: 0.0004247444
# Epoch  77: train loss: 0.0004271900, validation loss: 0.0005614374
# Epoch  78: train loss: 0.0004258360, validation loss: 0.0003743622
# Epoch  79: train loss: 0.0004267988, validation loss: 0.0002514621
# Epoch  80: train loss: 0.0004228009, validation loss: 0.0002652716
# Epoch  81: train loss: 0.0004220507, validation loss: 0.0008973527
# Epoch  82: train loss: 0.0004210788, validation loss: 0.0003891094
# Epoch  83: train loss: 0.0004169944, validation loss: 0.0005241303
# Epoch  84: train loss: 0.0004217193, validation loss: 0.0002474463
# Epoch  85: train loss: 0.0004148256, validation loss: 0.0002613564
# Epoch  86: train loss: 0.0004176045, validation loss: 0.0003243852
# Epoch  87: train loss: 0.0004088638, validation loss: 0.0003452526
# Epoch  88: train loss: 0.0004157879, validation loss: 0.0002790501
# Epoch  89: train loss: 0.0004151652, validation loss: 0.0002341739
# Epoch  90: train loss: 0.0004064962, validation loss: 0.0002295853
# Epoch  91: train loss: 0.0004166269, validation loss: 0.0004872883
# Epoch  92: train loss: 0.0004044588, validation loss: 0.0002408694
# Epoch  93: train loss: 0.0004092444, validation loss: 0.0005205447
# Epoch  94: train loss: 0.0004078083, validation loss: 0.0004509134
# Epoch  95: train loss: 0.0004030582, validation loss: 0.0002720438
# Epoch  96: train loss: 0.0003964507, validation loss: 0.0002568511
# Epoch  97: train loss: 0.0003994391, validation loss: 0.0003790814
# Epoch  98: train loss: 0.0004010757, validation loss: 0.0002319914
# Epoch  99: train loss: 0.0004001938, validation loss: 0.0002276159
# Epoch 100: train loss: 0.0003945538, validation loss: 0.0002900970
# Epoch 101: train loss: 0.0003991042, validation loss: 0.0003678520
# Epoch 102: train loss: 0.0003958023, validation loss: 0.0003962635
# Epoch 103: train loss: 0.0003933003, validation loss: 0.0003320567
# Epoch 104: train loss: 0.0003925936, validation loss: 0.0004630695
# Epoch 105: train loss: 0.0003916699, validation loss: 0.0002333150
# Epoch 106: train loss: 0.0003919661, validation loss: 0.0004005508
# Epoch 107: train loss: 0.0003830635, validation loss: 0.0002171585
# Epoch 108: train loss: 0.0003868337, validation loss: 0.0002220780
# Epoch 109: train loss: 0.0003863352, validation loss: 0.0002531883
# Epoch 110: train loss: 0.0003844109, validation loss: 0.0012794213
# Epoch 111: train loss: 0.0003867365, validation loss: 0.0022090291
# Epoch 112: train loss: 0.0003820800, validation loss: 0.0002095455
# Epoch 113: train loss: 0.0003823443, validation loss: 0.0002083271
# Epoch 114: train loss: 0.0003782875, validation loss: 0.0002168079
# Epoch 115: train loss: 0.0003856121, validation loss: 0.0006000438
# Epoch 116: train loss: 0.0003780697, validation loss: 0.0004826827
# Epoch 117: train loss: 0.0003803266, validation loss: 0.0002136216
# Epoch 118: train loss: 0.0003700846, validation loss: 0.0006132030
# Epoch 119: train loss: 0.0003747370, validation loss: 0.0003048845
# Epoch 120: train loss: 0.0003754074, validation loss: 0.0007008923
# Epoch 121: train loss: 0.0003746998, validation loss: 0.0008308670
# Epoch 122: train loss: 0.0003672602, validation loss: 0.0002537003
# Epoch 123: train loss: 0.0003752847, validation loss: 0.0002081474
# Epoch 124: train loss: 0.0003659972, validation loss: 0.0002038375
# Epoch 125: train loss: 0.0003684433, validation loss: 0.0002367836
# Epoch 126: train loss: 0.0003665679, validation loss: 0.0010601695
# Epoch 127: train loss: 0.0003703277, validation loss: 0.0001984673
# Epoch 128: train loss: 0.0003593248, validation loss: 0.0003235600
# Epoch 129: train loss: 0.0003654660, validation loss: 0.0002269596
# Epoch 130: train loss: 0.0003649055, validation loss: 0.0002459753
# Epoch 131: train loss: 0.0003629511, validation loss: 0.0002011700
# Epoch 132: train loss: 0.0003588779, validation loss: 0.0004017362
# Epoch 133: train loss: 0.0003555891, validation loss: 0.0018021761
# Epoch 134: train loss: 0.0003599576, validation loss: 0.0002368963
# Epoch 135: train loss: 0.0003611577, validation loss: 0.0002668430
# Epoch 136: train loss: 0.0003499053, validation loss: 0.0002634879
# Epoch 137: train loss: 0.0003537302, validation loss: 0.0003612998
# Epoch 138: train loss: 0.0003585552, validation loss: 0.0002847194
# Epoch 139: train loss: 0.0003598232, validation loss: 0.0002036247
# Epoch 140: train loss: 0.0003456612, validation loss: 0.0011301494
# Epoch 141: train loss: 0.0003507041, validation loss: 0.0002151213
# Epoch 142: train loss: 0.0003490631, validation loss: 0.0002350886
# Epoch 143: train loss: 0.0003491546, validation loss: 0.0003759966
# Epoch 144: train loss: 0.0003466136, validation loss: 0.0002090746
# Epoch 145: train loss: 0.0003462324, validation loss: 0.0002273017
# Epoch 146: train loss: 0.0003529238, validation loss: 0.0001864682
# Epoch 147: train loss: 0.0003435003, validation loss: 0.0002891298
# Epoch 148: train loss: 0.0003365317, validation loss: 0.0003379005
# Epoch 149: train loss: 0.0003443590, validation loss: 0.0002402908
# Epoch 150: train loss: 0.0003441774, validation loss: 0.0003303937
# Epoch 151: train loss: 0.0003403057, validation loss: 0.0003988023
# Epoch 152: train loss: 0.0003404009, validation loss: 0.0002089873
# Epoch 153: train loss: 0.0003320339, validation loss: 0.0004393481
# Epoch 154: train loss: 0.0003392203, validation loss: 0.0003744010
# Epoch 155: train loss: 0.0003365469, validation loss: 0.0003230945
# Epoch 156: train loss: 0.0003402939, validation loss: 0.0004024557
# Epoch 157: train loss: 0.0003291099, validation loss: 0.0002065347
# Epoch 158: train loss: 0.0003388873, validation loss: 0.0002083367
# Epoch 159: train loss: 0.0003259978, validation loss: 0.0001959021
# Epoch 160: train loss: 0.0003305187, validation loss: 0.0001853967
# Epoch 161: train loss: 0.0003312849, validation loss: 0.0004718955
# Epoch 162: train loss: 0.0003306814, validation loss: 0.0002311062
# Epoch 163: train loss: 0.0003316772, validation loss: 0.0004016399
# Epoch 164: train loss: 0.0003287617, validation loss: 0.0006266753
# Epoch 165: train loss: 0.0003238549, validation loss: 0.0001864367
# Epoch 166: train loss: 0.0003243220, validation loss: 0.0002621854
# Epoch 167: train loss: 0.0003211976, validation loss: 0.0001748166
# Epoch 168: train loss: 0.0003234139, validation loss: 0.0006551058
# Epoch 169: train loss: 0.0003202622, validation loss: 0.0001728169
# Epoch 170: train loss: 0.0003173960, validation loss: 0.0001849162
# Epoch 171: train loss: 0.0003212867, validation loss: 0.0003677428
# Epoch 172: train loss: 0.0003204278, validation loss: 0.0003625283
# Epoch 173: train loss: 0.0003178759, validation loss: 0.0001865708
# Epoch 174: train loss: 0.0003199715, validation loss: 0.0001684366
# Epoch 175: train loss: 0.0003128360, validation loss: 0.0001738828
# Epoch 176: train loss: 0.0003148753, validation loss: 0.0002549826
# Epoch 177: train loss: 0.0003158358, validation loss: 0.0003178896
# Epoch 178: train loss: 0.0003119647, validation loss: 0.0002663920
# Epoch 179: train loss: 0.0003102652, validation loss: 0.0002475019
# Epoch 180: train loss: 0.0003127987, validation loss: 0.0004754790
# Epoch 181: train loss: 0.0003100244, validation loss: 0.0002477401
# Epoch 182: train loss: 0.0003064394, validation loss: 0.0003053910
# Epoch 183: train loss: 0.0003099630, validation loss: 0.0001723231
# Epoch 184: train loss: 0.0003053203, validation loss: 0.0002742297
# Epoch 185: train loss: 0.0003084157, validation loss: 0.0001693113
# Epoch 186: train loss: 0.0003037192, validation loss: 0.0001821432
# Epoch 187: train loss: 0.0003008295, validation loss: 0.0003538650
# Epoch 188: train loss: 0.0003039125, validation loss: 0.0002231053
# Epoch 189: train loss: 0.0003031266, validation loss: 0.0001609726
# Epoch 190: train loss: 0.0002997626, validation loss: 0.0003403318
# Epoch 191: train loss: 0.0003015675, validation loss: 0.0003546849
# Epoch 192: train loss: 0.0002993681, validation loss: 0.0002383961
# Epoch 193: train loss: 0.0002958261, validation loss: 0.0002719138
# Epoch 194: train loss: 0.0002928861, validation loss: 0.0007244834
# Epoch 195: train loss: 0.0002970762, validation loss: 0.0002183242
# Epoch 196: train loss: 0.0002936933, validation loss: 0.0005953116
# Epoch 197: train loss: 0.0002908692, validation loss: 0.0001546958
# Epoch 198: train loss: 0.0002981383, validation loss: 0.0001795005
# Epoch 199: train loss: 0.0002874303, validation loss: 0.0008897379
# Epoch 200: train loss: 0.0002931930, validation loss: 0.0003913283
# Epoch 201: train loss: 0.0002852205, validation loss: 0.0003330077
# Epoch 202: train loss: 0.0002938838, validation loss: 0.0002951573
# Epoch 203: train loss: 0.0002812697, validation loss: 0.0004953629
# Epoch 204: train loss: 0.0002840152, validation loss: 0.0004224205
# Epoch 205: train loss: 0.0002880299, validation loss: 0.0002335248
# Epoch 206: train loss: 0.0002784467, validation loss: 0.0003517866
# Epoch 207: train loss: 0.0002836448, validation loss: 0.0001530706
# Epoch 208: train loss: 0.0002775560, validation loss: 0.0001798638
# Epoch 209: train loss: 0.0002799671, validation loss: 0.0001517635
# Epoch 210: train loss: 0.0002778914, validation loss: 0.0001981278
# Epoch 211: train loss: 0.0002767407, validation loss: 0.0001703068
# Epoch 212: train loss: 0.0002759494, validation loss: 0.0003754345
# Epoch 213: train loss: 0.0002779986, validation loss: 0.0002547404
# Epoch 214: train loss: 0.0002712537, validation loss: 0.0004935203
# Epoch 215: train loss: 0.0002708073, validation loss: 0.0007497846
# Epoch 216: train loss: 0.0002706368, validation loss: 0.0005060001
# Epoch 217: train loss: 0.0002694481, validation loss: 0.0001978315
# Epoch 218: train loss: 0.0002680822, validation loss: 0.0002685046
# Epoch 219: train loss: 0.0002654363, validation loss: 0.0002784045
# Epoch 220: train loss: 0.0002721202, validation loss: 0.0001800013
# Epoch 221: train loss: 0.0002599847, validation loss: 0.0006792538
# Epoch 222: train loss: 0.0002659680, validation loss: 0.0004797286
# Epoch 223: train loss: 0.0002673393, validation loss: 0.0001499568
# Epoch 224: train loss: 0.0002615928, validation loss: 0.0003356514
# Epoch 225: train loss: 0.0002650676, validation loss: 0.0002186983
# Epoch 226: train loss: 0.0002588335, validation loss: 0.0002598410
# Epoch 227: train loss: 0.0002643148, validation loss: 0.0001771897
# Epoch 228: train loss: 0.0002582882, validation loss: 0.0001508163
# Epoch 229: train loss: 0.0002573020, validation loss: 0.0001522595
# Epoch 230: train loss: 0.0002578201, validation loss: 0.0006277286
# Epoch 231: train loss: 0.0002543745, validation loss: 0.0001404010
# Epoch 232: train loss: 0.0002589357, validation loss: 0.0003432958
# Epoch 233: train loss: 0.0002550189, validation loss: 0.0001454750
# Epoch 234: train loss: 0.0002510586, validation loss: 0.0001456789
# Epoch 235: train loss: 0.0002516751, validation loss: 0.0001932788
# Epoch 236: train loss: 0.0002512176, validation loss: 0.0007187481
# Epoch 237: train loss: 0.0002526466, validation loss: 0.0001910158
# Epoch 238: train loss: 0.0002532201, validation loss: 0.0001784302
# Epoch 239: train loss: 0.0002421003, validation loss: 0.0002929602
# Epoch 240: train loss: 0.0002505435, validation loss: 0.0002290201
# Epoch 241: train loss: 0.0002428932, validation loss: 0.0002925114
# Epoch 242: train loss: 0.0002458891, validation loss: 0.0001503168
# Epoch 243: train loss: 0.0002445111, validation loss: 0.0002158238
# Epoch 244: train loss: 0.0002433678, validation loss: 0.0001762204
# Epoch 245: train loss: 0.0002447559, validation loss: 0.0001398628
# Epoch 246: train loss: 0.0002382446, validation loss: 0.0001710808
# Epoch 247: train loss: 0.0002413109, validation loss: 0.0001622463
# Epoch 248: train loss: 0.0002386295, validation loss: 0.0002881188
# Epoch 249: train loss: 0.0002395569, validation loss: 0.0001511955
# Epoch 250: train loss: 0.0002371896, validation loss: 0.0003711823
# Epoch 251: train loss: 0.0002356328, validation loss: 0.0005237030
# Epoch 252: train loss: 0.0002348980, validation loss: 0.0001282186
# Epoch 253: train loss: 0.0002401482, validation loss: 0.0003066915
# Epoch 254: train loss: 0.0002301379, validation loss: 0.0001520454
# Epoch 255: train loss: 0.0002262242, validation loss: 0.0004031754
# Epoch 256: train loss: 0.0002353114, validation loss: 0.0002355257
# Epoch 257: train loss: 0.0002264763, validation loss: 0.0001366542
# Epoch 258: train loss: 0.0002317579, validation loss: 0.0003672858
# Epoch 259: train loss: 0.0002253547, validation loss: 0.0001563908
# Epoch 260: train loss: 0.0002252491, validation loss: 0.0002375465
# Epoch 261: train loss: 0.0002284236, validation loss: 0.0001954775
# Epoch 262: train loss: 0.0002226573, validation loss: 0.0001719566
# Epoch 263: train loss: 0.0002214588, validation loss: 0.0001370094
# Epoch 264: train loss: 0.0002215121, validation loss: 0.0001619182
# Epoch 265: train loss: 0.0002167448, validation loss: 0.0001265979
# Epoch 266: train loss: 0.0002194368, validation loss: 0.0001343215
# Epoch 267: train loss: 0.0002245714, validation loss: 0.0001211703
# Epoch 268: train loss: 0.0002119683, validation loss: 0.0001302508
# Epoch 269: train loss: 0.0002172654, validation loss: 0.0001299519
# Epoch 270: train loss: 0.0002159753, validation loss: 0.0001162204
# Epoch 271: train loss: 0.0002204444, validation loss: 0.0001632147
# Epoch 272: train loss: 0.0002084107, validation loss: 0.0001116207
# Epoch 273: train loss: 0.0002156309, validation loss: 0.0001171401
# Epoch 274: train loss: 0.0002105782, validation loss: 0.0003495005
# Epoch 275: train loss: 0.0002114883, validation loss: 0.0001304454
# Epoch 276: train loss: 0.0002099069, validation loss: 0.0001338410
# Epoch 277: train loss: 0.0002111592, validation loss: 0.0001130633
# Epoch 278: train loss: 0.0002076737, validation loss: 0.0001191506
# Epoch 279: train loss: 0.0002085902, validation loss: 0.0001407175
# Epoch 280: train loss: 0.0002078690, validation loss: 0.0003239800
# Epoch 281: train loss: 0.0002025395, validation loss: 0.0003135383
# Epoch 282: train loss: 0.0002035744, validation loss: 0.0001253921
# Epoch 283: train loss: 0.0002038182, validation loss: 0.0001203070
# Epoch 284: train loss: 0.0001998540, validation loss: 0.0001050947
# Epoch 285: train loss: 0.0002029262, validation loss: 0.0010071799
# Epoch 286: train loss: 0.0002044973, validation loss: 0.0004081935
# Epoch 287: train loss: 0.0001950837, validation loss: 0.0001135408
# Epoch 288: train loss: 0.0001998021, validation loss: 0.0001173657
# Epoch 289: train loss: 0.0002023601, validation loss: 0.0001682717
# Epoch 290: train loss: 0.0001967525, validation loss: 0.0001720858
# Epoch 291: train loss: 0.0002005113, validation loss: 0.0005695482
# Epoch 292: train loss: 0.0001950044, validation loss: 0.0001110894
# Epoch 293: train loss: 0.0001936224, validation loss: 0.0001224912
# Epoch 294: train loss: 0.0001967364, validation loss: 0.0001220475
# Epoch 295: train loss: 0.0001929621, validation loss: 0.0001110957
# Epoch 296: train loss: 0.0001948315, validation loss: 0.0005634740
# Epoch 297: train loss: 0.0001919275, validation loss: 0.0001352752
# Epoch 298: train loss: 0.0002026098, validation loss: 0.0001024723
# Epoch 299: train loss: 0.0001840971, validation loss: 0.0003813393
# Epoch 300: train loss: 0.0001916081, validation loss: 0.0001048302
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn_lin.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn_lin.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn_lin.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn_lin.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn_lin.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn_lin.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Learned Model Parameters

# %% [markdown]
# ## linear Model Parameters

# %%
A = np.array(model_koop_dnn_lin.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn_lin.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn_lin.C)

print(A.shape, B.shape, C.shape)
# Out:
# (21, 21) (21, 1) (2, 21)

# %% [markdown]
# ## Controllabilty

# %%
# define no of observables
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const 

## convert matricies to continious forms
Ac = (A-np.eye(n_obs))/dt
Bc = B/dt
Cc = C

# %%
#check controllability
Con = ct.ctrb(Ac, Bc)
rank = np.linalg.matrix_rank(Con)

print("Controllability for linear Koopman :", rank)
# Out:
# Controllability for linear Koopman : 13

# %% [markdown]
# ## Output Contrability

# %%
out_con_mat, out_con_rank = Output_Con(Ac,Bc,Cc)


print(out_con_mat.shape)
print(out_con_rank)
# Out:
# (2, 22)
# 2

# %% [markdown]
# ## Testing

# %%
# test data parameters
num_snaps_test = 1000  # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)
num_traj_test = 1 # no. of training examples

# %%
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %%
_, x_test, u_test = dynamics_vanpol_data_gen(dt, num_traj_test, num_snaps_test,num_states, num_inputs, dyn_pars)
print(model_koop_dnn_lin.test_loss(x_test,u_test = u_test))
# Out:
# tensor(0.0002)

# %%
X_test,_ = model_koop_dnn_lin.net.process(x_test,data_u = u_test)

# %%
x_test = X_test[:, :num_states]
u = X_test[:, num_states:num_states+num_inputs]
x_prime_test = X_test[:,num_states+num_inputs:]

print(x_test.shape, u.shape, x_prime_test.shape)
# Out:
# (1000, 2) (1000, 1) (1000, 2)

# %%
z_test = np.empty((n_obs,num_snaps_test+1)).T
x_test_est = np.zeros((num_states,num_snaps_test+1)).T 

z_test[0,:] = lift(x_test[0,:],model_koop_dnn_lin, net_params)
x_test_est[0,:] = x_test[0,:]

# %%
for i in range(num_snaps_test):    
    #linear
    z_test[i+1,:] = np.matmul(z_test[i,:],A.T)+np.matmul(u[i,:],B.T)
    x_test_est[i+1,:] = np.matmul(z_test[i+1,:],C.T)

# %% [markdown]
# ## Lifting performance

# %%
plt.figure()
plt.plot(T_test[:-1], x_test[:,0],label ='Test data')
plt.plot(T_test, x_test_est[:,0],label = 'estimated')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_test[:,1],label ='Test data')
plt.plot(T_test, x_test_est[:,1],label = 'estimated')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_test[:,0],x_test[:,1],label ='Test data')
plt.plot(x_test_est[:,0],x_test_est[:,1],label = 'esimated')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ### Error Evolution

# %%
error_model = np.linalg.norm((x_test_est[:-1,:]-x_test[:,:]),axis=1)

# %%
plt.figure()
plt.plot(T_test[:-1],error_model)
plt.xlabel('t')
plt.ylabel('e')
plt.show()

# %% [markdown]
# ## Controllers

# %% [markdown]
# ## Reference Trajectory

# %%
t_ctrl = np.arange(start=0, stop=10, step=dt)
num_snaps_ctrl = t_ctrl.shape[0]

# %%
## linear path
# x_ref = np.vstack((np.vstack((np.linspace(0,np.pi,num_snaps_ctrl),np.linspace(0,np.pi/2,num_snaps_ctrl))),np.linspace(0,np.pi,num_snaps_ctrl)))
# x_ref_dot = np.vstack((np.vstack(((np.pi/10)*np.ones(num_snaps_ctrl),(np.pi/20)*np.ones(num_snaps_ctrl))),(np.pi/10)*np.ones(num_snaps_ctrl)))
# x_ref_ddot = np.vstack((np.vstack((np.zeros(num_snaps_ctrl),np.zeros(num_snaps_ctrl))),np.zeros(num_snaps_ctrl)))

def gen_desired_path(num_states,num_snaps, t_end,shape):
    
    x_ref = np.empty((int(num_states),num_snaps))
    x_ref_dot = np.empty_like(x_ref)
    x_ref_ddot = np.empty_like(x_ref)
    
    arg = np.linspace(0,np.pi,num_snaps)
    
    for i in range(num_snaps):
        if shape == 'linear':
            x_ref[:,i] = arg[i]
            x_ref_dot[:,i] = arg[-1]/t_end
            x_ref_ddot[:,i] = np.zeros(num_states,)
            
        elif shape == 'sinosoidal':
            x_ref[:,i] = np.sin(2*arg[i])
            x_ref_dot[:,i] = (2*arg[-1]/t_end)*np.cos(2*arg[i])
            x_ref_ddot[:,i] = -((2*arg[-1]/t_end)**2)*np.cos(2*arg[i])
        else:
            print('Shape is not defined')
            break
            
            
    return x_ref, x_ref_dot, x_ref_ddot

# %%
x_ref, x_ref_dot, x_ref_ddot = gen_desired_path(int(num_states/2),num_snaps_ctrl, t_ctrl[-1],'sinosoidal')

# %%
x_ref.shape
# Out:
# (1, 1000)

# %%
x_ref.shape
# Out:
# (1, 1000)

# %% [markdown]
# ## ZNN

# %%
gamma = 50

# %%
## specify the matricies
z_ctrl = np.empty((n_obs,num_snaps_ctrl))
x_ctrl = np.empty((num_states,num_snaps_ctrl))
u_ctrl = np.empty((num_inputs,num_snaps_ctrl-1))

## initialize the matricies
x_ctrl[:,0] = np.hstack((x_ref[:,0],x_ref_dot[:,0]))
z_ctrl[:,0] = lift(x_ctrl[:,0],model_koop_dnn_lin, net_params)

# %%
x_ref_full = np.vstack((x_ref,x_ref_dot))
x_ref_dot_full = np.vstack((x_ref_dot,x_ref_ddot))
for i in range(num_snaps_ctrl-1):
    t = t_ctrl[i]
    u_ctrl[:,i] = np.dot(np.linalg.pinv(np.matmul(C,Bc)), -np.matmul(C,np.matmul(Ac,z_ctrl[:,i])) + x_ref_dot_full[:,i] - gamma*(x_ctrl[:,i] - x_ref_full[:,i]))
                    
    _,x_ctrl[1,i+1],x_ctrl[0,i+1] = dynamics_vanpol(dt, x_ctrl[0,i],x_ctrl[1,i], u_ctrl[:,i], dyn_pars)
    z_ctrl[:,i+1] = lift(x_ctrl[:,i+1],model_koop_dnn_lin, net_params)

# %%
plt.figure(figsize=(18, 6)) 
plt.subplot(1,3,1)
plt.plot(t_ctrl[:],x_ref[0,:],label ='reference')
plt.plot(t_ctrl[:],x_ctrl[0,:],label = 'traced')
plt.xlabel('t')
plt.ylabel('x')
plt.title('x Comparison')
plt.legend()

plt.subplot(1,3,2)
plt.plot(t_ctrl[:],x_ref_dot[0,:],label ='reference')
plt.plot(t_ctrl[:],x_ctrl[1,:],label = 'traced')
plt.xlabel('t')
plt.ylabel('x dot')
plt.title('x dot')
plt.legend()

# %%
plt.figure(figsize=(18, 6)) 
plt.plot(t_ctrl[:-1],u_ctrl[0,:])
plt.xlabel('t')
plt.ylabel('u')
plt.title('u Comparison')
# Out:
# Text(0.5, 1.0, 'u Comparison')

# %% [markdown]
# ## MPC

# %%
# Create Linear Model Instanse
linear_model = linear_Dynamics(sparse.csc_matrix(A),sparse.csc_matrix(B), C)

# Model parameters
solver_settings = {}
solver_settings['gen_embedded_ctrl'] = False
solver_settings['warm_start'] = True
solver_settings['polish'] = True
solver_settings['polish_refine_iter'] = 3
solver_settings['scaling'] = True
solver_settings['adaptive_rho'] = False
solver_settings['check_termination'] = 25
solver_settings['max_iter'] = 1000
solver_settings['eps_abs'] = 1e-6
solver_settings['eps_rel'] = 1e-6
solver_settings['eps_prim_inf'] = 1e-4
solver_settings['eps_dual_inf'] = 1e-4
solver_settings['linsys_solver'] = 'qdldl'

## set limits
umax = 10*np.array([1])
umin = -umax

xmax =  10*np.array([1, 1])
xmin = -xmax

# %%
traj_length = num_snaps_ctrl
max_iter = 100
N = 2 #length of horizon
t_eval = dt * np.arange(traj_length+1)          # Simulation time points, closed loop
Q_mpc =  1e5*sparse.eye(num_states)       # State penalty matrix, trajectory generation
QN_mpc = 1e3*sparse.eye(num_states)       # Final state penalty matrix, trajectory generation
R_mpc =  1*sparse.eye(num_inputs)         # Actuation penalty matrix, trajectory generation
R0_mpc = sparse.csc_matrix(np.zeros(num_inputs))

# Design trajectory:
x0 = x_ref_full[:,0]                        
# State constraints, trajectory generation
# Define initial solution for SQP algorithm:
x_init = np.linspace(x0, x0, N+1)
u_init = 1*np.ones((num_inputs, N)).T

# %%
u_init.shape
# Out:
# (10, 1)

# %%
x_ref_full[:,0]
# Out:
# array([0.        , 0.62894748])

# %%
z_init = np.empty((N+1, n_obs))
z0 = lift(x0, model_koop_dnn_lin, net_params)
for i in range(N+1):
    z_init[i,:] = lift(x_init[i,:], model_koop_dnn_lin, net_params)

# %%
z_init.shape
# Out:
# (11, 21)

# %%
controller_nmpc = NonlinearMPCController(linear_model, N, dt, umin, umax, xmin, xmax, Q_mpc, R_mpc, QN_mpc, solver_settings)
controller_nmpc.construct_controller(z_init, u_init,x_ref_full[:,0])

# %%
controller_nmpc.trajectory_tracking(x0, z0, x_ref_full.T, max_iter)
# Out:
# time_step 0
# time_step 1
# time_step 2
# time_step 3
# time_step 4
# time_step 5
# time_step 6
# time_step 7
# time_step 8
# time_step 9
# time_step 10
# time_step 11
# time_step 12
# time_step 13
# time_step 14
# time_step 15
# time_step 16
# time_step 17
# time_step 18
# time_step 19
# time_step 20
# time_step 21
# time_step 22
# time_step 23
# time_step 24
# time_step 25
# time_step 26
# time_step 27
# time_step 28
# time_step 29
# time_step 30
# time_step 31
# time_step 32
# time_step 33
# time_step 34
# time_step 35
# time_step 36
# time_step 37
# time_step 38
# time_step 39
# time_step 40
# time_step 41
# time_step 42
# time_step 43
# time_step 44
# time_step 45
# time_step 46
# time_step 47
# time_step 48
# time_step 49
# time_step 50
# time_step 51
# time_step 52
# time_step 53
# time_step 54
# time_step 55
# time_step 56
# time_step 57
# time_step 58
# time_step 59
# time_step 60
# time_step 61
# time_step 62
# time_step 63
# time_step 64
# time_step 65
# time_step 66
# time_step 67
# time_step 68
# time_step 69
# time_step 70
# time_step 71
# time_step 72
# time_step 73
# time_step 74
# time_step 75
# time_step 76
# time_step 77
# time_step 78
# time_step 79
# time_step 80
# time_step 81
# time_step 82
# time_step 83
# time_step 84
# time_step 85
# time_step 86
# time_step 87
# time_step 88
# time_step 89
# time_step 90
# time_step 91
# time_step 92
# time_step 93
# time_step 94
# time_step 95
# time_step 96
# time_step 97
# time_step 98
# time_step 99
# time_step 100
# time_step 101
# time_step 102
# time_step 103
# time_step 104
# time_step 105
# time_step 106
# time_step 107
# time_step 108
# time_step 109
# time_step 110
# time_step 111
# time_step 112
# time_step 113
# time_step 114
# time_step 115
# time_step 116
# time_step 117
# time_step 118
# time_step 119
# time_step 120
# time_step 121
# time_step 122
# time_step 123
# time_step 124
# time_step 125
# time_step 126
# time_step 127
# time_step 128
# time_step 129
# time_step 130
# time_step 131
# time_step 132
# time_step 133
# time_step 134
# time_step 135
# time_step 136
# time_step 137
# time_step 138
# time_step 139
# time_step 140
# time_step 141
# time_step 142
# time_step 143
# time_step 144
# time_step 145
# time_step 146
# time_step 147
# time_step 148
# time_step 149
# time_step 150
# time_step 151
# time_step 152
# time_step 153
# time_step 154
# time_step 155
# time_step 156
# time_step 157
# time_step 158
# time_step 159
# time_step 160
# time_step 161
# time_step 162
# time_step 163
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [88], line 1
# ----> 1 controller_nmpc.trajectory_tracking(x0, z0, x_ref_full.T, max_iter)
#
# File ~/Adaptive-koopman/control_files/nmpc_osqp.py:137, in NonlinearMPCController.trajectory_tracking(self, x0, z0, x_ref_traj, max_iter)
#     135 print("time_step", i)
#     136 xr = self.xr_traj[i, :]
# --> 137 self.solve_to_convergence(xr, self.z_N0, self.z_init, self.u_init, max_iter = max_iter, eps = 1e-3)
#     138 self.update_initial_guess_()
#     139 self.x_traced[i+1, :] = self.x_N0
#
# File ~/Adaptive-koopman/control_files/nmpc_osqp.py:181, in NonlinearMPCController.solve_to_convergence(self, xr, z, z_init_0, u_init_0, max_iter, eps)
#     178 self.update_constraint_matrix_data_(A_lst, B_lst)
#     179 t_prep = time.time() - t0
# --> 181 self.solve_mpc_()
#     182 dz = self.dz_flat.reshape(self.N + 1, self.nz)
#     183 du = self.du_flat.reshape(self.N, self.nu)
#
# File ~/Adaptive-koopman/control_files/nmpc_osqp.py:412, in NonlinearMPCController.solve_mpc_(self)
#     410 self.du_flat = self.res.x[(self.N + 1) * self.nz:(self.N + 1) * self.nz + self.nu * self.N]
#     411 if self.res.info.status != 'solved':
# --> 412     raise ValueError('OSQP did not solve the problem!')
#
# ValueError: OSQP did not solve the problem!

# %%
plt.figure(figsize=(18, 6)) 
plt.subplot(1,3,1)
plt.plot(t_ctrl[:],x_ref[0,:],label ='reference')
plt.plot(t_eval,controller_nmpc.x_traced[:,0],label = 'traced')
plt.xlabel('t')
plt.ylabel('x')
plt.title('x Comparison')
plt.legend()

plt.subplot(1,3,2)
plt.plot(t_ctrl[:],x_ref_dot[0,:],label ='reference')
plt.plot(t_eval,controller_nmpc.x_traced[:,1],label = 'traced')
plt.xlabel('t')
plt.ylabel('x dot')
plt.title('x dot Comparison')
plt.legend()
