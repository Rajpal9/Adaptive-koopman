# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

from core.koopman_core import KoopDNN,KoopmanNet,KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from dynamics.duffing import dynamics_duff
from dynamics.Vanpol import dynamics_vanpol

from core.adapt_net import AdaptNet
import control as ct

# %%
# Base Parameters
dt = 0.01 #time step
num_snaps = 1000 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 200 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories

## Single System
num_states = 2 # no. of states
num_inputs = 1 # no. of inputs

# ## Coupled System
# num_states = 4 # no. of states
# num_inputs = 2 # no. of inputs

# %%
# Oscillator parameters
dyn_pars = {}


## Single System

dyn_pars['a'] = 1
dyn_pars['b'] = 4
dyn_pars['c'] = 0.5
dyn_pars['d'] = 0.5

dyn_pars['del_a'] = 0.3
dyn_pars['del_b'] = 0
dyn_pars['del_c'] = 0
dyn_pars['del_d'] = 0

dyn_pars['delay'] =  False

dyn_pars['delay_time'] = 5
dyn_pars['cont_unc_type'] = 'constant'

# %%
X_changed, X_unchanged, U = dynamics_duff(dt, num_traj, num_snaps, num_states, num_inputs, dyn_pars)

print(X_changed.shape, U.shape)
# Out:
# (250, 1001, 2) (250, 1000, 1)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X_changed)))))
print(sum(sum(sum(np.isnan(X_unchanged)))))
# Out:
# 0
# 0

# %%
l2_diff = np.linalg.norm(X_changed-X_unchanged)/((X_changed.size)**(1/2))
print('l2_diff = ', l2_diff)
# Out:
# l2_diff =  0.07026561279701697

# %%
change_in_dym = np.linalg.norm((X_changed-X_unchanged)/X_changed)/X_changed.size
print('fraction of change in dynamics = ', change_in_dym)
# Out:
# fraction of change in dynamics =  2.489194198561815

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Phase plot for unchanged dynamics")
axs[1].set_title("Phase plot for changed dynamics")

axs[0].set(xlabel = 'x1', ylabel = 'x2')
axs[1].set(xlabel = 'x1', ylabel = 'x2')

for i in range(num_traj):
    axs[0].plot(X_unchanged[i,:,0], X_unchanged[i,:,1])
    axs[1].plot(X_changed[i,:,0], X_changed[i,:,1])
plt.savefig('phase_plot_duffing.jpg')

# %%
plt.figure()

plt.title('Comparison of Phase plot')
plt.plot(X_unchanged[4,:,0], X_unchanged[4,:,1], label = 'unchanged')
plt.plot(X_changed[4,:,0], X_changed[4,:,1], label = 'changed')

plt.legend()
plt.savefig('phase_plot_duffing_single_traj.jpg')
plt.show()

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in position")
axs[1].set_title("Error in velocity")

axs[0].set(xlabel = 't', ylabel = 'x1')
axs[1].set(xlabel = 't', ylabel = 'x2')


axs[0].plot(T, X_unchanged[4,:,0], label = 'unchanged')
axs[0].plot(T, X_changed[4,:,0], label = 'changed')
axs[0].legend()

axs[1].plot(T, X_unchanged[4,:,1], label = 'unchanged')
axs[1].plot(T, X_changed[4,:,1], label = 'changed')
axs[1].legend()

plt.savefig('vel_pos_err_duffing_single_traj.jpg')

# %%
# split training and vaidation datasets
xs_train, us_train = X_unchanged[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X_unchanged[num_train:,:,:],U[num_train:,:,:]

# %% [markdown]
# ***Koopman bilinear Models***

# %%
# auto encoder parameters

net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 20
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 2e-4 # 5e-4
net_params['epochs'] = 300
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'duff_pos_adap.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'duff_pos_adap.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 0.3486358523, validation loss: 0.1267855456
# Epoch   2: train loss: 0.1080681682, validation loss: 0.1008264039
# Epoch   3: train loss: 0.0857120976, validation loss: 0.0722920546
# Epoch   4: train loss: 0.0489849336, validation loss: 0.0253530251
# Epoch   5: train loss: 0.0148042962, validation loss: 0.0078527658
# Epoch   6: train loss: 0.0070043164, validation loss: 0.0055710034
# Epoch   7: train loss: 0.0052214577, validation loss: 0.0046776582
# Epoch   8: train loss: 0.0042957095, validation loss: 0.0039486669
# Epoch   9: train loss: 0.0036896681, validation loss: 0.0034459119
# Epoch  10: train loss: 0.0031986767, validation loss: 0.0030549961
# Epoch  11: train loss: 0.0027918138, validation loss: 0.0026908624
# Epoch  12: train loss: 0.0024627671, validation loss: 0.0023925882
# Epoch  13: train loss: 0.0021977681, validation loss: 0.0021462010
# Epoch  14: train loss: 0.0019698928, validation loss: 0.0019587878
# Epoch  15: train loss: 0.0017867871, validation loss: 0.0017866937
# Epoch  16: train loss: 0.0016311166, validation loss: 0.0016477137
# Epoch  17: train loss: 0.0015017524, validation loss: 0.0015440065
# Epoch  18: train loss: 0.0013908102, validation loss: 0.0013973033
# Epoch  19: train loss: 0.0012945905, validation loss: 0.0013159718
# Epoch  20: train loss: 0.0012119864, validation loss: 0.0012253430
# Epoch  21: train loss: 0.0011367991, validation loss: 0.0011675428
# Epoch  22: train loss: 0.0010726784, validation loss: 0.0011102820
# Epoch  23: train loss: 0.0010109392, validation loss: 0.0010264250
# Epoch  24: train loss: 0.0009581614, validation loss: 0.0010543315
# Epoch  25: train loss: 0.0009068219, validation loss: 0.0009365207
# Epoch  26: train loss: 0.0008595365, validation loss: 0.0008901834
# Epoch  27: train loss: 0.0008175275, validation loss: 0.0008377285
# Epoch  28: train loss: 0.0007756894, validation loss: 0.0007981135
# Epoch  29: train loss: 0.0007377422, validation loss: 0.0007576675
# Epoch  30: train loss: 0.0006995494, validation loss: 0.0007241314
# Epoch  31: train loss: 0.0006641620, validation loss: 0.0006810987
# Epoch  32: train loss: 0.0006295430, validation loss: 0.0006588418
# Epoch  33: train loss: 0.0005941592, validation loss: 0.0006376987
# Epoch  34: train loss: 0.0005612448, validation loss: 0.0005897248
# Epoch  35: train loss: 0.0005310542, validation loss: 0.0005450999
# Epoch  36: train loss: 0.0004995957, validation loss: 0.0005251209
# Epoch  37: train loss: 0.0004676668, validation loss: 0.0004819986
# Epoch  38: train loss: 0.0004411043, validation loss: 0.0004537513
# Epoch  39: train loss: 0.0004130339, validation loss: 0.0004418272
# Epoch  40: train loss: 0.0003888689, validation loss: 0.0003988961
# Epoch  41: train loss: 0.0003634775, validation loss: 0.0003714193
# Epoch  42: train loss: 0.0003408601, validation loss: 0.0003529521
# Epoch  43: train loss: 0.0003200888, validation loss: 0.0003218691
# Epoch  44: train loss: 0.0003013620, validation loss: 0.0003428248
# Epoch  45: train loss: 0.0002865830, validation loss: 0.0002877236
# Epoch  46: train loss: 0.0002683792, validation loss: 0.0002772408
# Epoch  47: train loss: 0.0002561879, validation loss: 0.0002613507
# Epoch  48: train loss: 0.0002431854, validation loss: 0.0002676252
# Epoch  49: train loss: 0.0002310785, validation loss: 0.0002402994
# Epoch  50: train loss: 0.0002209668, validation loss: 0.0002175184
# Epoch  51: train loss: 0.0002110206, validation loss: 0.0002104581
# Epoch  52: train loss: 0.0002025165, validation loss: 0.0002024517
# Epoch  53: train loss: 0.0001930630, validation loss: 0.0001937372
# Epoch  54: train loss: 0.0001857196, validation loss: 0.0001890885
# Epoch  55: train loss: 0.0001782209, validation loss: 0.0001777118
# Epoch  56: train loss: 0.0001723917, validation loss: 0.0001879567
# Epoch  57: train loss: 0.0001658001, validation loss: 0.0001664176
# Epoch  58: train loss: 0.0001599888, validation loss: 0.0001712973
# Epoch  59: train loss: 0.0001540704, validation loss: 0.0001517553
# Epoch  60: train loss: 0.0001487266, validation loss: 0.0001527248
# Epoch  61: train loss: 0.0001437581, validation loss: 0.0001670572
# Epoch  62: train loss: 0.0001390756, validation loss: 0.0001446158
# Epoch  63: train loss: 0.0001349235, validation loss: 0.0001389940
# Epoch  64: train loss: 0.0001299703, validation loss: 0.0001283281
# Epoch  65: train loss: 0.0001275686, validation loss: 0.0001240005
# Epoch  66: train loss: 0.0001215981, validation loss: 0.0001191487
# Epoch  67: train loss: 0.0001196598, validation loss: 0.0001153419
# Epoch  68: train loss: 0.0001159688, validation loss: 0.0001146450
# Epoch  69: train loss: 0.0001131308, validation loss: 0.0001129275
# Epoch  70: train loss: 0.0001103391, validation loss: 0.0001081238
# Epoch  71: train loss: 0.0001073703, validation loss: 0.0001081131
# Epoch  72: train loss: 0.0001049630, validation loss: 0.0001072003
# Epoch  73: train loss: 0.0001013533, validation loss: 0.0000989020
# Epoch  74: train loss: 0.0000999250, validation loss: 0.0001039457
# Epoch  75: train loss: 0.0000963399, validation loss: 0.0000978878
# Epoch  76: train loss: 0.0000954525, validation loss: 0.0001029325
# Epoch  77: train loss: 0.0000922613, validation loss: 0.0000901130
# Epoch  78: train loss: 0.0000910385, validation loss: 0.0000947066
# Epoch  79: train loss: 0.0000885543, validation loss: 0.0000881101
# Epoch  80: train loss: 0.0000866104, validation loss: 0.0001198838
# Epoch  81: train loss: 0.0000853801, validation loss: 0.0000835043
# Epoch  82: train loss: 0.0000825430, validation loss: 0.0000847921
# Epoch  83: train loss: 0.0000812553, validation loss: 0.0000890426
# Epoch  84: train loss: 0.0000802247, validation loss: 0.0000879126
# Epoch  85: train loss: 0.0000781693, validation loss: 0.0000796322
# Epoch  86: train loss: 0.0000767361, validation loss: 0.0000740540
# Epoch  87: train loss: 0.0000746023, validation loss: 0.0000739951
# Epoch  88: train loss: 0.0000742215, validation loss: 0.0000783909
# Epoch  89: train loss: 0.0000719658, validation loss: 0.0000672879
# Epoch  90: train loss: 0.0000711927, validation loss: 0.0000737379
# Epoch  91: train loss: 0.0000693010, validation loss: 0.0000877265
# Epoch  92: train loss: 0.0000688601, validation loss: 0.0000655820
# Epoch  93: train loss: 0.0000669472, validation loss: 0.0000656587
# Epoch  94: train loss: 0.0000663382, validation loss: 0.0000677302
# Epoch  95: train loss: 0.0000644070, validation loss: 0.0000609535
# Epoch  96: train loss: 0.0000637073, validation loss: 0.0000646437
# Epoch  97: train loss: 0.0000629088, validation loss: 0.0000585471
# Epoch  98: train loss: 0.0000620270, validation loss: 0.0000685981
# Epoch  99: train loss: 0.0000602993, validation loss: 0.0000551818
# Epoch 100: train loss: 0.0000598922, validation loss: 0.0000574611
# Epoch 101: train loss: 0.0000584211, validation loss: 0.0000788963
# Epoch 102: train loss: 0.0000577089, validation loss: 0.0000580747
# Epoch 103: train loss: 0.0000569581, validation loss: 0.0000570552
# Epoch 104: train loss: 0.0000560796, validation loss: 0.0000536027
# Epoch 105: train loss: 0.0000555465, validation loss: 0.0000516024
# Epoch 106: train loss: 0.0000542946, validation loss: 0.0000604535
# Epoch 107: train loss: 0.0000537012, validation loss: 0.0000658022
# Epoch 108: train loss: 0.0000524025, validation loss: 0.0000658668
# Epoch 109: train loss: 0.0000517230, validation loss: 0.0000504130
# Epoch 110: train loss: 0.0000512703, validation loss: 0.0000473519
# Epoch 111: train loss: 0.0000508152, validation loss: 0.0000481145
# Epoch 112: train loss: 0.0000495197, validation loss: 0.0000465109
# Epoch 113: train loss: 0.0000494209, validation loss: 0.0000448129
# Epoch 114: train loss: 0.0000485084, validation loss: 0.0000542164
# Epoch 115: train loss: 0.0000485360, validation loss: 0.0000443541
# Epoch 116: train loss: 0.0000472713, validation loss: 0.0000434752
# Epoch 117: train loss: 0.0000464051, validation loss: 0.0000464704
# Epoch 118: train loss: 0.0000462211, validation loss: 0.0000403386
# Epoch 119: train loss: 0.0000453018, validation loss: 0.0000405141
# Epoch 120: train loss: 0.0000449776, validation loss: 0.0000406839
# Epoch 121: train loss: 0.0000442089, validation loss: 0.0000401265
# Epoch 122: train loss: 0.0000439065, validation loss: 0.0000433737
# Epoch 123: train loss: 0.0000430740, validation loss: 0.0000411601
# Epoch 124: train loss: 0.0000428740, validation loss: 0.0000384077
# Epoch 125: train loss: 0.0000421376, validation loss: 0.0000386419
# Epoch 126: train loss: 0.0000427219, validation loss: 0.0000436499
# Epoch 127: train loss: 0.0000407003, validation loss: 0.0000379902
# Epoch 128: train loss: 0.0000411725, validation loss: 0.0000384600
# Epoch 129: train loss: 0.0000401693, validation loss: 0.0000348379
# Epoch 130: train loss: 0.0000400645, validation loss: 0.0000351016
# Epoch 131: train loss: 0.0000394022, validation loss: 0.0000411379
# Epoch 132: train loss: 0.0000392539, validation loss: 0.0000390432
# Epoch 133: train loss: 0.0000386524, validation loss: 0.0000344800
# Epoch 134: train loss: 0.0000383856, validation loss: 0.0000374157
# Epoch 135: train loss: 0.0000378295, validation loss: 0.0000337578
# Epoch 136: train loss: 0.0000377272, validation loss: 0.0000334310
# Epoch 137: train loss: 0.0000368182, validation loss: 0.0000351023
# Epoch 138: train loss: 0.0000374546, validation loss: 0.0000345100
# Epoch 139: train loss: 0.0000360284, validation loss: 0.0000420974
# Epoch 140: train loss: 0.0000365306, validation loss: 0.0000304436
# Epoch 141: train loss: 0.0000355553, validation loss: 0.0000321081
# Epoch 142: train loss: 0.0000355544, validation loss: 0.0000400661
# Epoch 143: train loss: 0.0000348745, validation loss: 0.0000309724
# Epoch 144: train loss: 0.0000348806, validation loss: 0.0000298066
# Epoch 145: train loss: 0.0000345117, validation loss: 0.0000289700
# Epoch 146: train loss: 0.0000338061, validation loss: 0.0000330127
# Epoch 147: train loss: 0.0000337447, validation loss: 0.0000327010
# Epoch 148: train loss: 0.0000341626, validation loss: 0.0000385125
# Epoch 149: train loss: 0.0000325391, validation loss: 0.0000537376
# Epoch 150: train loss: 0.0000327759, validation loss: 0.0000291969
# Epoch 151: train loss: 0.0000327022, validation loss: 0.0000270387
# Epoch 152: train loss: 0.0000322477, validation loss: 0.0000274792
# Epoch 153: train loss: 0.0000316007, validation loss: 0.0000272112
# Epoch 154: train loss: 0.0000316382, validation loss: 0.0000355528
# Epoch 155: train loss: 0.0000322066, validation loss: 0.0000270026
# Epoch 156: train loss: 0.0000307425, validation loss: 0.0000324388
# Epoch 157: train loss: 0.0000308588, validation loss: 0.0000385650
# Epoch 158: train loss: 0.0000311002, validation loss: 0.0000316831
# Epoch 159: train loss: 0.0000299255, validation loss: 0.0000269269
# Epoch 160: train loss: 0.0000300310, validation loss: 0.0000249712
# Epoch 161: train loss: 0.0000296807, validation loss: 0.0000296655
# Epoch 162: train loss: 0.0000304121, validation loss: 0.0000256339
# Epoch 163: train loss: 0.0000289653, validation loss: 0.0000456725
# Epoch 164: train loss: 0.0000296340, validation loss: 0.0000961959
# Epoch 165: train loss: 0.0000283822, validation loss: 0.0000231895
# Epoch 166: train loss: 0.0000291175, validation loss: 0.0000255259
# Epoch 167: train loss: 0.0000282860, validation loss: 0.0000235333
# Epoch 168: train loss: 0.0000280637, validation loss: 0.0000235711
# Epoch 169: train loss: 0.0000285472, validation loss: 0.0000268575
# Epoch 170: train loss: 0.0000277644, validation loss: 0.0000225176
# Epoch 171: train loss: 0.0000279362, validation loss: 0.0000284918
# Epoch 172: train loss: 0.0000268024, validation loss: 0.0000491444
# Epoch 173: train loss: 0.0000273733, validation loss: 0.0000243275
# Epoch 174: train loss: 0.0000270090, validation loss: 0.0000215761
# Epoch 175: train loss: 0.0000267721, validation loss: 0.0000217267
# Epoch 176: train loss: 0.0000267020, validation loss: 0.0000227015
# Epoch 177: train loss: 0.0000264305, validation loss: 0.0000359461
# Epoch 178: train loss: 0.0000262629, validation loss: 0.0000279876
# Epoch 179: train loss: 0.0000261912, validation loss: 0.0000245086
# Epoch 180: train loss: 0.0000253562, validation loss: 0.0000256587
# Epoch 181: train loss: 0.0000256046, validation loss: 0.0000200218
# Epoch 182: train loss: 0.0000255155, validation loss: 0.0000236239
# Epoch 183: train loss: 0.0000254111, validation loss: 0.0000198482
# Epoch 184: train loss: 0.0000249297, validation loss: 0.0000316207
# Epoch 185: train loss: 0.0000247621, validation loss: 0.0000205262
# Epoch 186: train loss: 0.0000248606, validation loss: 0.0000282079
# Epoch 187: train loss: 0.0000251564, validation loss: 0.0000206606
# Epoch 188: train loss: 0.0000235169, validation loss: 0.0000232617
# Epoch 189: train loss: 0.0000248080, validation loss: 0.0000209607
# Epoch 190: train loss: 0.0000239244, validation loss: 0.0000188104
# Epoch 191: train loss: 0.0000239362, validation loss: 0.0000187237
# Epoch 192: train loss: 0.0000235091, validation loss: 0.0000177497
# Epoch 193: train loss: 0.0000240789, validation loss: 0.0000238826
# Epoch 194: train loss: 0.0000232634, validation loss: 0.0000187000
# Epoch 195: train loss: 0.0000232252, validation loss: 0.0000181022
# Epoch 196: train loss: 0.0000232046, validation loss: 0.0000388080
# Epoch 197: train loss: 0.0000228769, validation loss: 0.0000220514
# Epoch 198: train loss: 0.0000230590, validation loss: 0.0000187444
# Epoch 199: train loss: 0.0000222335, validation loss: 0.0000190773
# Epoch 200: train loss: 0.0000224048, validation loss: 0.0000179023
# Epoch 201: train loss: 0.0000224988, validation loss: 0.0000206720
# Epoch 202: train loss: 0.0000219109, validation loss: 0.0000199275
# Epoch 203: train loss: 0.0000220677, validation loss: 0.0000194474
# Epoch 204: train loss: 0.0000221045, validation loss: 0.0000161533
# Epoch 205: train loss: 0.0000217178, validation loss: 0.0000157762
# Epoch 206: train loss: 0.0000218719, validation loss: 0.0000172917
# Epoch 207: train loss: 0.0000217098, validation loss: 0.0000421748
# Epoch 208: train loss: 0.0000211129, validation loss: 0.0000237678
# Epoch 209: train loss: 0.0000214516, validation loss: 0.0000316511
# Epoch 210: train loss: 0.0000211833, validation loss: 0.0000157571
# Epoch 211: train loss: 0.0000208601, validation loss: 0.0000193944
# Epoch 212: train loss: 0.0000206874, validation loss: 0.0000152652
# Epoch 213: train loss: 0.0000204996, validation loss: 0.0000290345
# Epoch 214: train loss: 0.0000207360, validation loss: 0.0000547881
# Epoch 215: train loss: 0.0000208785, validation loss: 0.0000169916
# Epoch 216: train loss: 0.0000201103, validation loss: 0.0000149973
# Epoch 217: train loss: 0.0000200435, validation loss: 0.0000287827
# Epoch 218: train loss: 0.0000201051, validation loss: 0.0000173026
# Epoch 219: train loss: 0.0000199820, validation loss: 0.0000315012
# Epoch 220: train loss: 0.0000199775, validation loss: 0.0000145357
# Epoch 221: train loss: 0.0000198779, validation loss: 0.0000151428
# Epoch 222: train loss: 0.0000193789, validation loss: 0.0000185301
# Epoch 223: train loss: 0.0000200370, validation loss: 0.0000152347
# Epoch 224: train loss: 0.0000190798, validation loss: 0.0000335868
# Epoch 225: train loss: 0.0000192664, validation loss: 0.0000186040
# Epoch 226: train loss: 0.0000190280, validation loss: 0.0000498537
# Epoch 227: train loss: 0.0000194646, validation loss: 0.0000168180
# Epoch 228: train loss: 0.0000186389, validation loss: 0.0000162309
# Epoch 229: train loss: 0.0000188308, validation loss: 0.0000397849
# Epoch 230: train loss: 0.0000188975, validation loss: 0.0000280597
# Epoch 231: train loss: 0.0000188594, validation loss: 0.0000151973
# Epoch 232: train loss: 0.0000188638, validation loss: 0.0000230371
# Epoch 233: train loss: 0.0000187541, validation loss: 0.0000138181
# Epoch 234: train loss: 0.0000188856, validation loss: 0.0000153811
# Epoch 235: train loss: 0.0000178330, validation loss: 0.0000147053
# Epoch 236: train loss: 0.0000180795, validation loss: 0.0000126620
# Epoch 237: train loss: 0.0000178313, validation loss: 0.0000148520
# Epoch 238: train loss: 0.0000179735, validation loss: 0.0000241906
# Epoch 239: train loss: 0.0000180589, validation loss: 0.0000125978
# Epoch 240: train loss: 0.0000180161, validation loss: 0.0000222808
# Epoch 241: train loss: 0.0000174935, validation loss: 0.0000150027
# Epoch 242: train loss: 0.0000177286, validation loss: 0.0000188211
# Epoch 243: train loss: 0.0000175527, validation loss: 0.0000121779
# Epoch 244: train loss: 0.0000173702, validation loss: 0.0000164575
# Epoch 245: train loss: 0.0000172829, validation loss: 0.0000170827
# Epoch 246: train loss: 0.0000172861, validation loss: 0.0000211289
# Epoch 247: train loss: 0.0000170723, validation loss: 0.0000121580
# Epoch 248: train loss: 0.0000173177, validation loss: 0.0000135969
# Epoch 249: train loss: 0.0000171904, validation loss: 0.0000183586
# Epoch 250: train loss: 0.0000170739, validation loss: 0.0000134340
# Epoch 251: train loss: 0.0000167457, validation loss: 0.0000122125
# Epoch 252: train loss: 0.0000175870, validation loss: 0.0000206747
# Epoch 253: train loss: 0.0000167205, validation loss: 0.0000125703
# Epoch 254: train loss: 0.0000162585, validation loss: 0.0000183609
# Epoch 255: train loss: 0.0000168153, validation loss: 0.0000139388
# Epoch 256: train loss: 0.0000165741, validation loss: 0.0000101683
# Epoch 257: train loss: 0.0000167483, validation loss: 0.0000129693
# Epoch 258: train loss: 0.0000163122, validation loss: 0.0000175854
# Epoch 259: train loss: 0.0000163994, validation loss: 0.0000110999
# Epoch 260: train loss: 0.0000164431, validation loss: 0.0000115678
# Epoch 261: train loss: 0.0000158048, validation loss: 0.0000138434
# Epoch 262: train loss: 0.0000163207, validation loss: 0.0000124832
# Epoch 263: train loss: 0.0000161471, validation loss: 0.0000212318
# Epoch 264: train loss: 0.0000162843, validation loss: 0.0000096784
# Epoch 265: train loss: 0.0000164301, validation loss: 0.0000247614
# Epoch 266: train loss: 0.0000154005, validation loss: 0.0000099437
# Epoch 267: train loss: 0.0000157976, validation loss: 0.0000135548
# Epoch 268: train loss: 0.0000160830, validation loss: 0.0000104043
# Epoch 269: train loss: 0.0000155363, validation loss: 0.0000133442
# Epoch 270: train loss: 0.0000159808, validation loss: 0.0000254392
# Epoch 271: train loss: 0.0000153160, validation loss: 0.0000126031
# Epoch 272: train loss: 0.0000159084, validation loss: 0.0000167250
# Epoch 273: train loss: 0.0000152432, validation loss: 0.0000118279
# Epoch 274: train loss: 0.0000158292, validation loss: 0.0000099594
# Epoch 275: train loss: 0.0000148509, validation loss: 0.0000106474
# Epoch 276: train loss: 0.0000154444, validation loss: 0.0000094981
# Epoch 277: train loss: 0.0000152524, validation loss: 0.0000125219
# Epoch 278: train loss: 0.0000151666, validation loss: 0.0000108793
# Epoch 279: train loss: 0.0000155408, validation loss: 0.0000477883
# Epoch 280: train loss: 0.0000148931, validation loss: 0.0000131691
# Epoch 281: train loss: 0.0000150859, validation loss: 0.0000090271
# Epoch 282: train loss: 0.0000149545, validation loss: 0.0000089152
# Epoch 283: train loss: 0.0000150307, validation loss: 0.0000101712
# Epoch 284: train loss: 0.0000148676, validation loss: 0.0000195217
# Epoch 285: train loss: 0.0000147347, validation loss: 0.0000160012
# Epoch 286: train loss: 0.0000148397, validation loss: 0.0000093312
# Epoch 287: train loss: 0.0000143545, validation loss: 0.0000396694
# Epoch 288: train loss: 0.0000150409, validation loss: 0.0000177866
# Epoch 289: train loss: 0.0000147526, validation loss: 0.0000086268
# Epoch 290: train loss: 0.0000144616, validation loss: 0.0000084182
# Epoch 291: train loss: 0.0000147732, validation loss: 0.0000088061
# Epoch 292: train loss: 0.0000146538, validation loss: 0.0000206842
# Epoch 293: train loss: 0.0000143189, validation loss: 0.0000102289
# Epoch 294: train loss: 0.0000141901, validation loss: 0.0000177337
# Epoch 295: train loss: 0.0000141938, validation loss: 0.0000184594
# Epoch 296: train loss: 0.0000146056, validation loss: 0.0000091631
# Epoch 297: train loss: 0.0000148914, validation loss: 0.0000087628
# Epoch 298: train loss: 0.0000135022, validation loss: 0.0000080718
# Epoch 299: train loss: 0.0000143440, validation loss: 0.0000117436
# Epoch 300: train loss: 0.0000141875, validation loss: 0.0000115549
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Learned Model Parameters

# %% [markdown]
# ## Bilinear Model Parameters

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (23, 23) (23, 23) (2, 23)

# %% [markdown]
# ## Lifting function

# %% [markdown]
# # Testing

# %% [markdown]
# ## Parameters

# %%
# test data parameters
num_snaps_test = 5*1000 # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)
num_traj_test = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ## Testing Data

# %%
x_changed_test, x_unchanged_test, u_test = dynamics_duff(dt, num_traj_test, num_snaps_test,num_states, num_inputs, dyn_pars)
print(model_koop_dnn.test_loss(x_unchanged_test,u_test = u_test))
# Out:
# tensor(1.3145e-05)

# %%
x_unchanged_test.shape
# Out:
# (1, 5001, 2)

# %%
# Use the preprocessing if available
X_unchanged,_ = model_koop_dnn.net.process(x_unchanged_test,data_u = u_test)
X_changed,_ = model_koop_dnn.net.process(x_changed_test,data_u = u_test)

# %%
X_changed.shape
# Out:
# (5000, 5)

# %%
# flatten vector
x_unchanged = X_unchanged[:, :num_states]
u = X_unchanged[:, num_states:num_states+num_inputs]
x_unchanged_prime = X_unchanged[:,num_states+num_inputs:]

x_changed = X_changed[:, :num_states]
x_changed_prime = X_changed[:,num_states+num_inputs:]

x_changed_dot = (x_changed_prime-x_changed)/dt
print(x_changed.shape, u.shape, x_changed_prime.shape)
# Out:
# (5000, 2) (5000, 1) (5000, 2)

# %% [markdown]
# # Lifting of states

# %%
# initialize states
# initialize the matricies
z_unchanged = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_unchanged_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values

# %%
# actual lift
z_unchanged[0,:] = lift(x_unchanged[0,:],model_koop_dnn, net_params)
x_unchanged_est[0,:] = x_unchanged[0,:]

# %% [markdown]
# # Time Evolution

# %%
for i in range(num_snaps_test):
  #bilinear
    z_unchanged[i+1,:] = np.matmul(z_unchanged[i,:],A.T)+np.matmul(np.kron(u[i,:],z_unchanged[i,:]),B.T)
    x_unchanged_est[i+1,:] = np.matmul(z_unchanged[i+1,:],C.T)

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lifting performance

# %%
plt.figure()
plt.plot(T_test[:-1], x_unchanged[:,0],label ='Test unchanged data')
plt.plot(T_test, x_unchanged_est[:,0],label = 'estimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ### Error Evolution

# %%
error_model = np.linalg.norm((x_unchanged_est[:-1,:]-x_unchanged[:,:]),axis=1)
error_dynamics_no_adapt = np.linalg.norm((x_changed[:,:]-x_unchanged[:,:]),axis=1)

# %%
plt.figure()
plt.plot(T_test[:-1],error_model)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Model error evolution')
plt.show()

# %% [markdown]
# ## Deviation from Actual Dynamics

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data (changed dynamics)')
plt.plot(T_test[:-1],x_unchanged[:,0],label ='Test data (unchanged dynamics)')
plt.plot(T_test,x_unchanged_est[:,0],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data (changed model)')
plt.plot(T_test[:-1],x_unchanged[:,1],label ='Test data (unchanged model)')
plt.plot(T_test,x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Velocity Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data (changed dyn)')
plt.plot(x_unchanged[:,0],x_unchanged[:,1],label ='Test data (unchanged dyn)')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label = 'esimated unchanged dyn (bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(T_test[:-1],error_dynamics_no_adapt)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Dynamics error evolution')
plt.show()

# %% [markdown]
# ## Controlability

# %%
C = ct.ctrb(A, B)
np.linalg.matrix_rank(C)
# Out:
# 22

# %% [markdown]
# # Adaptation

# %% [markdown]
# ## Data Preprocessing

# %%
# initialize state matricies
z_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
z_changed = np.empty((n_obs,num_snaps_test)).T #actual lifted state
del_z_prime = np.empty((n_obs,num_snaps_test)).T
zu_unchanged = np.empty((n_obs*num_inputs,num_snaps_test)).T
x_adap_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values
del_A_norm = np.zeros((num_snaps_test,1))
del_B_norm = np.zeros((num_snaps_test,1))
# initialize
z_adap[0,:] = z_unchanged[0,:]
zu_unchanged[0,:] = np.kron(u[0,:],z_unchanged[0,:])
x_adap_est[0,:] = x_unchanged[0,:]

#
adap_window = 2 #hyperparameter

# %% [markdown]
# # Adaptive Time evolution

# %%
adapt_net_params = {}
adapt_net_params['state_dim'] = num_states
adapt_net_params['ctrl_dim'] = num_inputs
adapt_net_params['lift_dim'] = 20
adapt_net_params['optimizer'] = 'adam'
adapt_net_params['lr'] = 2e-4 # 5e-4
adapt_net_params['epochs'] = 5
adapt_net_params['batch_size'] = adap_window
adapt_net_params['l2_reg'] = 1e-2
adapt_net_params['l1_reg'] = 0
adapt_net_params['first_obs_const'] = net_params["first_obs_const"]
adapt_net_params['override_C'] = net_params["override_C"] # this makes the state a part of lifted state
adapt_net_params['warm_start'] = True



del_A = np.zeros_like(A)
del_B = np.zeros_like(B)

adapt_net_params['del_A_prev'] = del_A
adapt_net_params['del_B_prev'] = del_B

switch_time = 50

for i in range(num_snaps_test):
  # incorrect dynamics
    zu_unchanged[i,:] = np.kron(u[i,:],z_adap[i,:])
    # z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T + del_A.T)+np.matmul(zu_unchanged[i,:],B.T + del_B.T)
    z_unchanged[i+1,:] = np.matmul(z_adap[i,:],A.T)+np.matmul(zu_unchanged[i,:],B.T)
    
    z_changed[i,:] = lift(x_changed[i,:],model_koop_dnn, net_params)
    
    del_z_prime[i,:] = z_changed[i,:] - z_unchanged[i,:]
    if T_test[i] < switch_time:
        if i < adap_window + 1 :
            del_A = np.zeros_like(A)
            del_B = np.zeros_like(B)
        else:
            del_Z_prime = del_z_prime[i-adap_window:i,:].T
            Z_unchanged = z_unchanged[i-(adap_window+1):i-1].T
            ZU_unchanged = zu_unchanged[i-(adap_window+1):i-1].T

            #invoke neural net for adapation
            adapt_network = AdaptNet(adapt_net_params)
            adapt_network.model_pipeline(Z_unchanged, ZU_unchanged, del_Z_prime, print_epoch = True)

            del_A, del_B = adapt_network.get_del_matrices()

    del_A_norm[i] = np.linalg.norm(del_A)
    del_B_norm[i] = np.linalg.norm(del_B)
    
    # if del_B_norm[i] < np.linalg.norm(B):
    #     B_factor = adap_factor
    # else:
    #     B_factor = adap_factor*np.linalg.norm(B)/del_B_norm[i]
    #
    # if del_A_norm[i] < np.linalg.norm(A):
    #     A_factor = adap_factor
    # else:
    #     A_factor = adap_factor*np.linalg.norm(A)/del_A_norm[i]
    #
    # del_A = A_factor*del_A
    # del_B = B_factor*del_B
    adapt_net_params['del_A_prev'] = del_A
    adapt_net_params['del_B_prev'] = del_B
    # adapted model
    z_adap[i+1,:] = np.matmul(z_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_adap[i,:]), B.T + del_B.T )
    x_adap_est[i+1,:] = np.matmul(z_adap[i+1,:],C.T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 68
#      66 # adapted model
#      67 z_adap[i+1,:] = np.matmul(z_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_adap[i,:]), B.T + del_B.T )
# ---> 68 x_adap_est[i+1,:] = np.matmul(z_adap[i+1,:],C.T)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 529 is different from 23)

# %%
A.T.shape, del_A.shape

# %%
C.shape

# %%
z_adap.shape

# %% [markdown]
# # Performance Plotting

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,0],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,0],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.jpg')

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(T_test,x_adap_est[:,1],label = 'esimated (adapt)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.jpg')

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(x_adap_est[:,0],x_adap_est[:,1],label = 'estimated (adapt)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.jpg')

# %% [markdown]
# # Error Comparisons

# %%
error_dynamics_adap = np.linalg.norm((x_adap_est[:-1,:]-x_changed[:,:]), axis=1)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in Adaptive Model")
axs[1].set_title("Error in Non-Adaptive Model")

axs[0].set(xlabel = 't', ylabel = 'error')
axs[1].set(xlabel = 't', ylabel = 'error')


axs[0].plot(T_test[:-1],error_dynamics_adap)

axs[1].plot(T_test[:-1],error_dynamics_no_adapt)

plt.savefig('adap_error_comp.jpg')

# %% [markdown]
# ## Norm evolutions

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)
plt.show()

# %%
np.linalg.norm(A)

# %%
np.linalg.norm(A)

# %%
np.linalg.norm(B)

# %%
np.linalg.norm(B)

# %% [markdown]
# ## Post Adaptive Learning

# %%
z_post_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_post_adap_est = np.zeros((num_states,num_snaps_test+1)).T 
x_post_adap_est[0,:] = x_unchanged[0,:]
z_post_adap[0,:] = z_unchanged[0,:]

# %%
for i in range(num_snaps_test):
    z_post_adap[i+1,:] = np.matmul(z_post_adap[i,:], A.T+del_A.T) + np.matmul(np.kron(u[i,:],z_post_adap[i,:]), B + del_B.T )
    x_post_adap_est[i+1,:] = np.matmul(z_post_adap[i+1,:],C.T)

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,0],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,0],label ='estimated (no adapt)')
plt.plot(T_test,x_post_adap_est[:,0],label = 'esimated (post_adapt)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.jpg')

# %%
plt.figure()
plt.plot(T_test[:-1],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(T_test[:],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(T_test,x_post_adap_est[:,1],label = 'esimated (post_adapt)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.jpg')

# %%
plt.figure()
plt.plot(x_changed[:,0],x_changed[:,1],label ='Test data from changed dynamics')
plt.plot(x_unchanged_est[:,0],x_unchanged_est[:,1],label ='estimated (no adapt)')
plt.plot(x_adap_est[:,0],x_post_adap_est[:,1],label = 'estimated (post_adapt)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.jpg')
