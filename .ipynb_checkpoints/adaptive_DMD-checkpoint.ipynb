# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

from core.koopman_core import KoopDNN,KoopmanNet,KoopmanNetCtrl
from models.koop_model import model_matricies,lift
from dynamics.duffing import dynamics_duff
from dynamics.Vanpol import dynamics_vanpol

# %%
# Base Parameters
dt = 0.005 #time step
num_snaps = 2000 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 200 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 2 # no. of states
num_inputs = 1 # no. of inputs

# %%
# Oscillator parameters
dyn_pars = {}

dyn_pars['a'] = 1
dyn_pars['b'] = 4
dyn_pars['c'] = 0.5
dyn_pars['d'] = 0.5
dyn_pars['del_a'] = 0
dyn_pars['del_b'] = 0
dyn_pars['del_c'] = 5
dyn_pars['del_d'] = 0
dyn_pars['delay'] = False
dyn_pars['delay_time'] = 5
dyn_pars['cont_unc_type'] = 'sinosoidal'

# %%
X_cor, X_incor, U = dynamics_duff(dt, num_traj, num_snaps, num_states, num_inputs, dyn_pars)

print(X_cor.shape, U.shape)
# Out:
# (250, 2001, 2) (250, 2000, 1)

# %%
# Check for nan values
print(sum(sum(sum(np.isnan(X_cor)))))
print(sum(sum(sum(np.isnan(X_incor)))))
# Out:
# 0
# 0

# %%
l2_diff = np.linalg.norm(X_cor-X_incor)/((X_cor.size)**(1/2))
print('l2_diff = ', l2_diff)
# Out:
# l2_diff =  0.06114133812019993

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Phase plot for incorrect data")
axs[1].set_title("Phase plot for correct data")

axs[0].set(xlabel = 'x1', ylabel = 'x2')
axs[1].set(xlabel = 'x1', ylabel = 'x2')

for i in range(num_traj):
    axs[0].plot(X_incor[i,:,0], X_incor[i,:,1])
    axs[1].plot(X_cor[i,:,0], X_cor[i,:,1])
plt.savefig('phase_plot_duffing.jpg')

# %%
plt.figure()

plt.title('Comparison of Phase plot')
plt.plot(X_incor[4,:,0], X_incor[4,:,1], label = 'incorrect')
plt.plot(X_cor[4,:,0], X_cor[4,:,1], label = 'Actual')

plt.legend()
plt.savefig('phase_plot_duffing_sigle_traj.jpg')
plt.show()

# %%
# plot dataset
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in position")
axs[1].set_title("Error in velocity")

axs[0].set(xlabel = 't', ylabel = 'x1')
axs[1].set(xlabel = 't', ylabel = 'x2')


axs[0].plot(T, X_incor[4,:,0], label = 'Actual')
axs[0].plot(T, X_cor[4,:,0], label = 'Incorrect')
axs[0].legend()

axs[1].plot(T, X_incor[4,:,1], label = 'Actual')
axs[1].plot(T, X_cor[4,:,1], label = 'Incorrect')
axs[1].legend()

plt.savefig('vel_pos_err_duffing_sigle_traj.jpg')

# %%
# split training and vaidation datasets
xs_train, us_train = X_incor[:num_train,:,:],U[:num_train,:,:]
xs_val, us_val = X_incor[num_train:,:,:],U[num_train:,:,:]

# %% [markdown]
# ***Koopman bilinear Models***

# %%
# auto encoder parameters

net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 30
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 15
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 5e-4 # 5e-4
net_params['epochs'] = 100
net_params['batch_size'] = 256
net_params['lifted_loss_penalty'] = 0.3
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifted state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'duff.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'duff_best.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 0.1326095164, validation loss: 0.0205516948
# Epoch   2: train loss: 0.0092637325, validation loss: 0.0058310019
# Epoch   3: train loss: 0.0050856783, validation loss: 0.0038195015
# Epoch   4: train loss: 0.0034567020, validation loss: 0.0025991270
# Epoch   5: train loss: 0.0024770400, validation loss: 0.0019514357
# Epoch   6: train loss: 0.0018808235, validation loss: 0.0014624064
# Epoch   7: train loss: 0.0014686143, validation loss: 0.0011851533
# Epoch   8: train loss: 0.0011305925, validation loss: 0.0009608515
# Epoch   9: train loss: 0.0008220681, validation loss: 0.0007285246
# Epoch  10: train loss: 0.0005742418, validation loss: 0.0004591802
# Epoch  11: train loss: 0.0004324790, validation loss: 0.0003592317
# Epoch  12: train loss: 0.0003499706, validation loss: 0.0002721285
# Epoch  13: train loss: 0.0002892457, validation loss: 0.0002247474
# Epoch  14: train loss: 0.0002458020, validation loss: 0.0001986244
# Epoch  15: train loss: 0.0002112213, validation loss: 0.0001591532
# Epoch  16: train loss: 0.0001835128, validation loss: 0.0001564984
# Epoch  17: train loss: 0.0001611042, validation loss: 0.0001338154
# Epoch  18: train loss: 0.0001448968, validation loss: 0.0001108947
# Epoch  19: train loss: 0.0001311410, validation loss: 0.0000959918
# Epoch  20: train loss: 0.0001186477, validation loss: 0.0001209607
# Epoch  21: train loss: 0.0001092043, validation loss: 0.0001057054
# Epoch  22: train loss: 0.0001012008, validation loss: 0.0000893853
# Epoch  23: train loss: 0.0000956376, validation loss: 0.0000990686
# Epoch  24: train loss: 0.0000878340, validation loss: 0.0000727729
# Epoch  25: train loss: 0.0000831296, validation loss: 0.0000977722
# Epoch  26: train loss: 0.0000800465, validation loss: 0.0000596140
# Epoch  27: train loss: 0.0000750065, validation loss: 0.0000793358
# Epoch  28: train loss: 0.0000721973, validation loss: 0.0000751077
# Epoch  29: train loss: 0.0000684585, validation loss: 0.0000843346
# Epoch  30: train loss: 0.0000676729, validation loss: 0.0000551674
# Epoch  31: train loss: 0.0000645223, validation loss: 0.0000523571
# Epoch  32: train loss: 0.0000620040, validation loss: 0.0000419122
# Epoch  33: train loss: 0.0000606291, validation loss: 0.0000434691
# Epoch  34: train loss: 0.0000605092, validation loss: 0.0000464263
# Epoch  35: train loss: 0.0000572134, validation loss: 0.0000432755
# Epoch  36: train loss: 0.0000571106, validation loss: 0.0000350113
# Epoch  37: train loss: 0.0000541587, validation loss: 0.0000776347
# Epoch  38: train loss: 0.0000545043, validation loss: 0.0000347619
# Epoch  39: train loss: 0.0000534271, validation loss: 0.0000456975
# Epoch  40: train loss: 0.0000524462, validation loss: 0.0000322319
# Epoch  41: train loss: 0.0000514195, validation loss: 0.0000586943
# Epoch  42: train loss: 0.0000503361, validation loss: 0.0000290219
# Epoch  43: train loss: 0.0000493617, validation loss: 0.0001648154
# Epoch  44: train loss: 0.0000493306, validation loss: 0.0000375849
# Epoch  45: train loss: 0.0000478610, validation loss: 0.0000385489
# Epoch  46: train loss: 0.0000474931, validation loss: 0.0000683786
# Epoch  47: train loss: 0.0000477115, validation loss: 0.0000310136
# Epoch  48: train loss: 0.0000457454, validation loss: 0.0000407523
# Epoch  49: train loss: 0.0000466582, validation loss: 0.0000359949
# Epoch  50: train loss: 0.0000449528, validation loss: 0.0000241432
# Epoch  51: train loss: 0.0000444661, validation loss: 0.0000587194
# Epoch  52: train loss: 0.0000437692, validation loss: 0.0000284985
# Epoch  53: train loss: 0.0000449859, validation loss: 0.0000372746
# Epoch  54: train loss: 0.0000424652, validation loss: 0.0000345890
# Epoch  55: train loss: 0.0000428080, validation loss: 0.0000319685
# Epoch  56: train loss: 0.0000416796, validation loss: 0.0000383609
# Epoch  57: train loss: 0.0000417462, validation loss: 0.0000328944
# Epoch  58: train loss: 0.0000414873, validation loss: 0.0001794919
# Epoch  59: train loss: 0.0000400305, validation loss: 0.0000868448
# Epoch  60: train loss: 0.0000419523, validation loss: 0.0000480260
# Epoch  61: train loss: 0.0000393496, validation loss: 0.0000466331
# Epoch  62: train loss: 0.0000392889, validation loss: 0.0000278104
# Epoch  63: train loss: 0.0000394915, validation loss: 0.0000302641
# Epoch  64: train loss: 0.0000390525, validation loss: 0.0000350111
# Epoch  65: train loss: 0.0000406381, validation loss: 0.0000238884
# Epoch  66: train loss: 0.0000370688, validation loss: 0.0000615058
# Epoch  67: train loss: 0.0000379994, validation loss: 0.0000240380
# Epoch  68: train loss: 0.0000376821, validation loss: 0.0000440316
# Epoch  69: train loss: 0.0000369912, validation loss: 0.0000293753
# Epoch  70: train loss: 0.0000368026, validation loss: 0.0000235747
# Epoch  71: train loss: 0.0000366656, validation loss: 0.0000245326
# Epoch  72: train loss: 0.0000361483, validation loss: 0.0001845682
# Epoch  73: train loss: 0.0000357182, validation loss: 0.0000205180
# Epoch  74: train loss: 0.0000360102, validation loss: 0.0000746823
# Epoch  75: train loss: 0.0000359783, validation loss: 0.0000319234
# Epoch  76: train loss: 0.0000348941, validation loss: 0.0000150480
# Epoch  77: train loss: 0.0000344691, validation loss: 0.0000235797
# Epoch  78: train loss: 0.0000346567, validation loss: 0.0000167491
# Epoch  79: train loss: 0.0000350311, validation loss: 0.0000164615
# Epoch  80: train loss: 0.0000332116, validation loss: 0.0000240764
# Epoch  81: train loss: 0.0000342611, validation loss: 0.0000368657
# Epoch  82: train loss: 0.0000351030, validation loss: 0.0000146019
# Epoch  83: train loss: 0.0000330524, validation loss: 0.0000625552
# Epoch  84: train loss: 0.0000321482, validation loss: 0.0000180080
# Epoch  85: train loss: 0.0000324341, validation loss: 0.0000175346
# Epoch  86: train loss: 0.0000326763, validation loss: 0.0000269510
# Epoch  87: train loss: 0.0000314560, validation loss: 0.0000136354
# Epoch  88: train loss: 0.0000320467, validation loss: 0.0000242954
# Epoch  89: train loss: 0.0000315017, validation loss: 0.0000145851
# Epoch  90: train loss: 0.0000311384, validation loss: 0.0000241174
# Epoch  91: train loss: 0.0000308721, validation loss: 0.0001064552
# Epoch  92: train loss: 0.0000331140, validation loss: 0.0000230864
# Epoch  93: train loss: 0.0000284925, validation loss: 0.0000296404
# Epoch  94: train loss: 0.0000295556, validation loss: 0.0000447866
# Epoch  95: train loss: 0.0000316289, validation loss: 0.0000116302
# Epoch  96: train loss: 0.0000289165, validation loss: 0.0000532374
# Epoch  97: train loss: 0.0000293595, validation loss: 0.0000386769
# Epoch  98: train loss: 0.0000295988, validation loss: 0.0000181907
# Epoch  99: train loss: 0.0000289158, validation loss: 0.0000122824
# Epoch 100: train loss: 0.0000282902, validation loss: 0.0000293848
# Finished Training

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Learned Model Parameters

# %% [markdown]
# ## Bilinear Model Parameters

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)
# Out:
# (18, 18) (18, 18) (2, 18)

# %% [markdown]
# ## Lifting function

# %% [markdown]
# # Testing

# %% [markdown]
# ## Parameters

# %%
# test data parameters
num_snaps_test = 2000 # no. of snapshots
T_test = np.linspace(0,num_snaps_test*dt, num_snaps_test+1)
num_traj_test = 1 # no. of training examples
first_obs_const = int(net_params['first_obs_const']) #only one state
override_C = net_params['override_C']
if override_C:
    n_obs = int(net_params['encoder_output_dim']) + num_states + first_obs_const 
else:
    n_obs = int(net_params['encoder_output_dim']) + first_obs_const

# %% [markdown]
# ## Testing Data

# %%
x_cor_test, x_incor_test, u_test = dynamics_duff(dt, num_traj_test, num_snaps_test,num_states, num_inputs, dyn_pars)
print(model_koop_dnn.test_loss(x_incor_test,u_test = u_test))
# Out:
# tensor(0.0001)

# %%
x_cor_test.shape
# Out:
# (1, 2001, 2)

# %%
# Use the preprocessing if available
X_incor,_ = model_koop_dnn.net.process(x_incor_test,data_u = u_test)
X_cor,_ = model_koop_dnn.net.process(x_cor_test,data_u = u_test)

# %%
X_cor.shape
# Out:
# (2000, 5)

# %%
# flatten vector
x_incor = X_incor[:, :num_states]
u = X_incor[:, num_states:num_states+num_inputs]
x_incor_prime = X_incor[:,num_states+num_inputs:]

x_cor = X_cor[:, :num_states]
x_cor_prime = X_cor[:,num_states+num_inputs:]

x_cor_dot = (x_cor_prime-x_cor)/dt
print(x_cor.shape, u.shape, x_cor_prime.shape)
# Out:
# (2000, 2) (2000, 1) (2000, 2)

# %% [markdown]
# # Lifting of states

# %%
# initialize states
# initialize the matricies
z_incor = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
x_incor_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values

# %%
# actual lift
z_incor[0,:] = lift(x_incor[0,:],model_koop_dnn, net_params)
x_incor_est[0,:] = x_incor[0,:]

# %% [markdown]
# # Time Evolution

# %%
for i in range(num_snaps_test):
  #bilinear
    z_incor[i+1,:] = np.matmul(z_incor[i,:],A.T)+np.matmul(np.kron(u[i,:],z_incor[i,:]),B.T)
    x_incor_est[i+1,:] = np.matmul(z_incor[i+1,:],C.T)

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lifting performance

# %%
plt.figure()
plt.plot(T_test[:-1],x_incor[:,0],label ='Test data')
plt.plot(T_test,x_incor_est[:,0],label = 'esimated(bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T_test[:-1],x_incor[:,1],label ='Test data')
plt.plot(T_test,x_incor_est[:,1],label = 'esimated(bilinear)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(x_incor[:,0],x_incor[:,1],label ='Test data')
plt.plot(x_incor_est[:,0],x_incor_est[:,1],label = 'esimated(bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()

# %% [markdown]
# ### Error Evolution

# %%
error_model = np.sqrt(np.square(x_incor_est[:-1,:]-x_incor[:,:]).mean(axis=1))
error_dynamics = np.sqrt(np.square(x_incor_est[:-1,:]-x_cor[:,:]).mean(axis=1))

# %%
plt.figure()
plt.plot(T_test[:-1],error_model)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Model error evolution')
# Out:
# Text(0.5, 1.0, 'Model error evolution')

# %% [markdown]
# ## Deviation from Actual Dynamics

# %%
plt.figure()
plt.plot(T_test[:-1],x_cor[:,0],label ='Test data (accurate)')
plt.plot(T_test[:-1],x_incor[:,0],label ='Test data (inaccurate)')
plt.plot(T_test,x_incor_est[:,0],label = 'esimated(bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T_test[:-1],x_cor[:,1],label ='Test data (accurate)')
plt.plot(T_test[:-1],x_incor[:,1],label ='Test data (inaccurate)')
plt.plot(T_test,x_incor_est[:,1],label = 'esimated(bilinear)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Velocity Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(x_cor[:,0],x_cor[:,1],label ='Test data (accurate)')
plt.plot(x_incor[:,0],x_incor[:,1],label ='Test data (inaccurate)')
plt.plot(x_incor_est[:,0],x_incor_est[:,1],label = 'esimated(bilinear)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Phase Space trajectory Comparison')
plt.legend()

# %%
plt.figure()
plt.plot(T_test[:-1],error_dynamics)
plt.xlabel('t')
plt.ylabel('e')
plt.title('Dynamics error evolution')
# Out:
# Text(0.5, 1.0, 'Dynamics error evolution')

# %% [markdown]
# # Adaptation

# %% [markdown]
# ## Data Preprocessing

# %%
# initialize state matricies
z_adap = np.empty((n_obs,num_snaps_test+1)).T   #lifted state
z_cor = np.empty((n_obs,num_snaps_test)).T #actual lifted state
del_z_prime = np.empty((n_obs,num_snaps_test)).T
zu_incor = np.empty((n_obs*num_inputs,num_snaps_test)).T  
x_adap_est = np.zeros((num_states,num_snaps_test+1)).T #estimated values
del_A_norm = np.zeros((num_snaps_test,1))
del_B_norm = np.zeros((num_snaps_test,1))
# initialize
z_adap[0,:] = z_incor[0,:]
zu_incor[0,:] = np.kron(u[0,:],z_incor[i,:])
x_adap_est[0,:] = x_incor[0,:]

#
adap_window = 10
adap_factor = 5e-1

# %% [markdown]
# # Adaptive Time evolution

# %%
for i in range(num_snaps_test):
  # incorrect dynamics
    zu_incor[i,:] = np.kron(u[i,:],z_adap[i,:])
    z_incor[i+1,:] = np.matmul(z_adap[i,:],A.T)+np.matmul(zu_incor[i,:],B.T)
    
    z_cor[i,:] = lift(x_cor[i,:],model_koop_dnn, net_params)
    
    del_z_prime[i,:] = z_cor[i,:] - z_incor[i,:]
    if i < adap_window + 1 :
        del_A = np.zeros_like(A)
        del_B = np.zeros_like(A)
    else:
        del_Z_prime = del_z_prime[i-adap_window:i,:].T
        Z_incor = z_incor[i-(adap_window+1):i-1].T  
        ZU_incor = zu_incor[i-(adap_window+1):i-1].T
        Omega = np.vstack((Z_incor, ZU_incor))
        G = np.matmul(del_Z_prime, np.linalg.pinv(Omega))
        del_A = G[0:n_obs,0:n_obs]
        del_B = G[0:n_obs,n_obs:n_obs*(num_inputs+1)]

    del_A_norm[i] = np.linalg.norm(del_A)
    del_B_norm[i] = np.linalg.norm(del_B)
    
    if del_B_norm[i] < np.linalg.norm(B):
        B_factor = adap_factor
    else:
        B_factor = adap_factor*np.linalg.norm(B)/del_B_norm[i]
    
    if del_A_norm[i] < np.linalg.norm(A):
        A_factor = adap_factor
    else:
        A_factor = adap_factor*np.linalg.norm(A)/del_A_norm[i]
        
    del_A = A_factor*del_A
    del_B = B_factor*del_B
    
    
    # adapted model
    z_adap[i+1,:] = np.matmul(z_adap[i,:],A.T+del_A.T)+np.matmul(np.kron(u[i,:],z_adap[i,:]),B + del_B.T )
    x_adap_est[i+1,:] = np.matmul(z_adap[i+1,:],C.T)

# %% [markdown]
# # Performance Plotting

# %%
plt.figure()
plt.plot(T_test[:-1],x_cor[:,0],label ='Test data (accurate)')
plt.plot(T_test[:],x_incor_est[:,0],label ='est(unadap)')
plt.plot(T_test,x_adap_est[:,0],label = 'esimated(adap)')
plt.xlabel('t')
plt.ylabel('x1')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_pos.jpg')

# %%
plt.figure()
plt.plot(T_test[:-1],x_cor[:,1],label ='Test data (accurate)')
plt.plot(T_test[:],x_incor_est[:,1],label ='est(unadap)')
plt.plot(T_test,x_adap_est[:,1],label = 'esimated(adap)')
plt.xlabel('t')
plt.ylabel('x2')
plt.title('Velocity Comparison')
plt.legend()
plt.savefig('adap_vel.jpg')

# %%
plt.figure()
plt.plot(x_cor[:,0],x_cor[:,1],label ='Test data (accurate)')
plt.plot(x_incor_est[:,0],x_incor_est[:,1],label ='est(unadap)')
plt.plot(x_adap_est[:,0],x_adap_est[:,1],label = 'esimated(adap)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Position Comparison')
plt.legend()
plt.savefig('adap_phase.jpg')

# %% [markdown]
# # Error Comparisons

# %%
error_dynamics_adap = np.sqrt(np.square(x_adap_est[:-1,:]-x_cor[:,:]).mean(axis=1))

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title("Error in Adaptive Model")
axs[1].set_title("Error in Non-Adaptive Model")

axs[0].set(xlabel = 't', ylabel = 'error')
axs[1].set(xlabel = 't', ylabel = 'error')


axs[0].plot(T_test[:-1],error_dynamics_adap)

axs[1].plot(T_test[:-1],error_dynamics)

plt.savefig('adap_error_comp.jpg')

# %% [markdown]
# ## Norm evolutions

# %%
fig, axs = plt.subplots(1,2,figsize=(12,7))
axs[0].set_title(" ||del_A|| Evolution")
axs[1].set_title("||del_B|| Evolution")

axs[0].set(xlabel = 't', ylabel = '||del_A||')
axs[1].set(xlabel = 't', ylabel = '||del_B||')


axs[0].plot(T_test[:-1],del_A_norm)

axs[1].plot(T_test[:-1],del_B_norm)

# %%
np.linalg.norm(A)
# Out:
# 4.2391534

# %%
np.linalg.norm(B)
# Out:
# 0.008650367
