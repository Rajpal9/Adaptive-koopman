# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch

# linear Koopman
from core.koopman_core_linear import KoopDNN as KoopDNN
from core.koopman_core_linear import KoopmanNet as KoopmanNet
from core.koopman_core_linear import KoopmanNetCtrl as KoopmanNetCtrl
from core.adapt_net_lin import AdaptNet_lin



from models.koop_model import model_matricies,lift
from dynamics.robot_3R import dynamics_3R
from dynamics.Vanpol import dynamics_vanpol

import control as ct

# %%
dt = 0.005 #time step
num_snaps = 1000 # no. of snapshots
T = np.linspace(0,num_snaps*dt, num_snaps+1)
num_train = 100 # no. of training examples
num_val = int(0.25*num_train) # no of testing examples
num_traj = num_train+num_val #no of trajectories
num_states = 6 # no. of states
num_inputs = 3 # no. of inputs

# %%
robot_pars = {}
# link lengths
robot_pars['a1'] = 0.33
robot_pars['a2'] = 0.33
robot_pars['a3'] = 0.33

#link masses
robot_pars['m1'] = 0.1
robot_pars['m2'] = 0.1
robot_pars['m3'] = 0.1

# link inertias
robot_pars['I1'] = 1
robot_pars['I2'] = 1
robot_pars['I3'] = 1

#position of CM
robot_pars['l1'] = 0.33/2
robot_pars['l2'] = 0.33/2
robot_pars['l3'] = 0.33/2

#dynamic friction coefficient
robot_pars['fd'] = 0.1

# %%
X_end,X_full, U_full = dynamics_3R(dt,num_traj, num_snaps,num_states,num_inputs,robot_pars)
print(X_end.shape, X_full.shape,U_full.shape)
# Out:
# (125, 1001, 2) (125, 1001, 6) (125, 1000, 3)

# %%
"""Training dataset visualization"""
#theta1 theta2 plot
plt.subplot(2,3,1)
plt.title("Trajectory Plot")
plt.xlabel("th1")
plt.ylabel("th2")
for i in range(num_traj):
  plt.plot(X_full[i,:,0],X_full[i,:,1])

#theta2 theta3 plot
plt.subplot(2,3,2)
plt.xlabel("th2")
plt.ylabel("th3")
for i in range(num_traj):
    plt.plot(X_full[i,:,1],X_full[i,:,2])

#theta1 theta3 plot
plt.subplot(2,3,3)
plt.xlabel("th1")
plt.ylabel("th3")
for i in range(num_traj):
    plt.plot(X_full[i,:,0],X_full[i,:,2])

#theta1_dot theta2_dot plot
plt.subplot(2,3,4)
plt.xlabel("th1_dot")
plt.ylabel("th2_dot")
for i in range(num_traj):
    plt.plot(X_full[i,:,3],X_full[i,:,4])

#theta2_dot theta3_dot plot
plt.subplot(2,3,5)
plt.xlabel("th2_dot")
plt.ylabel("th3_dot")
for i in range(num_traj):
    plt.plot(X_full[i,:,4],X_full[i,:,5])

#theta1_dot theta3_dot plot
plt.subplot(2,3,6)
plt.xlabel("th1_dot")
plt.ylabel("th3_dot")
for i in range(num_traj):
    plt.plot(X_full[i,:,3],X_full[i,:,5])

# %%
#x and y positions of the end effector

plt.xlabel("x")
plt.ylabel("y")
for i in range(num_traj):
    plt.plot(X_end[i,:,0],X_end[i,:,1])

# %%
# split training and vaidation datasets
xs_train, us_train = X_full[:num_train,:,:],U_full[:num_train,:,:]
xs_val, us_val = X_full[num_train:,:,:],U_full[num_train:,:,:]

# %%
net_params = {}
net_params['state_dim'] = num_states
net_params['ctrl_dim'] = num_inputs
net_params['encoder_hidden_width'] = 10
net_params['encoder_hidden_depth'] = 2
net_params['encoder_output_dim'] = 10
net_params['optimizer'] = 'adam'
net_params['activation_type'] = 'tanh'
net_params['lr'] = 4e-4 # 5e-4
net_params['epochs'] = 2000
net_params['batch_size'] = 128
net_params['lifted_loss_penalty'] = 0.4 
net_params['l2_reg'] = 0.0         
net_params['l1_reg'] = 0.0
net_params['first_obs_const'] = True
net_params['override_C'] = True # this makes the state a part of lifetd state
net_params['dt'] = dt

# %%
train = True

if train == True:
    file = 'saved_models/learned_models/linear_model/robot_3r_lin.pth'
    net = KoopmanNetCtrl(net_params)
    model_koop_dnn = KoopDNN(net)
    model_koop_dnn.set_datasets(xs_train, u_train=us_train, x_val=xs_val, u_val=us_val)
    model_koop_dnn.model_pipeline(net_params)
    model_koop_dnn.construct_koopman_model()
    torch.save(model_koop_dnn,file)
else:
    file = 'saved_models/learned_models/linear_model/robot_3r_lin.pth'
    model_koop_dnn = torch.load(file)
# Out:
# Epoch   1: train loss: 1.0404229164, validation loss: 0.8886661422
# Epoch   2: train loss: 0.6961566210, validation loss: 0.6295444275
# Epoch   3: train loss: 0.4540104866, validation loss: 0.3933867988
# Epoch   4: train loss: 0.2577397525, validation loss: 0.1972809542
# Epoch   5: train loss: 0.1064249128, validation loss: 0.0634430963
# Epoch   6: train loss: 0.0344932377, validation loss: 0.0187715935
# Epoch   7: train loss: 0.0098646982, validation loss: 0.0053201535
# Epoch   8: train loss: 0.0027098728, validation loss: 0.0017788717
# Epoch   9: train loss: 0.0009209134, validation loss: 0.0009547109
# Epoch  10: train loss: 0.0005332040, validation loss: 0.0007301955
# Epoch  11: train loss: 0.0004121317, validation loss: 0.0005895718
# Epoch  12: train loss: 0.0003397791, validation loss: 0.0004981976
# Epoch  13: train loss: 0.0002894464, validation loss: 0.0004177641
# Epoch  14: train loss: 0.0002531226, validation loss: 0.0003721838
# Epoch  15: train loss: 0.0002263133, validation loss: 0.0003319002
# Epoch  16: train loss: 0.0002062270, validation loss: 0.0003010412
# Epoch  17: train loss: 0.0001904966, validation loss: 0.0002699408
# Epoch  18: train loss: 0.0001783879, validation loss: 0.0002488995
# Epoch  19: train loss: 0.0001676356, validation loss: 0.0002349210
# Epoch  20: train loss: 0.0001592785, validation loss: 0.0002088377
# Epoch  21: train loss: 0.0001514518, validation loss: 0.0001942224
# Epoch  22: train loss: 0.0001454857, validation loss: 0.0001918423
# Epoch  23: train loss: 0.0001402448, validation loss: 0.0001823366
# Epoch  24: train loss: 0.0001353527, validation loss: 0.0001754281
# Epoch  25: train loss: 0.0001311285, validation loss: 0.0001704649
# Epoch  26: train loss: 0.0001275480, validation loss: 0.0001567864
# Epoch  27: train loss: 0.0001247984, validation loss: 0.0001519330
# Epoch  28: train loss: 0.0001211763, validation loss: 0.0001465035
# Epoch  29: train loss: 0.0001187613, validation loss: 0.0001395776
# Epoch  30: train loss: 0.0001161122, validation loss: 0.0001402012
# Epoch  31: train loss: 0.0001144357, validation loss: 0.0001349295
# Epoch  32: train loss: 0.0001120080, validation loss: 0.0001323054
# Epoch  33: train loss: 0.0001103120, validation loss: 0.0001271699
# Epoch  34: train loss: 0.0001086284, validation loss: 0.0001263321
# Epoch  35: train loss: 0.0001066700, validation loss: 0.0001207250
# Epoch  36: train loss: 0.0001054713, validation loss: 0.0001221127
# Epoch  37: train loss: 0.0001037810, validation loss: 0.0001167219
# Epoch  38: train loss: 0.0001026011, validation loss: 0.0001130379
# Epoch  39: train loss: 0.0001016232, validation loss: 0.0001123898
# Epoch  40: train loss: 0.0000999726, validation loss: 0.0001070816
# Epoch  41: train loss: 0.0000991392, validation loss: 0.0001131400
# Epoch  42: train loss: 0.0000980451, validation loss: 0.0001069952
# Epoch  43: train loss: 0.0000973315, validation loss: 0.0001045182
# Epoch  44: train loss: 0.0000959539, validation loss: 0.0001062522
# Epoch  45: train loss: 0.0000953199, validation loss: 0.0000986406
# Epoch  46: train loss: 0.0000947204, validation loss: 0.0000989203
# Epoch  47: train loss: 0.0000932930, validation loss: 0.0001121440
# Epoch  48: train loss: 0.0000926252, validation loss: 0.0000949378
# Epoch  49: train loss: 0.0000917096, validation loss: 0.0000992835
# Epoch  50: train loss: 0.0000909747, validation loss: 0.0000967897
# Epoch  51: train loss: 0.0000910120, validation loss: 0.0000987664
# Epoch  52: train loss: 0.0000893969, validation loss: 0.0000930101
# Epoch  53: train loss: 0.0000896175, validation loss: 0.0000919024
# Epoch  54: train loss: 0.0000881543, validation loss: 0.0000920550
# Epoch  55: train loss: 0.0000877232, validation loss: 0.0000941785
# Epoch  56: train loss: 0.0000873126, validation loss: 0.0000885865
# Epoch  57: train loss: 0.0000867888, validation loss: 0.0000900259
# Epoch  58: train loss: 0.0000869759, validation loss: 0.0000875885
# Epoch  59: train loss: 0.0000854857, validation loss: 0.0000867728
# Epoch  60: train loss: 0.0000850877, validation loss: 0.0000981923
# Epoch  61: train loss: 0.0000846207, validation loss: 0.0000848827
# Epoch  62: train loss: 0.0000841647, validation loss: 0.0000858728
# Epoch  63: train loss: 0.0000835901, validation loss: 0.0000831425
# Epoch  64: train loss: 0.0000832347, validation loss: 0.0000828302
# Epoch  65: train loss: 0.0000824324, validation loss: 0.0000816662
# Epoch  66: train loss: 0.0000823898, validation loss: 0.0000829040
# Epoch  67: train loss: 0.0000821004, validation loss: 0.0000807245
# Epoch  68: train loss: 0.0000814208, validation loss: 0.0000803948
# Epoch  69: train loss: 0.0000810763, validation loss: 0.0000821563
# Epoch  70: train loss: 0.0000809305, validation loss: 0.0000785939
# Epoch  71: train loss: 0.0000806222, validation loss: 0.0000828289
# Epoch  72: train loss: 0.0000794870, validation loss: 0.0000812098
# Epoch  73: train loss: 0.0000798589, validation loss: 0.0000782232
# Epoch  74: train loss: 0.0000792544, validation loss: 0.0000786770
# Epoch  75: train loss: 0.0000789960, validation loss: 0.0000769306
# Epoch  76: train loss: 0.0000789243, validation loss: 0.0000756545
# Epoch  77: train loss: 0.0000787042, validation loss: 0.0000780667
# Epoch  78: train loss: 0.0000780732, validation loss: 0.0000785177
# Epoch  79: train loss: 0.0000774716, validation loss: 0.0000758028
# Epoch  80: train loss: 0.0000775694, validation loss: 0.0000751113
# Epoch  81: train loss: 0.0000775136, validation loss: 0.0000768813
# Epoch  82: train loss: 0.0000766148, validation loss: 0.0000787334
# Epoch  83: train loss: 0.0000767524, validation loss: 0.0000738787
# Epoch  84: train loss: 0.0000762704, validation loss: 0.0000725987
# Epoch  85: train loss: 0.0000761023, validation loss: 0.0000744373
# Epoch  86: train loss: 0.0000758627, validation loss: 0.0000749780
# Epoch  87: train loss: 0.0000756312, validation loss: 0.0000736262
# Epoch  88: train loss: 0.0000754646, validation loss: 0.0000735047
# Epoch  89: train loss: 0.0000749836, validation loss: 0.0000756587
# Epoch  90: train loss: 0.0000751339, validation loss: 0.0000723959
# Epoch  91: train loss: 0.0000745891, validation loss: 0.0000713104
# Epoch  92: train loss: 0.0000743013, validation loss: 0.0000729279
# Epoch  93: train loss: 0.0000742954, validation loss: 0.0000743774
# Epoch  94: train loss: 0.0000743639, validation loss: 0.0000725860
# Epoch  95: train loss: 0.0000735823, validation loss: 0.0000707743
# Epoch  96: train loss: 0.0000739816, validation loss: 0.0000696538
# Epoch  97: train loss: 0.0000731671, validation loss: 0.0000695351
# Epoch  98: train loss: 0.0000732033, validation loss: 0.0000738040
# Epoch  99: train loss: 0.0000728829, validation loss: 0.0000701089
# Epoch 100: train loss: 0.0000734005, validation loss: 0.0000693245
# Epoch 101: train loss: 0.0000725445, validation loss: 0.0000714050
# Epoch 102: train loss: 0.0000727956, validation loss: 0.0000687962
# Epoch 103: train loss: 0.0000723076, validation loss: 0.0000679383
# Epoch 104: train loss: 0.0000721520, validation loss: 0.0000703772
# Epoch 105: train loss: 0.0000721622, validation loss: 0.0000713406
# Epoch 106: train loss: 0.0000719001, validation loss: 0.0000688199
# Epoch 107: train loss: 0.0000721039, validation loss: 0.0000676618
# Epoch 108: train loss: 0.0000712093, validation loss: 0.0000706144
# Epoch 109: train loss: 0.0000715119, validation loss: 0.0000734574
# Epoch 110: train loss: 0.0000713131, validation loss: 0.0000706226
# Epoch 111: train loss: 0.0000713666, validation loss: 0.0000675274
# Epoch 112: train loss: 0.0000707361, validation loss: 0.0000666739
# Epoch 113: train loss: 0.0000707739, validation loss: 0.0000663164
# Epoch 114: train loss: 0.0000704430, validation loss: 0.0000675411
# Epoch 115: train loss: 0.0000707949, validation loss: 0.0000704280
# Epoch 116: train loss: 0.0000705293, validation loss: 0.0000672551
# Epoch 117: train loss: 0.0000703021, validation loss: 0.0000668344
# Epoch 118: train loss: 0.0000701695, validation loss: 0.0000659481
# Epoch 119: train loss: 0.0000700118, validation loss: 0.0000675874
# Epoch 120: train loss: 0.0000699264, validation loss: 0.0000667483
# Epoch 121: train loss: 0.0000698533, validation loss: 0.0000651542
# Epoch 122: train loss: 0.0000697596, validation loss: 0.0000672759
# Epoch 123: train loss: 0.0000702228, validation loss: 0.0000652961
# Epoch 124: train loss: 0.0000689804, validation loss: 0.0000660049
# Epoch 125: train loss: 0.0000692314, validation loss: 0.0000655433
# Epoch 126: train loss: 0.0000693484, validation loss: 0.0000682749
# Epoch 127: train loss: 0.0000693712, validation loss: 0.0000642532
# Epoch 128: train loss: 0.0000687618, validation loss: 0.0000674249

# %%
train_loss = [l[0] for l in model_koop_dnn.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn.val_loss_hist]
epochs = np.arange(0, net_params_lin['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_loss, color='tab:orange', label='Training loss')
plt.plot(epochs, train_pred_loss, '--', color='tab:orange', label='Training prediction loss')
plt.plot(epochs, train_lifted_loss, ':', color='tab:orange', label='Training lifted loss')
plt.plot(epochs, val_loss, color='tab:blue', label='Validation loss')
plt.plot(epochs, val_pred_loss, '--', color='tab:blue', label='Validation prediction loss')
plt.plot(epochs, val_lifted_loss, ':', color='tab:blue', label='Validation lifted loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Koopman Linear Model

# %%
A = np.array(model_koop_dnn.A)
#B = np.array(model_koop_dnn.B).reshape(-1,num_inputs*n_obs)
B = np.array(model_koop_dnn.B)
#B_tensor = np.empty((num_inputs,n_obs, n_obs))
#for ii, b in enumerate(B):
    #B_tensor[ii] = b
C = np.array(model_koop_dnn.C)

print(A.shape, B.shape, C.shape)

# %% [markdown]
# ## Controllability

# %%
#check controllability
Con_lin = ct.ctrb(A, B)
rank_lin = np.linalg.matrix_rank(Con)
