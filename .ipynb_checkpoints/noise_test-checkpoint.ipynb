# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,2*np.pi,101)
y = np.sin(x)
SNR_DB = 1
SN = 10**(SNR_DB/10)
SN
# Out:
# 1.2589254117941673

# %%
y_noise_gaus = np.random.normal(loc = y,scale = 1/SN)
y_noise_rand = y + (2*np.random.rand(y.shape[0])-1)/SN
y_noise_sino = y*np.sin(100*np.pi*x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y_noise_gaus = np.random.normal(loc = y,scale = 1/SN)
#       2 y_noise_rand = y + (2*np.random.rand(y.shape[0])-1)/SN
#       3 y_noise_sino = y*np.sin(100*np.pi*x)
#
# NameError: name 'np' is not defined

# %%
plt.figure()
plt.plot(y)
plt.plot(y_noise_gaus,'--')

# %%
plt.figure()
plt.plot(y)
plt.plot(y_noise_rand,'--')

# %%
plt.figure()
plt.plot(y)
plt.plot(y_noise_sin,'--')
